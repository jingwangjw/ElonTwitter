# %%
# !pip install pandas_datareader
# !pip install fix-yahoo-finance
# %matplotlib inline

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas_datareader
from pandas_datareader import data as pdr
import fix_yahoo_finance
import datetime
import os
import time
# show all output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import fix_yahoo_finance as yf
# Out:
# Requirement already satisfied: pandas_datareader in /jet/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied: lxml in /jet/lib/python3.6/site-packages (from pandas_datareader) (4.3.3)
# Requirement already satisfied: wrapt in /jet/lib/python3.6/site-packages (from pandas_datareader) (1.11.1)
# Requirement already satisfied: pandas>=0.19.2 in /jet/lib/python3.6/site-packages (from pandas_datareader) (0.24.2)
# Requirement already satisfied: requests>=2.3.0 in /jet/lib/python3.6/site-packages (from pandas_datareader) (2.21.0)
# Requirement already satisfied: pytz>=2011k in /jet/lib/python3.6/site-packages (from pandas>=0.19.2->pandas_datareader) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /jet/lib/python3.6/site-packages (from pandas>=0.19.2->pandas_datareader) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /jet/lib/python3.6/site-packages (from pandas>=0.19.2->pandas_datareader) (2.6.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /jet/lib/python3.6/site-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /jet/lib/python3.6/site-packages (from requests>=2.3.0->pandas_datareader) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /jet/lib/python3.6/site-packages (from requests>=2.3.0->pandas_datareader) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /jet/lib/python3.6/site-packages (from requests>=2.3.0->pandas_datareader) (2.8)
# Requirement already satisfied: six>=1.5 in /jet/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.19.2->pandas_datareader) (1.11.0)
# Requirement already satisfied: fix-yahoo-finance in /jet/lib/python3.6/site-packages (0.1.25)
# Requirement already satisfied: numpy in /jet/lib/python3.6/site-packages (from fix-yahoo-finance) (1.16.2)
# Requirement already satisfied: pandas in /jet/lib/python3.6/site-packages (from fix-yahoo-finance) (0.24.2)
# Requirement already satisfied: requests in /jet/lib/python3.6/site-packages (from fix-yahoo-finance) (2.21.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /jet/lib/python3.6/site-packages (from pandas->fix-yahoo-finance) (2.6.0)
# Requirement already satisfied: pytz>=2011k in /jet/lib/python3.6/site-packages (from pandas->fix-yahoo-finance) (2018.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /jet/lib/python3.6/site-packages (from requests->fix-yahoo-finance) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /jet/lib/python3.6/site-packages (from requests->fix-yahoo-finance) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /jet/lib/python3.6/site-packages (from requests->fix-yahoo-finance) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /jet/lib/python3.6/site-packages (from requests->fix-yahoo-finance) (3.0.4)
# Requirement already satisfied: six>=1.5 in /jet/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->fix-yahoo-finance) (1.11.0)

# %%
data = pd.read_csv("/users/siyuanxue/desktop/研一下/224/224 project/company_symbol.csv", header=None, index_col= False)
data.columns=["Ticker"]
data1_100 = data.iloc[0:30]
data100_200 = data.iloc[100:200]
data200_300 = data.iloc[200:300]
data300_400 = data.iloc[300:400]
data400_500 = data.iloc[400:500]
data500_600 = data.iloc[500:600]
data600_700 = data.iloc[600:700]
data700_800 = data.iloc[700:800]
data800_900 = data.iloc[800:900]
data900_1000 = data.iloc[900:1000]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-34e786d9bbd2> in <module>()
# ----> 1 data = pd.read_csv("/users/siyuanxue/desktop/研一下/224/224 project/company_symbol.csv", header=None, index_col= False)
#       2 data.columns=["Ticker"]
#       3 data1_100 = data.iloc[0:30]
#       4 data100_200 = data.iloc[100:200]
#       5 data200_300 = data.iloc[200:300]
#
# ~/var/python/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/var/python/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/var/python/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/var/python/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/var/python/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/users/siyuanxue/desktop/\xe7\xa0\x94\xe4\xb8\x80\xe4\xb8\x8b/224/224 project/company_symbol.csv' does not exist: b'/users/siyuanxue/desktop/\xe7\xa0\x94\xe4\xb8\x80\xe4\xb8\x8b/224/224 project/company_symbol.csv'

# %%
def get_adj_closing_prices(tickers, start_date, end_date):
    all_prices = {}
    for ticker in tickers:
        count = 0
        success = False
        while (not success) and count < 10:
            success = True
            count += 1
            try:
                prices = pdr.get_data_yahoo(ticker, 
                    start=start_date,
                    end=end_date
                )
                all_prices[ticker] = prices["Adj Close"]
                time.sleep(1)
            except KeyError:
                success = False
                time.sleep(5)
        if not success:
            print("Skipping %s" % ticker)
    
    return pd.DataFrame(all_prices)

# %%
price_without_na_columns1_100 = get_adj_closing_prices(["TSLA"], datetime.datetime(2017, 12, 31), datetime.datetime(2018, 12, 31)).dropna(1)

# %%
price_without_na_columns1_100
# Out:
#                   TSLA
# Date
# 2018-01-02  320.529999
# 2018-01-03  317.250000
# 2018-01-04  314.619995
# 2018-01-05  316.579987
# 2018-01-08  336.410004
# 2018-01-09  333.690002
# 2018-01-10  334.799988
# 2018-01-11  337.950012
# 2018-01-12  336.220001
# 2018-01-16  340.059998
# 2018-01-17  347.160004
# 2018-01-18  344.570007
# 2018-01-19  350.019989
# 2018-01-22  351.559998
# 2018-01-23  352.790009
# 2018-01-24  345.890015
# 2018-01-25  337.640015
# 2018-01-26  342.850006
# 2018-01-29  349.529999
# 2018-01-30  345.820007
# 2018-01-31  354.309998
# 2018-02-01  349.250000
# 2018-02-02  343.750000
# 2018-02-05  333.130005
# 2018-02-06  333.970001
# 2018-02-07  345.000000
# 2018-02-08  315.230011
# 2018-02-09  310.420013
# 2018-02-12  315.730011
# 2018-02-13  323.660004
# ...                ...
# 2018-11-15  348.440002
# 2018-11-16  354.309998
# 2018-11-19  353.470001
# 2018-11-20  347.489990
# 2018-11-21  338.190002
# 2018-11-23  325.829987
# 2018-11-26  346.000000
# 2018-11-27  343.920013
# 2018-11-28  347.869995
# 2018-11-29  341.170013
# 2018-11-30  350.480011
# 2018-12-03  358.489990
# 2018-12-04  359.700012
# 2018-12-06  363.059998
# 2018-12-07  357.970001
# 2018-12-10  365.149994
# 2018-12-11  366.760010
# 2018-12-12  366.600006
# 2018-12-13  376.790009
# 2018-12-14  365.709991
# 2018-12-17  348.420013
# 2018-12-18  337.029999
# 2018-12-19  332.970001
# 2018-12-20  315.380005
# 2018-12-21  319.769989
# 2018-12-24  295.390015
# 2018-12-26  326.089996
# 2018-12-27  316.130005
# 2018-12-28  333.869995
# 2018-12-31  332.799988
#
# [251 rows x 1 columns]

# %%
price_without_na_columns1_100 = get_adj_closing_prices(data1_100["Ticker"], datetime.datetime(2017, 12, 31), datetime.datetime(2018, 12, 31)).dropna(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-07d5bd660d81> in <module>()
# ----> 1 price_without_na_columns1_100 = get_adj_closing_prices(data1_100["Ticker"], datetime.datetime(2017, 12, 31), datetime.datetime(2018, 12, 31)).dropna(1)
#
# NameError: name 'data1_100' is not defined

# %%
monthly_returns_before = price_without_na_columns1_100.resample('M').last()
monthly_returns = monthly_returns_before.pct_change()

# %%
price_without_na_columns1_100 .to_csv('daily_return1.csv', encoding='utf-8')
monthly_returns .to_csv('monthly_return1.csv',encoding='utf-8')

# %%
msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="1d", interval = "1m", auto_adjust=True)
# Out:
# {'ask': 120.65,
#  'askSize': 31,
#  'averageDailyVolume10Day': 16447716,
#  'averageDailyVolume3Month': 26306087,
#  'bid': 120.65,
#  'bidSize': 22,
#  'bookValue': 11.991,
#  'currency': 'USD',
#  'dividendDate': 1560384000,
#  'earningsTimestamp': 1556136000,
#  'earningsTimestampEnd': 1556539200,
#  'earningsTimestampStart': 1556103540,
#  'epsForward': 4.99,
#  'epsTrailingTwelveMonths': 4.311,
#  'esgPopulated': False,
#  'exchange': 'NMS',
#  'exchangeDataDelayedBy': 0,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'fiftyDayAverage': 116.253334,
#  'fiftyDayAverageChange': 4.5166626,
#  'fiftyDayAverageChangePercent': 0.0388519,
#  'fiftyTwoWeekHigh': 121.65,
#  'fiftyTwoWeekHighChange': -0.8800049,
#  'fiftyTwoWeekHighChangePercent': -0.0072339075,
#  'fiftyTwoWeekLow': 90.28,
#  'fiftyTwoWeekLowChange': 30.489998,
#  'fiftyTwoWeekLowChangePercent': 0.33772704,
#  'fiftyTwoWeekRange': '90.28 - 121.65',
#  'financialCurrency': 'USD',
#  'forwardPE': 24.202406,
#  'fullExchangeName': 'NasdaqGS',
#  'gmtOffSetMilliseconds': -14400000,
#  'language': 'en-US',
#  'longName': 'Microsoft Corporation',
#  'market': 'us_market',
#  'marketCap': 926572740608,
#  'marketState': 'POSTPOST',
#  'messageBoardId': 'finmb_21835',
#  'postMarketChange': -0.35999298,
#  'postMarketChangePercent': -0.29808146,
#  'postMarketPrice': 120.41,
#  'postMarketTime': 1555459198,
#  'priceHint': 2,
#  'priceToBook': 10.07172,
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'quoteType': 'EQUITY',
#  'region': 'US',
#  'regularMarketChange': -0.2800064,
#  'regularMarketChangePercent': -0.23131466,
#  'regularMarketDayHigh': 121.65,
#  'regularMarketDayLow': 120.1,
#  'regularMarketDayRange': '120.1 - 121.65',
#  'regularMarketOpen': 121.64,
#  'regularMarketPreviousClose': 121.05,
#  'regularMarketPrice': 120.77,
#  'regularMarketTime': 1555444801,
#  'regularMarketVolume': 12315624,
#  'sharesOutstanding': 7672209920,
#  'shortName': 'Microsoft Corporation',
#  'sourceInterval': 15,
#  'symbol': 'MSFT',
#  'tradeable': True,
#  'trailingAnnualDividendRate': 1.76,
#  'trailingAnnualDividendYield': 0.014539446,
#  'trailingPE': 28.014381,
#  'twoHundredDayAverage': 109.11978,
#  'twoHundredDayAverageChange': 11.650215,
#  'twoHundredDayAverageChangePercent': 0.10676538}

# %%
import fix_yahoo_finance as yf

tsla = yf.Ticker("TSLA")

# get stock info
tsla.info

# get historical market data
hist = tsla.history(period="1d", interval = "1m", auto_adjust=True)
# Out:
# {'ask': 272.8,
#  'askSize': 9,
#  'averageDailyVolume10Day': 8331983,
#  'averageDailyVolume3Month': 8997312,
#  'bid': 272.35,
#  'bidSize': 8,
#  'bookValue': 28.524,
#  'currency': 'USD',
#  'earningsTimestamp': 1556136000,
#  'earningsTimestampEnd': 1557144000,
#  'earningsTimestampStart': 1556621940,
#  'epsForward': 7.31,
#  'epsTrailingTwelveMonths': -5.724,
#  'esgPopulated': False,
#  'exchange': 'NMS',
#  'exchangeDataDelayedBy': 0,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'fiftyDayAverage': 280.49527,
#  'fiftyDayAverageChange': -7.1352844,
#  'fiftyDayAverageChangePercent': -0.025438163,
#  'fiftyTwoWeekHigh': 387.46,
#  'fiftyTwoWeekHighChange': -114.100006,
#  'fiftyTwoWeekHighChangePercent': -0.29448202,
#  'fiftyTwoWeekLow': 247.77,
#  'fiftyTwoWeekLowChange': 25.589981,
#  'fiftyTwoWeekLowChangePercent': 0.10328119,
#  'fiftyTwoWeekRange': '247.77 - 387.46',
#  'financialCurrency': 'USD',
#  'forwardPE': 37.395348,
#  'fullExchangeName': 'NasdaqGS',
#  'gmtOffSetMilliseconds': -14400000,
#  'language': 'en-US',
#  'longName': 'Tesla, Inc.',
#  'market': 'us_market',
#  'marketCap': 47215009792,
#  'marketState': 'POSTPOST',
#  'messageBoardId': 'finmb_27444752',
#  'postMarketChange': -0.55999756,
#  'postMarketChangePercent': -0.20485719,
#  'postMarketPrice': 272.8,
#  'postMarketTime': 1555457957,
#  'priceHint': 2,
#  'priceToBook': 9.5835085,
#  'quoteSourceName': 'Delayed Quote',
#  'quoteType': 'EQUITY',
#  'region': 'US',
#  'regularMarketChange': 6.9799805,
#  'regularMarketChangePercent': 2.6203094,
#  'regularMarketDayHigh': 274.99,
#  'regularMarketDayLow': 264.72,
#  'regularMarketDayRange': '264.72 - 274.99',
#  'regularMarketOpen': 265.75,
#  'regularMarketPreviousClose': 266.38,
#  'regularMarketPrice': 273.36,
#  'regularMarketTime': 1555444801,
#  'regularMarketVolume': 7195130,
#  'sharesOutstanding': 172720992,
#  'shortName': 'Tesla, Inc.',
#  'sourceInterval': 15,
#  'symbol': 'TSLA',
#  'tradeable': True,
#  'twoHundredDayAverage': 309.14145,
#  'twoHundredDayAverageChange': -35.781464,
#  'twoHundredDayAverageChangePercent': -0.115744635}

# %%
hist
# Out:
#                              Open    High     Low   Close  Volume  Dividends  \
# Datetime
# 2019-04-16 09:30:00-04:00  265.75  266.34  264.72  265.89  197840          0
# 2019-04-16 09:31:00-04:00  266.23  267.20  266.05  266.56   37298          0
# 2019-04-16 09:32:00-04:00  266.14  268.48  266.14  267.85   72026          0
# 2019-04-16 09:33:00-04:00  267.98  268.00  267.65  267.80   23213          0
# 2019-04-16 09:34:00-04:00  267.84  268.46  267.02  268.40   47283          0
# 2019-04-16 09:35:00-04:00  268.40  268.50  267.85  268.17   47363          0
# 2019-04-16 09:36:00-04:00  268.27  268.63  268.06  268.55   30942          0
# 2019-04-16 09:37:00-04:00  268.60  268.68  267.80  267.82   21626          0
# 2019-04-16 09:38:00-04:00  267.96  268.18  267.50  267.80   20467          0
# 2019-04-16 15:48:00-04:00             0
# 2019-04-16 15:49:00-04:00             0
# 2019-04-16 15:50:00-04:00             0
# 2019-04-16 15:51:00-04:00             0
# 2019-04-16 15:52:00-04:00             0
# 2019-04-16 15:53:00-04:00             0
# 2019-04-16 15:54:00-04:00             0
# 2019-04-16 15:55:00-04:00             0
# 2019-04-16 15:56:00-04:00             0
# 2019-04-16 15:57:00-04:00             0
# 2019-04-16 15:58:00-04:00             0
# 2019-04-16 15:59:00-04:00             0
#
# [390 rows x 7 columns]

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="7d", interval = "1m", auto_adjust=True)

print("max period for 1m interval is 7d, max df shape is:", hist.shape)
# Out:
# max period for 1m interval is 7d, max df shape is: (2728, 7)

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="60d", interval = "2m", auto_adjust=True)

print("max period for 2m interval is 60d, max df shape is:", hist.shape)
# Out:
# max period for 2m interval is 60d, max df shape is: (6213, 7)

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="60d", interval = "5m", auto_adjust=True)

print("max period for 5m interval is 60d, max df shape is:", hist.shape)
# Out:
# max period for 5m interval is 60d, max df shape is: (4670, 7)

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="60d", interval = "15m", auto_adjust=True)

print("max period for 15m interval is 60d, max df shape is:", hist.shape)
# Out:
# max period for 15m interval is 60d, max df shape is: (830, 7)

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="730d", interval = "30m", auto_adjust=True)

print("max period for 30m interval is 730d, max df shape is:", hist.shape)
# Out:
# max period for 30m interval is 730d, max df shape is: (5089, 7)

# %%
idx = 230
hist.iloc[idx: idx+10,]
# Out:
#                              Open    High     Low   Close   Volume  Dividends  \
# Datetime
# 2016-07-08 15:30:00-04:00  217.46  217.58  216.78  216.78   416505          0
# 2016-07-11 09:30:00-04:00  219.99  226.78  219.52  224.24  2108871          0
# 2016-07-11 10:30:00-04:00  224.33  225.31  224.25  225.09   634571          0
# 2016-07-11 11:30:00-04:00  225.06  226.70  225.06  226.55   636909          0
# 2016-07-11 12:30:00-04:00  226.52  226.69  225.90  226.38   408297          0
# 2016-07-11 13:30:00-04:00  226.28  226.40  225.13  225.13   391608          0
# 2016-07-11 14:30:00-04:00  225.19  226.35  225.19  225.47   376931          0
# 2016-07-11 15:30:00-04:00  225.37  225.43  224.65  224.78   631711          0
# 2016-07-12 09:30:00-04:00  224.13  227.49  223.32  224.73  1256507          0
# 2016-07-12 10:30:00-04:00  224.69  226.06  224.69  226.00   419300          0
#
#                            Stock Splits
# Datetime
# 2016-07-08 15:30:00-04:00             0
# 2016-07-11 09:30:00-04:00             0
# 2016-07-11 10:30:00-04:00             0
# 2016-07-11 11:30:00-04:00             0
# 2016-07-11 12:30:00-04:00             0
# 2016-07-11 13:30:00-04:00             0
# 2016-07-11 14:30:00-04:00             0
# 2016-07-11 15:30:00-04:00             0
# 2016-07-12 09:30:00-04:00             0
# 2016-07-12 10:30:00-04:00             0

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="730d", interval = "60m", auto_adjust=True)

print("max period for 60m interval is 730d, max df shape is:", hist.shape)
# Out:
# max period for 60m interval is 730d, max df shape is: (5089, 7)

# %%
idx = 230
hist.iloc[idx: idx+10,]
# Out:
#                              Open    High     Low   Close   Volume  Dividends  \
# Datetime
# 2016-07-08 15:30:00-04:00  217.46  217.58  216.78  216.78   416505          0
# 2016-07-11 09:30:00-04:00  219.99  226.78  219.52  224.24  2108871          0
# 2016-07-11 10:30:00-04:00  224.33  225.31  224.25  225.09   634571          0
# 2016-07-11 11:30:00-04:00  225.06  226.70  225.06  226.55   636909          0
# 2016-07-11 12:30:00-04:00  226.52  226.69  225.90  226.38   408297          0
# 2016-07-11 13:30:00-04:00  226.28  226.40  225.13  225.13   391608          0
# 2016-07-11 14:30:00-04:00  225.19  226.35  225.19  225.47   376931          0
# 2016-07-11 15:30:00-04:00  225.37  225.43  224.65  224.78   631711          0
# 2016-07-12 09:30:00-04:00  224.13  227.49  223.32  224.73  1256507          0
# 2016-07-12 10:30:00-04:00  224.69  226.06  224.69  226.00   419300          0
#
#                            Stock Splits
# Datetime
# 2016-07-08 15:30:00-04:00             0
# 2016-07-11 09:30:00-04:00             0
# 2016-07-11 10:30:00-04:00             0
# 2016-07-11 11:30:00-04:00             0
# 2016-07-11 12:30:00-04:00             0
# 2016-07-11 13:30:00-04:00             0
# 2016-07-11 14:30:00-04:00             0
# 2016-07-11 15:30:00-04:00             0
# 2016-07-12 09:30:00-04:00             0
# 2016-07-12 10:30:00-04:00             0

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="60d", interval = "90m", auto_adjust=True)

print("max period for 90m interval is 60d, max df shape is:", hist.shape)
# Out:
# max period for 90m interval is 60d, max df shape is: (160, 7)

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="730d", interval = "1h", auto_adjust=True)

print("max period for 60m interval is 730d, max df shape is:", hist.shape)
# Out:
# max period for 60m interval is 730d, max df shape is: (5077, 7)

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="73000d", interval = "1d", auto_adjust=True)

print("max period for 60m interval is 730d, max df shape is:", hist.shape)
# Out:
# max period for 60m interval is 730d, max df shape is: (2215, 7)

# %%
intervals = ["1m", "2m", "5m", "15m", "30m", "60m", "90m", "1h", "1d"]
max_periods = ["7d", "60d", "60d", "60d", "730d", "730d", "60d", "730d", "Unlimited"]

# %%
intervals = [1, 2, 5, 15, 30, 60, 90]
max_periods = [7, 60, 60, 60, 730, 730, 60]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(15,6))
ax.plot(intervals, max_periods)
ax.set_xlabel("Intraday interval of data", fontsize=15)
ax.set_ylabel("Max number of days we can scrap", fontsize=15)
plt.show();

# %%
tsla = yf.Ticker("TSLA")

# get historical market data
hist = tsla.history(period="730d", interval = "60m", auto_adjust=True)

hist.to_csv('../../data/stock_price/TSLA_30m_2y.csv',encoding='utf-8')
