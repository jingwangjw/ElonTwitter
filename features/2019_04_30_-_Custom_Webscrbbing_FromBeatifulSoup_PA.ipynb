# %% [markdown]
# ## Custome webscrapping from Beautifulsoup.
#
# However, this method is too slow so I used another API instead.

# %%
import pandas as pd

import pickle
import os
import numpy as np
import pandas as pd


file =  os.listdir('../../data/Comment_to_Elon/')
donefile = [f.split('.')[0]+'.csv' for f in os.listdir('../../data/ProcessedComment/')]
file = pd.DataFrame(set(file) - set(donefile))
file
# Out:
#                       0
# 0   to_Elon_2018-10.csv
# 1   to_Elon_2018-01.csv
# 2   to_Elon_2018-02.csv
# 3   to_Elon_2015-02.csv
# 4   to_Elon_2017-02.csv
# 5   to_Elon_2013-03.csv
# 6   to_Elon_2012-04.csv
# 7   to_Elon_2015-05.csv
# 8   to_Elon_2013-07.csv
# 9   to_Elon_2014-07.csv
# 10  to_Elon_2018-06.csv
# 11  to_Elon_2013-02.csv
# 12  to_Elon_2014-02.csv
# 13  to_Elon_2013-01.csv
# 14  to_Elon_2014-06.csv
# 15  to_Elon_2012-07.csv
# 16  to_Elon_2014-10.csv
# 17  to_Elon_2017-07.csv
# 18  to_Elon_2018-04.csv
# 19  to_Elon_2019-01.csv
# 20  to_Elon_2017-06.csv
# 21  to_Elon_2018-12.csv
# 22  to_Elon_2018-05.csv
# 23  to_Elon_2012-11.csv
# 24  to_Elon_2012-02.csv
# 25  to_Elon_2018-07.csv
# 26  to_Elon_2015-03.csv
# 27  to_Elon_2014-12.csv
# 28  to_Elon_2016-07.csv
# 29  to_Elon_2015-11.csv
# ..                  ...
# 35  to_Elon_2018-03.csv
# 36  to_Elon_2017-12.csv
# 37  to_Elon_2013-05.csv
# 38  to_Elon_2012-12.csv
# 39  to_Elon_2012-01.csv
# 40  to_Elon_2013-08.csv
# ...

# %%
# pd.set_option('display.expand_frame_repr',0)

# %%
# "Sigue sumando altura" @ elonmusk: Rocket flight to 744m, hover &amp; return to launch pad (shot from hexacopter) http://youtu.be/9ZDkItO-0a4 "";;@;;"389501516996165632";https://twitter.com/oscaralcalde12/status/389501516996165632;;True
# "@ elonmusk's Grasshopper rocket makes its highest leap to date http://www.theverge.com/2013/10/13/4834606/elon-musks-grasshopper-rocket-makes-its-highest-leap-to-date …";;@;;"389504531966345217";https://twitter.com/davidiohmbra/status/389504531966345217;;False

# %%
def getoriginID(http,i):
    import time
    
    if(i%1000 == 0): 
        print(i)
    if(i%100 == 0): 
        time.sleep(3)
    if(http.isreply == True):
#         print(http.permalink)
        import requests
        from socket import error as SocketError
#     headers = {
#     'user-agent': 'curl/7.54.0'}
        try:
            page = requests.get(http.permalink, timeout=5)
            if(page.status_code == 200):

                from bs4 import BeautifulSoup as bs
                from bs4 import SoupStrainer
                strainer = SoupStrainer('form', attrs={'id': 'form1'})
                soup = bs(page.content, 'lxml', parse_only=strainer)

                lst = soup.find_all(class_="js-stream-item stream-item stream-item")
                if len(lst) > 0: 
                    id = lst[0]['data-item-id']
                    return(id)
                else:
                    return('')
            else:
                return('timeout')
                print('timeout ', http.permalink)
            #     for tag2 in soup.find_all(class_="js-stream-item stream-item stream-item"):
    #             print(tag)
        except SocketError as e:
            print(e)
            return('')
    else:
#         print('')
        return('')

# %%
for i,f in file.iterrows():
    print('----------------------',f[0])
    month = int(f[0].split('-')[1].split('.')[0])
    
    comment = pd.read_csv('../../data/Comment_to_Elon/'+f[0], sep=';', error_bad_lines=False)

    comment.date = pd.to_datetime(comment.date)
    comment=comment[[True if c.isreply else False for i,c in comment.iterrows()]]
    comment = comment[[i.month ==month for i in comment.date]]

    comment['origin'] = [ getoriginID(c,j) for j,c in comment.iterrows()]

    with open('../../data/ProcessedComment/'+f[0].split('.')[0]+'.pickle', 'wb') as handle:
        pickle.dump(comment, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# ---------------------- to_Elon_2018-10.csv
# b'Skipping line 1407: expected 12 fields, saw 13\nSkipping line 2628: expected 12 fields, saw 14\nSkipping line 4383: expected 12 fields, saw 13\nSkipping line 6029: expected 12 fields, saw 13\nSkipping line 6316: expected 12 fields, saw 14\nSkipping line 12115: expected 12 fields, saw 13\nSkipping line 15082: expected 12 fields, saw 14\nSkipping line 15156: expected 12 fields, saw 13\nSkipping line 21168: expected 12 fields, saw 13\nSkipping line 26724: expected 12 fields, saw 13\nSkipping line 41441: expected 12 fields, saw 13\nSkipping line 48260: expected 12 fields, saw 13\n'
# ...
