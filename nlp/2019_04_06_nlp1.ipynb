# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import os
# os.listdir('../../data/twitter')

pd.set_option('display.max_colwidth', -1)

# %%
elon = pd.read_csv('../../data/twitter/elon.csv', sep = ";", dtype={'id': object})

# %%
elon.head()
# Out:
#    username              date  retweets  favorites  \
# 0  elonmusk  2019-04-02 20:38  993       9263
# 1  elonmusk  2019-04-02 20:16  7238      55271
# 2  elonmusk  2019-04-02 19:40  368       9159
# 3  elonmusk  2019-04-02 09:24  1317      6176
# 4  elonmusk  2019-04-02 09:21  1557      26925
#
#                                                                                                                       text  \
# 0  Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1  Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2  Uh oh
# 3  Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4  Yup https:// twitter.com/nasa/status/11 12860196043452417 …
#
#    geo mentions hashtags                   id  \
# 0  NaN  NaN      NaN      1113178951403180032
# 1  NaN  NaN      NaN      1113173498384441344
# 2  NaN  NaN      NaN      1113164389929160706
# 3  NaN  NaN      NaN      1113009339743100929
# ...

# %%
elon.shape
# Out:
# (6124, 10)

# %%
elon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6124 entries, 0 to 6123
# Data columns (total 10 columns):
# username     6124 non-null object
# date         6124 non-null object
# retweets     6124 non-null int64
# favorites    6124 non-null int64
# text         6091 non-null object
# geo          9 non-null object
# mentions     807 non-null object
# hashtags     61 non-null object
# id           6115 non-null object
# permalink    6115 non-null object
# dtypes: int64(2), object(8)
# memory usage: 478.5+ KB

# %%
# number of days
len(pd.to_datetime(elon.date).dt.date.unique())
# len(elon.date.unique())
# Out:
# 1338

# %%
# number of unique twitters
len(elon.id.unique())
# Out:
# 6116

# %%
elon.head()
# Out:
#    username              date  retweets  favorites  \
# 0  elonmusk  2019-04-02 20:38  993       9263
# 1  elonmusk  2019-04-02 20:16  7238      55271
# 2  elonmusk  2019-04-02 19:40  368       9159
# 3  elonmusk  2019-04-02 09:24  1317      6176
# 4  elonmusk  2019-04-02 09:21  1557      26925
#
#                                                                                                                       text  \
# 0  Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1  Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2  Uh oh
# 3  Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4  Yup https:// twitter.com/nasa/status/11 12860196043452417 …
#
#    geo mentions hashtags                   id  \
# 0  NaN  NaN      NaN      1113178951403180032
# 1  NaN  NaN      NaN      1113173498384441344
# 2  NaN  NaN      NaN      1113164389929160706
# 3  NaN  NaN      NaN      1113009339743100929
# ...

# %%
#elon[-elon.geo.isna()]

# %%
elon.head()
# Out:
#    username              date  retweets  favorites  \
# 0  elonmusk  2019-04-02 20:38  993       9263
# 1  elonmusk  2019-04-02 20:16  7238      55271
# 2  elonmusk  2019-04-02 19:40  368       9159
# 3  elonmusk  2019-04-02 09:24  1317      6176
# 4  elonmusk  2019-04-02 09:21  1557      26925
#
#                                                                                                                       text  \
# 0  Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1  Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2  Uh oh
# 3  Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4  Yup https:// twitter.com/nasa/status/11 12860196043452417 …
#
#    geo mentions hashtags                   id  \
# 0  NaN  NaN      NaN      1113178951403180032
# 1  NaN  NaN      NaN      1113173498384441344
# 2  NaN  NaN      NaN      1113164389929160706
# 3  NaN  NaN      NaN      1113009339743100929
# ...

# %%
elon[elon.id.isna()].id = elon[elon.id.isna()].geo.str[37:]
# Out:
# /jet/var/python/lib/python3.6/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
a = (str('https://twitter.com/elonmusk/status/1041108570740158464'))

# %%
elon[elon.id.isna()]
# Out:
#       username              date  retweets  favorites  \
# 1415  elonmusk  2018-09-15 23:36  2398      19545
# 4056  elonmusk  2017-01-25 00:43  2241      9398
# 4057  elonmusk  2017-01-25 00:41  241       1244
# 4985  elonmusk  2015-10-02 22:43  12        67
# 5290  elonmusk  2014-06-17 04:32  350       514
# 5365  elonmusk  2014-03-11 02:15  442       473
# 5714  elonmusk  2013-03-31 00:54  48        19
# 5818  elonmusk  2012-12-19 01:20  93        68
# 5927  elonmusk  2012-07-12 14:50  41        12
#
#                                                                                                                                                                                                                                                  text  \
# 1415  Tesla owners can grant free Supercharging for life to a friend who buys S/3/X. Ends tomorrow night. http:// tesla.com/support/referr al-program … ";;;;1041108570740158464"
# ...

# %%
#elon[elon.id.duplicated()]

# %%
df_elon = elon[-elon.id.isna()]

# %%
df_elon.shape
# Out:
# (6115, 10)

# %%
df_elon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6115 entries, 0 to 6123
# Data columns (total 10 columns):
# username     6115 non-null object
# date         6115 non-null object
# retweets     6115 non-null int64
# favorites    6115 non-null int64
# text         6082 non-null object
# geo          0 non-null object
# mentions     807 non-null object
# hashtags     61 non-null object
# id           6115 non-null object
# permalink    6115 non-null object
# dtypes: int64(2), object(8)
# memory usage: 525.5+ KB

# %%
df_elon[['date','text','permalink']][0:10]
# Out:
#                date  \
# 0  2019-04-02 20:38
# 1  2019-04-02 20:16
# 2  2019-04-02 19:40
# 3  2019-04-02 09:24
# 4  2019-04-02 09:21
# 5  2019-04-02 08:50
# 6  2019-04-02 08:45
# 7  2019-04-02 01:00
# 8  2019-04-01 22:45
# 9  2019-04-01 22:40
#
#                                                                                                                       text  \
# 0  Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1  Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2  Uh oh
# 3  Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4  Yup https:// twitter.com/nasa/status/11 12860196043452417 …
# 5  Some challenges with ice formation in the cryogenic propellant prevalves. Hopefully overcome soon.
# 6  What could possibly go wrong?
# 7  No
# 8  You’re so right. Working on it!
# 9  That car seemed so advanced when I watched that show as a kid! Knight Industries Two Thousand
#
# ...

# %%
df_elon[10:30]
# Out:
#     username              date  retweets  favorites  \
# 10  elonmusk  2019-04-01 22:13  28        1061
# 11  elonmusk  2019-04-01 22:12  22        937
# 12  elonmusk  2019-04-01 22:11  413       8636
# 13  elonmusk  2019-04-01 19:39  31        856
# 14  elonmusk  2019-04-01 19:25  20        512
# 15  elonmusk  2019-04-01 19:24  603       13092
# 16  elonmusk  2019-04-01 19:16  39        1466
# 17  elonmusk  2019-04-01 17:59  2967      36328
# 18  elonmusk  2019-04-01 03:54  19        705
# 19  elonmusk  2019-04-01 03:24  43        986
# 20  elonmusk  2019-04-01 02:21  45        2999
#                                                                                                                       text  \
# 0  Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1  Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2  Uh oh
# 3  Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4  Yup https:// twitter.com/nasa/status/11 12860196043452417 …
#
#    geo mentions hashtags                   id  \
# 0  NaN  NaN      NaN      1113178951403180032
# 1  NaN  NaN      NaN      1113173498384441344
# 2  NaN  NaN      NaN      1113164389929160706
# 3  NaN  NaN      NaN      1113009339743100929
# ...

# %%
import datetime as dt
df_elon['date']=pd.to_datetime(df_elon['date'])

df_elon[df_elon['date'] > dt.datetime(2018,3,1)]
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       username                date  retweets  favorites  \
# 0     elonmusk 2019-04-02 20:38:00  993       9263
# 1     elonmusk 2019-04-02 20:16:00  7238      55271
# 2     elonmusk 2019-04-02 19:40:00  368       9159
# 3     elonmusk 2019-04-02 09:24:00  1317      6176
# 4     elonmusk 2019-04-02 09:21:00  1557      26925
# 5     elonmusk 2019-04-02 08:50:00  61        941
# 6     elonmusk 2019-04-02 08:45:00  90        1885
# 7     elonmusk 2019-04-02 01:00:00  586       17330
# 8     elonmusk 2019-04-01 22:45:00  30        764
# 9     elonmusk 2019-04-01 22:40:00  37        828
# 10    elonmusk 2019-04-01 22:13:00  28        1061
# ...

# %%
df_elon['day'] = df_elon[df_elon['date'] > dt.datetime(2018,3,1)]['date'].dt.date
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_elon['hour'] = df_elon[df_elon['date'] > dt.datetime(2018,3,1)]['date'].dt.hour
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
counts=df_elon.groupby(['day','hour']).size().sort_values(ascending=False)

# %%
counts
# Out:
# day         hour
# 2018-05-20  6.0     16
# 2018-05-23  19.0    14
# 2018-12-19  19.0    13
# 2018-05-27  1.0     12
# 2019-02-22  2.0     12
# 2018-10-27  3.0     12
# 2019-03-17  20.0    11
# 2019-02-21  18.0    10
# 2019-03-12  5.0     10
# 2018-06-17  18.0    10
# 2018-03-22  10.0    10
# 2018-06-17  17.0    10
# 2018-12-19  3.0     10
# 2018-10-27  1.0     10
# 2018-05-26  22.0    10
# 2019-02-11  2.0     9
# 2019-01-05  15.0    9
# 2018-07-21  3.0     9
# 2018-12-22  22.0    9
# 2018-09-18  18.0    9
# 2018-07-08  18.0    9
# 2019-02-11  3.0     8
# 2018-11-15  17.0    8
# 2018-11-19  14.0    8
# 2018-06-25  3.0     8
# 2018-08-01  18.0    8
# 2019-01-09  22.0    8
# 2018-08-01  20.0    8
# 2018-05-25  18.0    8
# 2018-06-29  19.0    8
#                    ..
# 2018-07-10  23.0    1
# 2018-12-23  5.0     1
#             15.0    1
# 2018-07-10  12.0    1
#             7.0     1
# 2018-07-09  22.0    1
#             19.0    1
#             1.0     1
# 2018-07-12  12.0    1
# ...

# %%
plt.hist(counts.values)
# Out:
# (array([893., 164., 121.,  33.,  30.,   6.,   9.,   3.,   2.,   1.]),
#  array([ 1. ,  2.5,  4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. ]),
#  <a list of 10 Patch objects>)

# %%
df_elon.groupby('day').size().hist()

# %%
stock_tsla = pd.read_csv('../../data/stock_price/TSLA.csv')

# %%
stock_tsla.shape
# Out:
# (2204, 7)
