# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
file1 = open("../../data/features/2019_04_30_TSLA_y_02_yishuang.pickle",'rb')
tsla = pickle.load(file1, encoding='utf-8')

file2 = open("../../data/features/2019_04_23_all_features.pickle",'rb')
elon = pickle.load(file2, encoding='utf-8')

# %%
a = tsla['Volume'][:-1].tolist()

# %%
len(a)
# Out:
# 5088

# %%
b = np.insert(a, 0, 0)

# %%
tsla['Volume_prior'] = b

# %%
a = tsla['Percentage_Volume'][:-1].tolist()
b = np.insert(a, 0, 0)
tsla['Volume_perc_prior'] = b

# %%
tsla
# Out:
#                  Start_Datetime               End_Datetime  Trading_Hour  \
# 0     2016-05-23 13:30:00+00:00  2016-05-23 14:30:00+00:00             1
# 1     2016-05-23 14:30:00+00:00  2016-05-23 15:30:00+00:00             2
# 2     2016-05-23 15:30:00+00:00  2016-05-23 16:30:00+00:00             3
# 3     2016-05-23 16:30:00+00:00  2016-05-23 17:30:00+00:00             4
# 4     2016-05-23 17:30:00+00:00  2016-05-23 18:30:00+00:00             5
# 5     2016-05-23 18:30:00+00:00  2016-05-23 19:30:00+00:00             6
# 6     2016-05-23 19:30:00+00:00  2016-05-23 20:00:00+00:00             7
# 7     2016-05-24 13:30:00+00:00  2016-05-24 14:30:00+00:00             1
# 8     2016-05-24 14:30:00+00:00  2016-05-24 15:30:00+00:00             2
# 9     2016-05-24 15:30:00+00:00  2016-05-24 16:30:00+00:00             3
# 10    2016-05-24 16:30:00+00:00  2016-05-24 17:30:00+00:00             4
# 11    2016-05-24 17:30:00+00:00  2016-05-24 18:30:00+00:00             5
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))

y1 = tsla["Percentage_Volume"]
y2 = tsla["Volume_perc_prior"]

ax.plot(y1, color = 'cornflowerblue')
ax.plot(y2, color = 'orange', linestyle='--', linewidth = 0.5)
#ax.plot(y1,color='green', linestyle=':', label='line 1',linewidth = 2.5)
#ax.plot(x,y*2,color='orange', linestyle='--', label = 'line 2')
#ax.plot(x,y+4,color='black',marker='o', label = 'line 3')
#plt.tight_layout(pad=0.4, h_pad=5.0)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))

y1 = tsla["Percentage_Volume"]
y2 = tsla["Rolling_perc_volume"]

ax.plot(y1)
ax.plot(y2, linestyle='--', linewidth = 0.5)
#ax.plot(y1,color='green', linestyle=':', label='line 1',linewidth = 2.5)
#ax.plot(x,y*2,color='orange', linestyle='--', label = 'line 2')
#ax.plot(x,y+4,color='black',marker='o', label = 'line 3')
#plt.tight_layout(pad=0.4, h_pad=5.0)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))

y1 = tsla["Volume"]
y2 = tsla["Rolling_volume"]

ax.plot(y1)
ax.plot(y2, linestyle='--', linewidth = 0.5)
#ax.plot(y1,color='green', linestyle=':', label='line 1',linewidth = 2.5)
#ax.plot(x,y*2,color='orange', linestyle='--', label = 'line 2')
#ax.plot(x,y+4,color='black',marker='o', label = 'line 3')
#plt.tight_layout(pad=0.4, h_pad=5.0)
plt.show()
