# %%
import pandas as pd
stock = pd.read_csv("../../data/stock_price/TSLA.csv")

# %%
stock.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
# the column 'close' is the same as 'adj close'
stock[stock['Close'] != stock ['Adj Close']].shape
# Out:
# (0, 7)

# %%
stock.drop('Adj Close', axis = 1, inplace = True)

# %%
elon = pd.read_csv("../../data/twitter/elon_clean.csv")

# %%
elon.head()
# Out:
#    username              date  retweets  favorites  \
# 0  elonmusk  2019-04-02 20:38       993       9263
# 1  elonmusk  2019-04-02 20:16      7238      55271
# 2  elonmusk  2019-04-02 19:40       368       9159
# 3  elonmusk  2019-04-02 09:24      1317       6176
# 4  elonmusk  2019-04-02 09:21      1557      26925
#
#                                                 text mentions hashtags  \
# 0  Dogecoin value may vary https://www. theonion....      NaN      NaN
# 1           Dogecoin rulz pic.twitter.com/flWWUgAgLU      NaN      NaN
# 2                                              Uh oh      NaN      NaN
# 3  Dogecoin might be my fav cryptocurrency. It’s ...      NaN      NaN
# 4  Yup https:// twitter.com/nasa/status/11 128601...      NaN      NaN
#
#                                            permalink
# 0  https://twitter.com/elonmusk/status/1113178951...
# 1  https://twitter.com/elonmusk/status/1113173498...
# 2  https://twitter.com/elonmusk/status/1113164389...
# ...

# %%
elon_date = elon['date'].str[:-6].unique().tolist()

# %%
elon_date
# Out:
# ['2019-04-02',
#  '2019-04-01',
#  '2019-03-31',
#  '2019-03-30',
#  '2019-03-29',
#  '2019-03-28',
#  '2019-03-27',
#  '2019-03-26',
#  '2019-03-25',
#  '2019-03-24',
#  '2019-03-22',
#  '2019-03-21',
#  '2019-03-20',
#  '2019-03-17',
#  '2019-03-16',
#  '2019-03-15',
#  '2019-03-14',
#  '2019-03-13',
#  '2019-03-12',
#  '2019-03-11',
#  '2019-03-09',
#  '2019-03-08',
#  '2019-03-07',
#  '2019-03-06',
#  '2019-03-05',
#  '2019-03-04',
#  '2019-03-03',
#  '2019-03-02',
#  '2019-03-01',
#  '2019-02-28',
#  '2019-02-27',
#  '2019-02-26',
#  '2019-02-25',
#  '2019-02-23',
#  '2019-02-22',
#  '2019-02-21',
#  '2019-02-20',
#  '2019-02-19',
#  '2019-02-18',
#  '2019-02-17',
#  '2019-02-16',
#  '2019-02-15',
#  '2019-02-14',
#  '2019-02-13',
#  '2019-02-12',
#  '2019-02-11',
#  '2019-02-10',
#  '2019-02-09',
#  '2019-02-08',
#  '2019-02-07',
#  '2019-02-06',
#  '2019-02-05',
#  '2019-02-04',
#  '2019-02-03',
#  '2019-02-02',
#  '2019-02-01',
#  '2019-01-31',
#  '2019-01-30',
# ...

# %%
# direction
# delta of absolute value 
# moving average 
# moving std
# def stock_output(date, t, dataframe)

# %%
stock.head()
# Out:
#          Date       Open   High        Low      Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001   6866900
