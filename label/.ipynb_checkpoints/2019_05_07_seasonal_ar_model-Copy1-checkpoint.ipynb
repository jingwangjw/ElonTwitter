# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
file1 = open("../../data/features/2019_05_15_TSLA_y_05_yishuang.pickle",'rb')
tsla = pickle.load(file1, encoding='utf-8')

# %% [markdown]
# # balance trading hour

# %%
# we don't need this any more

# %%
tsla.groupby(['Trading_Hour'])['Trading_Hour'].count()

# %%
tsla["Start_Datetime"] = pd.to_datetime(tsla["Start_Datetime"])

# %%
dates = set()
for i in range(8):
    date = tsla[tsla['Trading_Hour'] == i]["Start_Datetime"].dt.date.tolist()
    date_set = set(date)
    if len(dates) == 0:
        dates = date_set
    else:
        dates = date_set & dates

# %%
len(dates)

# %%
tsla['Date'] = tsla['Start_Datetime'].dt.date

# %%
tsla_new = tsla[tsla['Date'].isin(dates)]

# %%
tsla_new.groupby(['Trading_Hour'])['Trading_Hour'].count()

# %%
tsla_new.reset_index(drop = True, inplace = True)

# %%
tsla_new.head(10)

# %%
tsla_new.drop(['Percentage_Volume', 'Rolling_volume', 'Rolling_perc_volume', 'Res_Perc_vol', 'Res_vol'], axis = 1, inplace = True)

# %%
tsla_new.head()

# %% [markdown]
# # design AR features

# %%
tsla.head(10)
# Out:
#         Date  Daily_volume                   Datetime  Hour_volume  \
# 0 2016-05-24       3013800  2016-05-24 13:30:00+00:00    1088736.0
# 1 2016-05-24       3013800  2016-05-24 14:30:00+00:00     565361.0
# 2 2016-05-24       3013800  2016-05-24 15:30:00+00:00     282089.0
# 3 2016-05-24       3013800  2016-05-24 16:30:00+00:00     267042.0
# 4 2016-05-24       3013800  2016-05-24 17:30:00+00:00     145856.0
# 5 2016-05-24       3013800  2016-05-24 18:30:00+00:00     266077.0
# 6 2016-05-24       3013800  2016-05-24 19:30:00+00:00     324737.0
# 7 2016-05-25       3126800  2016-05-25 13:30:00+00:00     772125.0
# 8 2016-05-25       3126800  2016-05-25 14:30:00+00:00     706932.0
# 9 2016-05-25       3126800  2016-05-25 15:30:00+00:00     271832.0
#
#    Trading_Hour  Roll_volume  Volume_perc
# 0             1    4155755.0     0.261983
# 1             2    4042448.0     0.139856
# 2             3    3723060.0     0.075768
# 3             4    3550596.0     0.075210
# 4             5    3181963.0     0.045838
# 5             6    3115184.0     0.085413
# 6             7    2939898.0     0.110459
# 7             1    2623287.0     0.294335
# 8             2    2764858.0     0.255685
# 9             3    2754601.0     0.098683

# %%
tsla['Perc_shift_1'] = tsla['Volume_perc'].shift(1)
tsla['Perc_shift_2'] = tsla['Volume_perc'].shift(2)
tsla['Perc_shift_3'] = tsla['Volume_perc'].shift(3)
tsla['Perc_shift_4'] = tsla['Volume_perc'].shift(4)
tsla['Perc_shift_5'] = tsla['Volume_perc'].shift(5)
tsla['Perc_shift_6'] = tsla['Volume_perc'].shift(6)
tsla['Perc_shift_7'] = tsla['Volume_perc'].shift(7)

# %%
tsla.dropna(inplace = True)

# %%
tsla.head()
# Out:
#          Date  Daily_volume                   Datetime  Hour_volume  \
# 13 2016-05-25       3126800  2016-05-25 19:30:00+00:00     329208.0
# 14 2016-05-26       4064000  2016-05-26 13:30:00+00:00    1020114.0
# 15 2016-05-26       4064000  2016-05-26 14:30:00+00:00     887124.0
# 16 2016-05-26       4064000  2016-05-26 15:30:00+00:00     506720.0
# 17 2016-05-26       4064000  2016-05-26 16:30:00+00:00     261914.0
#
#     Trading_Hour  Roll_volume  Volume_perc  Perc_shift_1  Perc_shift_2  \
# 13             7    3074533.0     0.107076      0.086303      0.143450
# 14             1    3322522.0     0.307030      0.107076      0.086303
# 15             2    3502714.0     0.253268      0.307030      0.107076
# 16             3    3737602.0     0.135574      0.253268      0.307030
# 17             4    3710598.0     0.070585      0.135574      0.253268
#
#     Perc_shift_3  Perc_shift_4  Perc_shift_5  Perc_shift_6  Perc_shift_7
# 13      0.104059      0.098683      0.255685      0.294335      0.110459
# 14      0.143450      0.104059      0.098683      0.255685      0.294335
# 15      0.086303      0.143450      0.104059      0.098683      0.255685
# 16      0.107076      0.086303      0.143450      0.104059      0.098683
# 17      0.307030      0.107076      0.086303      0.143450      0.104059

# %%
ar = tsla[['Volume_perc','Perc_shift_1', 'Perc_shift_2', 'Perc_shift_3', 'Perc_shift_4', 'Perc_shift_5', 'Perc_shift_6', 'Perc_shift_7']]

# %%
ar.reset_index(drop = True, inplace = True)

# %%
ar.corr()
# Out:
#                Volume_perc  Perc_shift_1  Perc_shift_2  Perc_shift_3  \
# Volume_perc   1.000000e+00  6.741662e-05 -6.586904e-05 -4.315042e-07
# Perc_shift_1  6.741662e-05  1.000000e+00  6.741520e-05 -6.587117e-05
# Perc_shift_2 -6.586904e-05  6.741520e-05  1.000000e+00  6.741467e-05
# Perc_shift_3 -4.315042e-07 -6.587117e-05  6.741467e-05  1.000000e+00
# Perc_shift_4 -2.515599e-04 -4.319536e-07 -6.587035e-05  6.741466e-05
# Perc_shift_5 -8.491645e-05 -2.515589e-04 -4.259695e-07 -6.586778e-05
# Perc_shift_6 -9.670492e-05 -8.491832e-05 -2.515544e-04 -4.256593e-07
# Perc_shift_7 -4.348848e-05 -9.671485e-05 -8.492562e-05 -2.515632e-04
#
#               Perc_shift_4  Perc_shift_5  Perc_shift_6  Perc_shift_7
# Volume_perc  -2.515599e-04 -8.491645e-05 -9.670492e-05 -4.348848e-05
# Perc_shift_1 -4.319536e-07 -2.515589e-04 -8.491832e-05 -9.671485e-05
# Perc_shift_2 -6.587035e-05 -4.259695e-07 -2.515544e-04 -8.492562e-05
# Perc_shift_3  6.741466e-05 -6.586778e-05 -4.256593e-07 -2.515632e-04
# Perc_shift_4  1.000000e+00  6.741797e-05 -6.586494e-05 -4.284757e-07
# Perc_shift_5  6.741797e-05  1.000000e+00  6.743486e-05 -6.586720e-05
# Perc_shift_6 -6.586494e-05  6.743486e-05  1.000000e+00  6.742206e-05
# Perc_shift_7 -4.284757e-07 -6.586720e-05  6.742206e-05  1.000000e+00

# %%
Trading_Hour = pd.get_dummies(data= tsla['Trading_Hour'], drop_first = True)

# %%
tsla_new = pd.concat([Trading_Hour, tsla], axis = 1)

# %%
tsla_new.head()
# Out:
#     2  3  4  5  6  7       Date  Daily_volume                   Datetime  \
# 13  0  0  0  0  0  1 2016-05-25       3126800  2016-05-25 19:30:00+00:00
# 14  0  0  0  0  0  0 2016-05-26       4064000  2016-05-26 13:30:00+00:00
# 15  1  0  0  0  0  0 2016-05-26       4064000  2016-05-26 14:30:00+00:00
# 16  0  1  0  0  0  0 2016-05-26       4064000  2016-05-26 15:30:00+00:00
# 17  0  0  1  0  0  0 2016-05-26       4064000  2016-05-26 16:30:00+00:00
#
#     Hour_volume  Trading_Hour  Roll_volume  Volume_perc  Perc_shift_1  \
# 13     329208.0             7    3074533.0     0.107076      0.086303
# 14    1020114.0             1    3322522.0     0.307030      0.107076
# 15     887124.0             2    3502714.0     0.253268      0.307030
# 16     506720.0             3    3737602.0     0.135574      0.253268
# 17     261914.0             4    3710598.0     0.070585      0.135574
#
#     Perc_shift_2  Perc_shift_3  Perc_shift_4  Perc_shift_5  Perc_shift_6  \
# 13      0.143450      0.104059      0.098683      0.255685      0.294335
# 14      0.086303      0.143450      0.104059      0.098683      0.255685
# 15      0.107076      0.086303      0.143450      0.104059      0.098683
# 16      0.307030      0.107076      0.086303      0.143450      0.104059
# 17      0.253268      0.307030      0.107076      0.086303      0.143450
#
#     Perc_shift_7
# 13      0.110459
# 14      0.294335
# 15      0.255685
# 16      0.098683
# 17      0.104059

# %%
tsla_new.rename(columns = {2:'Hour2', 3: 'Hour3', 4: 'Hour4', 5:'Hour5', 6:'Hour6', 7:'Hour7'}, inplace = True)

# %%
tsla_new.drop(['Trading_Hour'], axis = 1, inplace = True)

# %%
tsla_new.head()
# Out:
#     Hour2  Hour3  Hour4  Hour5  Hour6  Hour7       Date  Daily_volume  \
# 13      0      0      0      0      0      1 2016-05-25       3126800
# 14      0      0      0      0      0      0 2016-05-26       4064000
# 15      1      0      0      0      0      0 2016-05-26       4064000
# 16      0      1      0      0      0      0 2016-05-26       4064000
# 17      0      0      1      0      0      0 2016-05-26       4064000
#
#                      Datetime  Hour_volume  Roll_volume  Volume_perc  \
# 13  2016-05-25 19:30:00+00:00     329208.0    3074533.0     0.107076
# 14  2016-05-26 13:30:00+00:00    1020114.0    3322522.0     0.307030
# 15  2016-05-26 14:30:00+00:00     887124.0    3502714.0     0.253268
# 16  2016-05-26 15:30:00+00:00     506720.0    3737602.0     0.135574
# 17  2016-05-26 16:30:00+00:00     261914.0    3710598.0     0.070585
#
#     Perc_shift_1  Perc_shift_2  Perc_shift_3  Perc_shift_4  Perc_shift_5  \
# 13      0.086303      0.143450      0.104059      0.098683      0.255685
# 14      0.107076      0.086303      0.143450      0.104059      0.098683
# 15      0.307030      0.107076      0.086303      0.143450      0.104059
# 16      0.253268      0.307030      0.107076      0.086303      0.143450
# 17      0.135574      0.253268      0.307030      0.107076      0.086303
#
#     Perc_shift_6  Perc_shift_7
# 13      0.294335      0.110459
# 14      0.255685      0.294335
# 15      0.098683      0.255685
# 16      0.104059      0.098683
# 17      0.143450      0.104059

# %%
tsla_new.reset_index(inplace = True, drop = True)

# %%
from pandas.plotting import autocorrelation_plot

# %%
plt.figure(figsize=(20,10))
autocorrelation_plot(ar['Volume_perc'])

# %%
# !pip install statsmodels

# %%
from statsmodels.tsa.ar_model import AR

# %%
import statsmodels.api as sm

# %%
X = tsla_new[["Perc_shift_1", "Perc_shift_2", "Perc_shift_3", "Perc_shift_4", "Perc_shift_5", "Perc_shift_6", "Perc_shift_7",
         "Hour2", "Hour3", "Hour4", "Hour5", "Hour6", "Hour7"]]
y = tsla_new["Volume_perc"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Volume_perc   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1208
# Date:                Thu, 16 May 2019   Prob (F-statistic):               1.00
# Time:                        05:48:48   Log-Likelihood:                -22615.
# No. Observations:                5013   AIC:                         4.526e+04
# Df Residuals:                    5000   BIC:                         4.534e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Perc_shift_1     0.0002      0.014      0.012      0.990      -0.028       0.028
# Perc_shift_2  -9.39e-06      0.014     -0.001      0.999      -0.028       0.028
# Perc_shift_3 -1.262e-05      0.014     -0.001      0.999      -0.028       0.028
# Perc_shift_4    -0.0003      0.014     -0.019      0.985      -0.028       0.027
# Perc_shift_5 -6.421e-05      0.014     -0.005      0.996      -0.028       0.028
# Perc_shift_6  9.729e-05      0.014      0.007      0.995      -0.028       0.028
# Perc_shift_7    -0.0004      0.014     -0.025      0.980      -0.028       0.027
# Hour2            0.1624      0.824      0.197      0.844      -1.454       1.779
# Hour3            0.1226      0.824      0.149      0.882      -1.494       1.739
# Hour4            0.0011      0.824      0.001      0.999      -1.615       1.617
# Hour5            0.0982      0.824      0.119      0.905      -1.518       1.714
# Hour6            0.5246      0.824      0.636      0.525      -1.092       2.141
# Hour7           -0.8604      0.824     -1.044      0.296      -2.475       0.755
# ==============================================================================
# Omnibus:                    10171.513   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        865366166.403
# Skew:                          15.217   Prob(JB):                         0.00
# Kurtosis:                    2038.205   Cond. No.                         58.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig, ax = plt.subplots(figsize=(20,10))

y1 = tsla["Percentage_Volume"]

ax.plot(y1, color = 'cornflowerblue')


plt.show()
