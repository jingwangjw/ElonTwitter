# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint as sp_randint
import pickle
% matplotlib inline
# machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
file = open("../../data/features/2019_05_15_features_finally.pickle",'rb')
df = pickle.load(file, encoding='utf-8')
df.columns
# Out:
# Index(['id', 'Datetime', 'text', 'sentiment', 'subjectivity', 'isreply',
#        'year', 'month', 'day', 'date', 'DayofWeek', 'Weekend', 'Time',
#        'BinaryTrading', 'DayDistance', 'gtrend', 'CommentSentimental',
#        'CommentSubjectivity', 'countComment', 'posCommentSum', 'negCommentSum',
#        'CommentSD', 'posCommentSD', 'negCommentSD', 'negCommentPercent',
#        'posCommentPercent', 'Volume_perc', 'Trading_Hour'],
#       dtype='object')

# %%
df.shape
# Out:
# (749, 28)

# %%
print(df.isnull().sum())
# Out:
# id                      0
# Datetime                0
# text                    0
# sentiment               0
# subjectivity            0
# isreply                 0
# year                    0
# month                   0
# day                     0
# date                    0
# DayofWeek               0
# Weekend                 0
# Time                    0
# BinaryTrading           0
# DayDistance             0
# gtrend                  0
# CommentSentimental      0
# CommentSubjectivity     0
# countComment            0
# posCommentSum           0
# negCommentSum           0
# CommentSD               0
# posCommentSD            0
# negCommentSD            0
# negCommentPercent       0
# posCommentPercent       0
# Volume_perc            29
# Trading_Hour           29
# dtype: int64

# %%
df = df[df['Volume_perc'].isnull() == False]

# %%
df.shape
# Out:
# (720, 28)

# %%
df
# Out:
#                       id                  Datetime  \
# 29   1112123741574586368 2019-03-30 22:45:00+00:00
# 30   1112106548363292672 2019-03-30 21:37:00+00:00
# 31   1112036985504317442 2019-03-30 17:00:00+00:00
# 32   1111788218142216192 2019-03-30 00:32:00+00:00
# 33   1111762533520531456 2019-03-29 22:50:00+00:00
# 34   1111001632731389952 2019-03-27 20:26:00+00:00
# 35   1110632394611015681 2019-03-26 19:59:00+00:00
# 36   1110576683411628032 2019-03-26 16:18:00+00:00
# 37   1110368897151066114 2019-03-26 02:32:00+00:00
# 38   1109901209446416385 2019-03-24 19:34:00+00:00
# 39   1109900063302508545 2019-03-24 19:29:00+00:00
# 40   1109895343452282880 2019-03-24 19:10:00+00:00
# 41   1108890675922112512 2019-03-22 00:38:00+00:00
# 42   1108630032153341952 2019-03-21 07:22:00+00:00
# 43   1107382673012486144 2019-03-17 20:46:00+00:00
# 44   1107038036913610752 2019-03-16 21:56:00+00:00
# 45   1107029046095810561 2019-03-16 21:21:00+00:00
# 46   1107026609268113408 2019-03-16 21:11:00+00:00
# 47   1107018227727491073 2019-03-16 20:38:00+00:00
# 48   1107009951266824192 2019-03-16 20:05:00+00:00
# 49   1106714774694297601 2019-03-16 00:32:00+00:00
# 50   1106714324968468480 2019-03-16 00:30:00+00:00
# 51   1106319363840397312 2019-03-14 22:21:00+00:00
# 52   1105333522728775686 2019-03-12 05:03:00+00:00
# 53   1105318154375376897 2019-03-12 04:02:00+00:00
# 54   1104514410935050240 2019-03-09 22:48:00+00:00
# 48   still get this question a lot, even though nor...   0.445833
# 49   about a minute in, we flashed a teaser pic of ...   0.000000
# 50   end titles from blade runner played after mode...   0.000000
# 51   worth watching revenge of the electric car. co...   0.200000
# 52   when prices go down, those who already bought ...  -0.077778
# 53   tesla car prices go up ~3% next week, except f...   0.000000
# 54   for cargo missions, propulsive land landing sh...   0.000000
# 55      phenolic impregnated carbon ablator, version 3   0.000000
# 56   those improvements are independent of supercha...   0.311111
# 57   latest software improves tesla supercharger ti...   0.437500
# 58   if you navigate to supercharger, car will warm...   0.600000
# ..                                                 ...        ...
# 719  moving the tesla announcement to wednesday. ne...   0.075000
# 720  @ heiseonline not actually based on science. o...   0.000000
# 721  real fraud going on is denial of climate scien...   0.066667
# 722  coal-mining ceo: 'tesla is a fraud' http://fin...   0.000000
# 723  tesla product unveiling on the 17th (unexpecte...   0.300000
# 724  cumulative tesla autopilot miles now at 222 mi...   0.000000
# 725  something messed up here. tesla policy is equa...   0.000000
# 726  aiming for oct 28 unveil in sf bay area of new...   0.136364
# 727                         thanks for ordering a car!   0.250000
# 728  tesla is sometimes criticized for government s...   0.000000
# 729                    also, the tesla is poison free!   0.500000
# 730                                           all cars   0.000000
# 731  tesla keeps temp below 40c/105f by automatical...   0.175000
# 732  v8.0 starts downloading tonight. release will ...   0.208333
# 733  tesla p100d put to the test by drag timeshttp:...  -0.100000
# 734  tesla model s loses 28% after 50k miles, a mer...  -0.300000
# 735  comprehensive study by autolist shows that a t...   0.300000
# 736  writing post now with details. will publish on...   0.000000
# 737  tesla product announcement at noon california ...   0.000000
# 738  owner account of a model x severely impacted b...   0.000000
# 739  model y (compact suv) off model 3 chassis. tes...   0.000000
# 740  i think we should be inconsistent in our namin...   0.000000
# 741  some good guessing by @ jalopnik. the tesla mi...   0.260000
# 742  the libertarian argument for a carbon taxhttp:...   0.000000
# 743  insurance premiums expected to decline by 80% ...  -0.112500
# 744  jerome is driving tesla semi & doing a great j...   0.712500
# 745  tesla master plan, part deuxhttp://tesla.com/b...   0.000000
# 746    post should go live on tesla website around 5pm   0.136364
# 747  will be working at tesla on autopilot & model ...   0.100000
# 748  thanks. exactly. some in the press think they'...   0.200000
#
#      subjectivity  isreply  year  month  day        date  ...  countComment  \
# 29       0.225000        0  2019      3   30  2019-03-30  ...          1635
# 30       0.000000        0  2019      3   30  2019-03-30  ...           998
# 31       0.608333        0  2019      3   30  2019-03-30  ...           321
# 32       0.419792        1  2019      3   30  2019-03-30  ...           490
# 33       0.461667        0  2019      3   29  2019-03-29  ...           359
# 34       0.833333        1  2019      3   27  2019-03-27  ...            86
# 35       0.359877        1  2019      3   26  2019-03-26  ...           842
# 36       0.370833        1  2019      3   26  2019-03-26  ...           304
# 37       0.050000        1  2019      3   26  2019-03-26  ...          2158
# 38       0.333333        1  2019      3   24  2019-03-24  ...          1075
# 39       0.183333        0  2019      3   24  2019-03-24  ...          1058
# 40       0.000000        0  2019      3   24  2019-03-24  ...           986
# 738           0.066667           0.622222     0.298769           1.0
# 739           0.166667           0.666667     0.298769           1.0
# 740           0.089744           0.378205     0.258483           1.0
# 741           0.117647           0.352941     0.258483           1.0
# 742           0.171429           0.328571     0.077111           4.0
# 743           0.136364           0.357143     0.340438           1.0
# 744           0.000000           0.454545     0.355461           1.0
# 745           0.079570           0.531183     0.187801           6.0
# 746           0.062745           0.376471     0.398325           1.0
# 747           0.107784           0.407186     0.167625           1.0
# 748           0.140288           0.485612     0.255685           2.0
#
# [720 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['id', 'Datetime', 'text', 'sentiment', 'subjectivity', 'isreply',
#        'year', 'month', 'day', 'date', 'DayofWeek', 'Weekend', 'Time',
#        'BinaryTrading', 'DayDistance', 'gtrend', 'CommentSentimental',
#        'CommentSubjectivity', 'countComment', 'posCommentSum', 'negCommentSum',
#        'CommentSD', 'posCommentSD', 'negCommentSD', 'negCommentPercent',
#        'posCommentPercent', 'Volume_perc', 'Trading_Hour'],
#       dtype='object')

# %%
df['Weekend'] = df['Weekend'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 29 to 748
# Data columns (total 28 columns):
# id                     720 non-null object
# Datetime               720 non-null datetime64[ns, UTC]
# text                   720 non-null object
# sentiment              720 non-null float64
# subjectivity           720 non-null float64
# isreply                720 non-null int64
# year                   720 non-null int64
# month                  720 non-null int64
# day                    720 non-null int64
# date                   720 non-null object
# DayofWeek              720 non-null int64
# Weekend                720 non-null int64
# Time                   720 non-null object
# BinaryTrading          720 non-null int64
# DayDistance            720 non-null int64
# gtrend                 720 non-null int64
# CommentSentimental     720 non-null float64
# CommentSubjectivity    720 non-null float64
# countComment           720 non-null int64
# posCommentSum          720 non-null float64
# negCommentSum          720 non-null float64
# CommentSD              720 non-null float64
# posCommentSD           720 non-null float64
# negCommentSD           720 non-null float64
# negCommentPercent      720 non-null float64
# posCommentPercent      720 non-null float64
# Volume_perc            720 non-null float64
# Trading_Hour           720 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(13), int64(10), object(4)
# memory usage: 163.1+ KB

# %%
# prepare X and Y

X = df[['sentiment', 'subjectivity', 'isreply',
       'year','month','day','DayofWeek', 'Weekend',
       'BinaryTrading', 'DayDistance', 'gtrend', 'CommentSentimental',
       'CommentSubjectivity', 'countComment',  'posCommentSum',
       'negCommentSum', 'CommentSD', 'posCommentSD', 'negCommentSD',
       'negCommentPercent', 'posCommentPercent', 'Trading_Hour']]

Y = df['Volume_perc']

# %%
fig, ax = plt.subplots(figsize=(10,8))
cax = ax.matshow(X.corr(), vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(X.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(X.columns)
ax.set_yticklabels(X.columns);

# %%
X = df[['sentiment', 'subjectivity', 'isreply',
       'year','month','day','DayofWeek', 
       'BinaryTrading', 'DayDistance', 'gtrend', 
        'CommentSentimental','posCommentSD', 'negCommentSD',
       'negCommentPercent', 'posCommentPercent', 'Trading_Hour']]

fig, ax = plt.subplots(figsize=(10,8))
cax = ax.matshow(X.corr(), vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(X.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(X.columns)
ax.set_yticklabels(X.columns);

# %%
num_features = len(X.columns)

# %%
num_features
# Out:
# 16

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=100)

print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (576, 16) (576,)
# (144, 16) (144,)

# %% [markdown]
# ### 1. Linear Regression

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train, Y_train)

print("Linear Reg R^2 training is: {}".format(linear_reg.score(X_train, Y_train)))
print("Linear Reg R^2 testing is: {}".format(linear_reg.score(X_test, Y_test)))
print("Linear Reg Train RMSE is: {}".format(np.sqrt(mean_squared_error(Y_train, linear_reg.predict(X_train)))))
print("Linear Reg Test RMSE is: {}".format(np.sqrt(mean_squared_error(Y_test, linear_reg.predict(X_test)))))
# Out:
# Linear Reg R^2 training is: 0.4519727248818831
# Linear Reg R^2 testing is: 0.348762624453934
# Linear Reg Train RMSE is: 0.09013524980290942
# Linear Reg Test RMSE is: 0.10317001840091794

# %% [markdown]
# ### 2a. Simple Random Forest

# %%
# Random Forest
random_forest = RandomForestRegressor(n_estimators=100)     # instantiate
random_forest.fit(X_train, Y_train)                         # fit

print("Random Forest R^2 training is: {}".format(random_forest.score(X_train, Y_train)))                
print("Random Forest R^2 testing is: {}".format(random_forest.score(X_test, Y_test)))   
print("Random Forest Train RMSE is: {}".format(np.sqrt(mean_squared_error(Y_train, random_forest.predict(X_train)))))
print("Random Forest Test RMSE is: {}".format(np.sqrt(mean_squared_error(Y_test, random_forest.predict(X_test)))))
# Out:
# Random Forest R^2 training is: 0.9361923741272327
# Random Forest R^2 testing is: 0.5010304135069604
# Random Forest Train RMSE is: 0.030756001454656387
# Random Forest Test RMSE is: 0.09030689011447438

# %% [markdown]
# ### 2b. Random Forest with Cross Validation

# %%
rf_cv = RandomForestRegressor(n_estimators=100, max_depth=10, max_features=np.sqrt(num_features), random_state=10)

n_estimators = [int(x) for x in np.linspace(start = 100, stop = 500, num = 5)]
max_features = [int(x) for x in np.linspace(4, 16, num = 8)]
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]

# create the hyperparameter grid
hyperparam_grid = {'n_estimators': n_estimators,
                   'max_features': max_features,
                   'max_depth': max_depth}

print(hyperparam_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500], 'max_features': [4, 5, 7, 9, 10, 12, 14, 16], 'max_depth': [10, 20, 30]}

# %%
rf_grid = GridSearchCV(estimator = rf_cv, 
                       param_grid = hyperparam_grid,
                       cv = 5,
                       verbose=2,
                       n_jobs = -1)

# fit the grid search model
rf_grid.fit(X_train, Y_train)

# best hyperparameters
rf_grid.best_params_
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] max_depth=10, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=4, n_estimators=100 ..................
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ... max_depth=10, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=200, total=   0.2s
# [CV] max_depth=10, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=200, total=   0.2s
# [CV] max_depth=10, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=200, total=   0.2s
# [CV] max_depth=10, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=200, total=   0.2s
# [CV] max_depth=10, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=200, total=   0.2s
# [CV] max_depth=10, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=500, total=   0.7s
# [CV] max_depth=10, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=4, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=100, total=   0.1s
# [CV] max_depth=10, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=300, total=   0.4s
# [CV] max_depth=10, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=400, total=   0.5s
# [CV] max_depth=10, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=500, total=   0.7s
# [CV] max_depth=10, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=5, n_estimators=500, total=   0.6s
# [CV] max_depth=10, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=200, total=   0.3s
# [CV] max_depth=10, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=400, total=   0.6s
# [CV] max_depth=10, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=400, total=   0.6s
# [CV] max_depth=10, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=400, total=   0.6s
# [CV] max_depth=10, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=400, total=   0.6s
# [CV] max_depth=10, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=400, total=   0.6s
# [CV] max_depth=10, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=500, total=   0.8s
# [CV] max_depth=10, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=500, total=   0.8s
# [CV] max_depth=10, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=500, total=   0.8s
# [CV] max_depth=10, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=500, total=   0.8s
# [CV] max_depth=10, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=7, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=300, total=   0.5s
# [CV] max_depth=10, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=400, total=   0.7s
# [CV] max_depth=10, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=400, total=   0.7s
# [CV] max_depth=10, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=400, total=   0.7s
# [CV] max_depth=10, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=400, total=   0.7s
# [CV] max_depth=10, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=400, total=   0.7s
# [CV] max_depth=10, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=10, max_features=9, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=400, total=   0.8s
# [CV] max_depth=10, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=400, total=   0.8s
# [CV] max_depth=10, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=400, total=   0.8s
# [CV] max_depth=10, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=400, total=   0.8s
# [CV] max_depth=10, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=400, total=   0.7s
# [CV] max_depth=10, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=500, total=   0.9s
# [CV] max_depth=10, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=500, total=   1.0s
# [CV] max_depth=10, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=10, n_estimators=500, total=   1.0s
# [CV] max_depth=10, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=200, total=   0.4s
# [CV] max_depth=10, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=300, total=   0.7s
# [CV] max_depth=10, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=300, total=   0.6s
# [CV] max_depth=10, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=500, total=   1.1s
# [CV] max_depth=10, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=500, total=   1.1s
# [CV] max_depth=10, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=500, total=   1.1s
# [CV] max_depth=10, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=500, total=   1.1s
# [CV] max_depth=10, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=12, n_estimators=500, total=   1.1s
# [CV] max_depth=10, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=100, total=   0.2s
# [CV] max_depth=10, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=300, total=   0.7s
# [CV] max_depth=10, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=300, total=   0.7s
# [CV] max_depth=10, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=300, total=   0.8s
# [CV] max_depth=10, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=300, total=   0.7s
# [CV] max_depth=10, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=300, total=   0.7s
# [CV] max_depth=10, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=400, total=   1.0s
# [CV] max_depth=10, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=400, total=   1.0s
# [CV] max_depth=10, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=400, total=   0.9s
# [CV] max_depth=10, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=500, total=   1.3s
# [CV] max_depth=10, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=500, total=   1.2s
# [CV] max_depth=10, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=500, total=   1.2s
# [CV] max_depth=10, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=500, total=   1.2s
# [CV] max_depth=10, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=14, n_estimators=500, total=   1.2s
# [CV] max_depth=10, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=10, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=200, total=   0.5s
# [CV] max_depth=10, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=300, total=   0.8s
# [CV] max_depth=10, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=300, total=   0.8s
# [CV] max_depth=10, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=300, total=   0.8s
# [CV] max_depth=10, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=300, total=   0.8s
# [CV] max_depth=10, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=300, total=   0.8s
# [CV] max_depth=10, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=400, total=   1.0s
# [CV] max_depth=10, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=400, total=   1.0s
# [CV] max_depth=10, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=400, total=   1.0s
# [CV] max_depth=10, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=400, total=   1.1s
# [CV] max_depth=10, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=400, total=   1.0s
# [CV] max_depth=10, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=500, total=   1.3s
# [CV] max_depth=10, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=500, total=   1.3s
# [CV] max_depth=10, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=500, total=   1.3s
# [CV] max_depth=10, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=500, total=   1.3s
# [CV] max_depth=10, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=10, max_features=16, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=20, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=20, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=20, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=20, max_features=4, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=100, total=   0.1s
# [CV] max_depth=20, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=4, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=20, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=20, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=20, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=20, max_features=4, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=300, total=   0.4s
# [CV] max_depth=20, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=20, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=20, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=20, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=20, max_features=4, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=400, total=   0.5s
# [CV] max_depth=20, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=4, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=4, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=100, total=   0.1s
# [CV] max_depth=20, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=5, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=5, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=200, total=   0.3s
# [CV] max_depth=20, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=5, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=400, total=   0.6s
# [CV] max_depth=20, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=400, total=   0.6s
# [CV] max_depth=20, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=400, total=   0.6s
# [CV] max_depth=20, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=400, total=   0.6s
# [CV] max_depth=20, max_features=5, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=400, total=   0.6s
# [CV] max_depth=20, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=500, total=   0.8s
# [CV] max_depth=20, max_features=5, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=5, n_estimators=500, total=   0.7s
# [CV] max_depth=20, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=7, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=7, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=300, total=   0.5s
# [CV] max_depth=20, max_features=7, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=400, total=   0.7s
# [CV] max_depth=20, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=400, total=   0.7s
# [CV] max_depth=20, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=400, total=   0.7s
# [CV] max_depth=20, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=400, total=   0.7s
# [CV] max_depth=20, max_features=7, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=400, total=   0.7s
# [CV] max_depth=20, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=500, total=   1.0s
# [CV] max_depth=20, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=500, total=   0.9s
# [CV] max_depth=20, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=500, total=   0.9s
# [CV] max_depth=20, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=500, total=   0.9s
# [CV] max_depth=20, max_features=7, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=7, n_estimators=500, total=   0.9s
# [CV] max_depth=20, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=9, n_estimators=100 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=9, n_estimators=200 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=300, total=   0.7s
# [CV] max_depth=20, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=300, total=   0.6s
# [CV] max_depth=20, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=20, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=20, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=20, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=400, total=   0.9s
# [CV] max_depth=20, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=20, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=20, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=20, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=20, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=20, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=20, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=20, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=20, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=200, total=   0.5s
# [CV] max_depth=20, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=20, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=20, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=20, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=20, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=20, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=20, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=20, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=400, total=   1.0s
# [CV] max_depth=20, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=20, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=20, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=20, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=20, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=20, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=20, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=20, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=20, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=20, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=20, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=20, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=20, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=20, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=20, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=20, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=20, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=20, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=20, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=20, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=20, max_features=12, n_estimators=300, total=   0.8s
# ...
# [CV] ... max_depth=30, max_features=9, n_estimators=300, total=   0.6s
# [CV] max_depth=30, max_features=9, n_estimators=300 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=300, total=   0.7s
# [CV] max_depth=30, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=30, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=30, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=30, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=30, max_features=9, n_estimators=400 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=400, total=   0.8s
# [CV] max_depth=30, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=30, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=30, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=30, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=500, total=   1.1s
# [CV] max_depth=30, max_features=9, n_estimators=500 ..................
# [CV] ... max_depth=30, max_features=9, n_estimators=500, total=   1.0s
# [CV] max_depth=30, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=30, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=30, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=30, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=30, max_features=10, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=100, total=   0.2s
# [CV] max_depth=30, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=200, total=   0.4s
# [CV] max_depth=30, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=10, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=30, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=30, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=30, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=30, max_features=10, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=300, total=   0.7s
# [CV] max_depth=30, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=30, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=30, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=30, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=30, max_features=10, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=400, total=   0.9s
# [CV] max_depth=30, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=500, total=   1.2s
# [CV] max_depth=30, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=30, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=30, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=30, max_features=10, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=10, n_estimators=500, total=   1.1s
# [CV] max_depth=30, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=12, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=12, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=200, total=   0.5s
# [CV] max_depth=30, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=300, total=   0.8s
# [CV] max_depth=30, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=300, total=   0.8s
# [CV] max_depth=30, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=300, total=   0.8s
# [CV] max_depth=30, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=300, total=   0.8s
# [CV] max_depth=30, max_features=12, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=300, total=   0.8s
# [CV] max_depth=30, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=400, total=   1.0s
# [CV] max_depth=30, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=400, total=   1.0s
# [CV] max_depth=30, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=400, total=   1.0s
# [CV] max_depth=30, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=400, total=   1.0s
# [CV] max_depth=30, max_features=12, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=400, total=   1.0s
# [CV] max_depth=30, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=500, total=   1.3s
# [CV] max_depth=30, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=500, total=   1.3s
# [CV] max_depth=30, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=500, total=   1.3s
# [CV] max_depth=30, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=500, total=   1.4s
# [CV] max_depth=30, max_features=12, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=12, n_estimators=500, total=   1.3s
# [CV] max_depth=30, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=14, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=14, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=300, total=   0.9s
# [CV] max_depth=30, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=300, total=   0.8s
# [CV] max_depth=30, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=300, total=   0.9s
# [CV] max_depth=30, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=300, total=   0.9s
# [CV] max_depth=30, max_features=14, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=300, total=   0.9s
# [CV] max_depth=30, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=400, total=   1.1s
# [CV] max_depth=30, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=400, total=   1.1s
# [CV] max_depth=30, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=400, total=   1.1s
# [CV] max_depth=30, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=400, total=   1.2s
# [CV] max_depth=30, max_features=14, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=400, total=   1.1s
# [CV] max_depth=30, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=500, total=   1.4s
# [CV] max_depth=30, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=500, total=   1.4s
# [CV] max_depth=30, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=500, total=   1.4s
# [CV] max_depth=30, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=500, total=   1.5s
# [CV] max_depth=30, max_features=14, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=14, n_estimators=500, total=   1.4s
# [CV] max_depth=30, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=16, n_estimators=100 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=100, total=   0.3s
# [CV] max_depth=30, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=16, n_estimators=200 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=200, total=   0.6s
# [CV] max_depth=30, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=300, total=   1.0s
# [CV] max_depth=30, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=300, total=   0.9s
# [CV] max_depth=30, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=300, total=   0.9s
# [CV] max_depth=30, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=300, total=   1.0s
# [CV] max_depth=30, max_features=16, n_estimators=300 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=300, total=   1.0s
# [CV] max_depth=30, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=400, total=   1.3s
# [CV] max_depth=30, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=400, total=   1.2s
# [CV] max_depth=30, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=400, total=   1.3s
# [CV] max_depth=30, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=400, total=   1.3s
# [CV] max_depth=30, max_features=16, n_estimators=400 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=400, total=   1.3s
# [CV] max_depth=30, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=500, total=   1.6s
# [CV] max_depth=30, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=500, total=   1.6s
# [CV] max_depth=30, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=500, total=   1.6s
# [CV] max_depth=30, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=500, total=   1.6s
# [CV] max_depth=30, max_features=16, n_estimators=500 .................
# [CV] .. max_depth=30, max_features=16, n_estimators=500, total=   1.6s
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:  6.6min finished
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 500}

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 500}

# %%
#rf_grid.cv_results_

# %%
# use optimal hyperparameters
rf_cv = RandomForestRegressor(n_estimators=500, max_depth=20, max_features=5, random_state=10)
rf_cv.fit(X_train, Y_train)                         # fit

print("Random Forest R^2 training is: {}".format(rf_cv.score(X_train, Y_train)))                
print("Random Forest R^2 testing is: {}".format(rf_cv.score(X_test, Y_test)))   
print("Random Forest Train RMSE is: {}".format(np.sqrt(mean_squared_error(Y_train, rf_cv.predict(X_train)))))
print("Random Forest Test RMSE is: {}".format(np.sqrt(mean_squared_error(Y_test, rf_cv.predict(X_test)))))
# Out:
# Random Forest R^2 training is: 0.936610654811798
# Random Forest R^2 testing is: 0.4862276549425167
# Random Forest Train RMSE is: 0.03065502767935184
# Random Forest Test RMSE is: 0.09163665147769548

# %% [markdown]
# ### Feature Importance

# %%
import pandas as pd
feature_importances = pd.DataFrame(rf_cv.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=True)

y_pos = np.arange(len(X_train.columns))
plt.barh(y_pos, feature_importances.importance, align='center', alpha=0.5)
plt.yticks(y_pos, X_train.columns)
plt.title('CV Random Forest Feature Importance')
plt.show()

# %% [markdown]
# ### 3. Xtreme Gradient Boosting
#
# Parameter Reference: https://www.datacamp.com/community/tutorials/xgboost-in-python
#
# Default Hyperparams:
#  - XGB Train RMSE is: 0.0627184664815691
#  - XGB Test RMSE is: 0.10047705976306533

# %%
xgb = XGBRegressor(objective ='reg:linear', 
                   colsample_bytree = 0.9, 
                   learning_rate = 0.2,
                   max_depth = 20, 
                   alpha = 5, 
                   n_estimators = 500)

xgb.fit(X_train, Y_train)

print("XGB R^2 training is: {}".format(xgb.score(X_train, Y_train)))                
print("XGB R^2 testing is: {}".format(xgb.score(X_test, Y_test)))  
print("XGB Train RMSE is: {}".format(np.sqrt(mean_squared_error(Y_train, xgb.predict(X_train)))))
print("XGB Test RMSE is: {}".format(np.sqrt(mean_squared_error(Y_test, xgb.predict(X_test)))))
# Out:
# XGB R^2 training is: 0.9999794292098636
# XGB R^2 testing is: 0.4322205207952022
# XGB Train RMSE is: 0.0005522288181162515
# XGB Test RMSE is: 0.0963326916892139

# %%
modellist = [linear_reg, random_forest, rf_cv, xgb]
modelname = ['log','rf','cv_rf','xgb']  

n = 500
bootstrap = pd.DataFrame(columns=['size','model','mean','sd','CI','LB','UB'])
err = pd.DataFrame(columns=['size','model','mse'])
errors   = np.zeros((n, len(modellist)))

for b in range(0,n):
    for i,model in enumerate(modellist):
        index = np.random.choice(list(range(0,len(X_test))),len(X_test), replace=True)
        errors[b,i] = r2_score(Y_test.iloc[index], model.predict(X_test.iloc[index]))
        err = err.append(pd.DataFrame([{'size': n, 'model' : modelname[i],'MSE' : errors[b,i]  }])) 

bootstrapres = pd.DataFrame({'size': n, 'model' : modelname,'mean' : errors.mean(axis=0) ,'sd' : np.std(errors, axis=0)})
#     print(bootstrapres)
bootstrapres['CI'] = [ 1.96* b[3] for _,b in bootstrapres.iterrows()]
bootstrapres['LB'] = [b[2] - 1.96* b[3] for _,b in bootstrapres.iterrows()]
bootstrapres['UB'] = [b[2] + 1.96* b[3] for _,b in bootstrapres.iterrows()]

bootstrap = bootstrap.append(bootstrapres)

# %%
# Test R^2 bootstrap 95% confidence interval
bootstrap
# Out:
#   size  model      mean        sd        CI        LB        UB
# 0  500    log  0.347873  0.052216  0.102343  0.245530  0.450216
# 1  500     rf  0.493874  0.058189  0.114051  0.379824  0.607925
# 2  500  cv_rf  0.479162  0.057112  0.111940  0.367223  0.591102
# 3  500    xgb  0.422130  0.067868  0.133022  0.289108  0.555152

# %%
modellist = [linear_reg, random_forest, rf_cv, xgb]
modelname = ['log','rf','cv_rf','xgb'] 

n = 500
bootstrap = pd.DataFrame(columns=['size','model','mean','sd','CI','LB','UB'])
err = pd.DataFrame(columns=['size','model','mse'])
errors   = np.zeros((n, len(modellist)))

for b in range(0,n):
    for i,model in enumerate(modellist):
        index = np.random.choice(list(range(0,len(X_test))),len(X_test), replace=True)
        errors[b,i] = np.sqrt(mean_squared_error(Y_test.iloc[index], model.predict(X_test.iloc[index])))
        err = err.append(pd.DataFrame([{'size': n, 'model' : modelname[i],'MSE' : errors[b,i]  }])) 

bootstrapres = pd.DataFrame({'size': n, 'model' : modelname,'mean' : errors.mean(axis=0) ,'sd' : np.std(errors, axis=0)})
#     print(bootstrapres)
bootstrapres['CI'] = [ 1.96* b[3] for _,b in bootstrapres.iterrows()]
bootstrapres['LB'] = [b[2] - 1.96* b[3] for _,b in bootstrapres.iterrows()]
bootstrapres['UB'] = [b[2] + 1.96* b[3] for _,b in bootstrapres.iterrows()]

bootstrap = bootstrap.append(bootstrapres)

# %%
# RMSE bootstrap 95% confidence interval
bootstrap
# Out:
#   size  model      mean        sd        CI        LB        UB
# 0  500    log  0.102508  0.007919  0.015521  0.086987  0.118029
# 1  500     rf  0.090611  0.005932  0.011627  0.078985  0.102238
# 2  500  cv_rf  0.091156  0.006660  0.013053  0.078102  0.104209
# 3  500    xgb  0.096620  0.006139  0.012032  0.084588  0.108652

# %%
# pd.set_option('display.float_format', lambda x: '%.3f' % x)
# print(bootstrap)

# plt.figure(figsize = (8,5))
# ax = sns.lineplot(x="size", y="MSE", hue="model",ci='sd', data=err)
# ax.set_ylim(0,1)
## ax.fill_between(bootstrap.size, bootstrap.LB, bootstrap.UB, color='#888888', alpha=0.2)
