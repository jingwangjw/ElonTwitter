# %%
# Packages
import pandas as pd
import numpy as np
from collections import Counter
import nltk, spacy, re, json
from nltk.corpus import stopwords
from nltk.util import ngrams
nltk.download("punkt")
nltk.download('stopwords')

# Set up
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', -1)
# Out:
# [nltk_data] Downloading package punkt to /jet/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /jet/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filename="../../data/twitter/elon_clean.csv"

# %%
elon = pd.read_csv(filename)

# %%
elon.head()
# Out:
#    username              date  retweets  favorites  \
# 0  elonmusk  2019-04-02 20:38  993       9263
# 1  elonmusk  2019-04-02 20:16  7238      55271
# 2  elonmusk  2019-04-02 19:40  368       9159
# 3  elonmusk  2019-04-02 09:24  1317      6176
# 4  elonmusk  2019-04-02 09:21  1557      26925
#
#                                                                                                                       text  \
# 0  Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1  Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2  Uh oh
# 3  Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4  Yup https:// twitter.com/nasa/status/11 12860196043452417 …
#
#   mentions hashtags                                                permalink
# 0  NaN      NaN      https://twitter.com/elonmusk/status/1113178951403180032
# 1  NaN      NaN      https://twitter.com/elonmusk/status/1113173498384441344
# 2  NaN      NaN      https://twitter.com/elonmusk/status/1113164389929160706
# 3  NaN      NaN      https://twitter.com/elonmusk/status/1113009339743100929
# 4  NaN      NaN      https://twitter.com/elonmusk/status/1113008497006804992

# %%
tweets=elon['text']

# %%
tweets
# Out:
# 0       Dogecoin value may vary https://www. theonion.com/bitcoin-plunge -reveals-possible-vulnerabilities-in-craz-1821134169 …
# 1       Dogecoin rulz pic.twitter.com/flWWUgAgLU
# 2       Uh oh
# 3       Dogecoin might be my fav cryptocurrency. It’s pretty cool.
# 4       Yup https:// twitter.com/nasa/status/11 12860196043452417 …
# 5       Some challenges with ice formation in the cryogenic propellant prevalves. Hopefully overcome soon.
# 6       What could possibly go wrong?
# 7       No
# 8       You’re so right. Working on it!
# 9       That car seemed so advanced when I watched that show as a kid! Knight Industries Two Thousand
# 10      And even tinier ones for tardigrades
# 11      Yes
# 12      Going forward, all Tesla stores will be tiny & have tiny cars
# 13      Meant to say young, but spelled it wrong
# 14      Ironic stan
# 15      If can do this, what can’t they do!?
# 16      Solid work by Keen, as usual
# 17      Norway https:// twitter.com/elbilforeninge n/status/1112702954719588357 …
# 18      Yes
# 19      Yes
# 20      Seems fair
# 21      Some people use their hair to express themselves, I use Twitter
# 22      . @TheOnion
# 23      Making The Onion articles real … https://www. rollingstone.com/music/music-ne ws/elon-musk-rap-song-rip-harambe-815813/ …
# 24      @yungjake & @bloodpop
# 25      Duck emoji FTW
# 26      Final edit was on Ableton
# 27      Surprisingly difficult to address false positives with rain. System would go nuts trying to wipe away non-existent rain, which was obv ineffective.
# 28      Jung pic.twitter.com/pDR4JI4lpu
# 29      We’ve been so mired in production & logistics for past 18 months. Really looking fwd to getting Semi into production.
#                                                                 ...
# 6061    @om Cool personal essay. It really resonated with me, as I felt the same way after coming very close to dying from malaria ten years ago.
# 6062    @richardbranson Liked Screw Business as Usual" a lot. This approach should be taken to heart by all, as it really is the smart move."
# 6063    @kanyewest Just returned from Haiti. For those who want to help, I recommend donating to MSF, UNICEF and Artists for Peace & Justice.
# 6064    @TheOnion So true :)
# 6065    If you ever wanted to know the *real* truth about the moon landings ...(best Onion article ever) http:// j.mp/vLhhov
# 6066    Walked around a neighborhood recently rebuilt with help from APJ and others pic.twitter.com/KYHjsS1k
# 6067    It was Xmas, so we brought presents for the kids at the orphanage. They don't usually get much. pic.twitter.com/r8qfluIG
# 6068    Met with UNICEF, Doctors Without Borders and Artists for Peace & Justice. I support them and would recommend others do too.
# 6069    Just returned from a trip to Haiti. Covered a lot of ground and saw many tough situations. They need a lot of help.
# 6070    Single character Tweets are the ulitmate extension of the Twitmeme...
# 6071    I
# 6072    The Russians are having some challenges with their rockets. Too many of the engineers that designed them have retired: http:// ow.ly/89k5F
# 6073    We had a long and interesting conversation on many subjects. He has exciting ideas for extending his creative talents beyond music.
# 6074    Kanye stopped by the SpaceX rocket factory today. pic.twitter.com/6z7gHBn6
# 6075    Model S options are out! Performance in red and black for me. I will deliver my car in June/July. pic.twitter.com/acnyP4nh
# 6076    Hi, I'm Art Garfunkel. Have you heard the sound of silence? Because, you know, it makes a sound... pic.twitter.com/7vgya9xL
# 6077    Raul Campos invited me to do a guest DJ gig on KCRW. Hear my random holiday season music selections at http:// ow.ly/87gEb
# 6078    Yum! Even better than deep fried butter: http:// ow.ly/877EB
# 6079    Yeah, this really is me, as my Mom @mayemusk will attest. Not sure I can handle just doing 140 char missives. Will put longer thoughts on G+
# 6080    Got called randomly by Kanye West today and received a download of his thoughts, ranging from shoes to Moses. He was polite, but opaque.
# 6081    His singing and acting talent will be sorely missed: http://www. youtube.com/watch?v=jdug6y HJB40&feature=related … South Park sequel coming soon...
# 6082    Why does the crowd cry over the glorious leader Kim Il Sung's death? Fear of being shot may play a role: http:// ow.ly/86gDA
# 6083    Sam Harris also wrote a nice piece on the awesomeness of Hitchens: http://www. samharris.org/blog/item/hitc h/ … May the good man RIP.
# 6084    Read Lying", the new book by my friend Sam Harris. Excellent cover art and lots of good reasons not to lie!"
# 6085    Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 6086    That was a total non sequitur btw
# 6087    Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 6088    I made the volume on the Model S http:// ow.ly/i/mtD7 go to 11. Now I just need to work in a miniature Stonehenge...
# 6089    Went to Iceland on Sat to ride bumper cars on ice! No, not the country, Vlad's rink in Van Nuys. Awesome family fun :) pic.twitter.com/rBQXJ9IT
# 6090    Please ignore prior tweets, as that was someone pretending to be me :) This is actually me.
# Name: text, Length: 6091, dtype: object

# %%
nltk_twitter_tokens=[]
for tweet in tweets:
    nltk_twitter_tokens.append(nltk.casual_tokenize(tweet))

# %%
### Remember to follow the order here: match from first to last
regexes=(
    # Keep usernames together (any token starting with @, followed by A-Z, a-z, 0-9)
    r"(?:@[\w_]+)",
    # Keep hashtags together (any token starting with #, followed by A-Z, a-z, 0-9, _, or -)
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)",
    # Keep words with apostrophes, hyphens and underscores together
    r"(?:[a-z][a-z’'\-_]+[a-z])",
    # Keep all other sequences of A-Z, a-z, 0-9, _ together
    r"(?:[\w_]+)",
    # Everything else that's not whitespace
    r"(?:\S)")
big_regex="|".join(regexes)
extensible_tokenizer = re.compile(big_regex, re.VERBOSE | re.I | re.UNICODE)

def extensible_tokenize(text):
    return extensible_tokenizer.findall(text)

# %%
# Tokenize tweets data 
tweets_tokens=[]
for tweet in tweets:
    tokens=extensible_tokenize(tweet.lower())
    tweets_tokens.append(tokens)

# %%
tweets_tokens
# Out:
# [['dogecoin',
#   'value',
#   'may',
#   'vary',
#   'https',
#   ':',
#   '/',
#   '/',
#   'www',
#   '.',
#   'theonion',
#   '.',
#   'com',
#   '/',
#   'bitcoin-plunge',
#   '-',
#   'reveals-possible-vulnerabilities-in-craz',
#   '-',
#   '1821134169',
#   '…'],
#  ['dogecoin', 'rulz', 'pic', '.', 'twitter', '.', 'com', '/', 'flwwugaglu'],
#  ['uh', 'oh'],
#  ['dogecoin',
#   'might',
#   'be',
#   'my',
#   'fav',
#   'cryptocurrency',
#   '.',
#   'it’s',
#   'pretty',
#   'cool',
#   '.'],
#  ['yup',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'nasa',
#   '/',
#   'status',
#   '/',
#   '11',
#   '12860196043452417',
#   '…'],
#  ['some',
#   'challenges',
#   'with',
#   'ice',
#   'formation',
#   'in',
#   'the',
#   'cryogenic',
#   'propellant',
#   'prevalves',
#   '.',
#   'hopefully',
#   'overcome',
#   'soon',
#   '.'],
#  ['what', 'could', 'possibly', 'go', 'wrong', '?'],
#  ['no'],
#  ['you’re', 'so', 'right', '.', 'working', 'on', 'it', '!'],
#  ['that',
#   'car',
#   'seemed',
#   'so',
#   'advanced',
#   'when',
#   'i',
#   'watched',
#   'that',
#   'show',
#   'as',
#   'a',
#   'kid',
#   '!',
#   'knight',
#   'industries',
#   'two',
#   'thousand'],
#  ['and', 'even', 'tinier', 'ones', 'for', 'tardigrades'],
#  ['yes'],
#  ['going',
#   'forward',
#   ',',
#   'all',
#   'tesla',
#   'stores',
#   'will',
#   'be',
#   'tiny',
#   '&',
#   'have',
#   'tiny',
#   'cars'],
#  ['meant', 'to', 'say', 'young', ',', 'but', 'spelled', 'it', 'wrong'],
#  ['ironic', 'stan'],
#  ['if', 'can', 'do', 'this', ',', 'what', 'can’t', 'they', 'do', '!', '?'],
#  ['solid', 'work', 'by', 'keen', ',', 'as', 'usual'],
#  ['norway',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'elbilforeninge',
#   'n',
#   '/',
#   'status',
#   '/',
#   '1112702954719588357',
#   '…'],
#  ['yes'],
#  ['yes'],
#  ['seems', 'fair'],
#  ['some',
#   'people',
#   'use',
#   'their',
#   'hair',
#   'to',
#   'express',
#   'themselves',
#   ',',
#   'i',
#   'use',
#   'twitter'],
#  ['.', '@theonion'],
#  ['making',
#   'the',
#   'onion',
#   'articles',
#   'real',
#   '…',
#   'https',
#   ':',
#   '/',
#   '/',
#   'www',
#   '.',
#   'rollingstone',
#   '.',
#   'com',
#   '/',
#   'music',
#   '/',
#   'music-ne',
#   'ws',
#   '/',
#   'elon-musk-rap-song-rip-harambe',
#   '-',
#   '815813',
#   '/',
#   '…'],
#  ['@yungjake', '&', '@bloodpop'],
#  ['duck', 'emoji', 'ftw'],
#  ['final', 'edit', 'was', 'on', 'ableton'],
#  ['surprisingly',
#   'difficult',
#   'to',
#   'address',
#   'false',
#   'positives',
#   'with',
#   'rain',
#   '.',
#   'system',
#   'would',
#   'go',
#   'nuts',
#   'trying',
#   'to',
#   'wipe',
#   'away',
#   'non-existent',
#   'rain',
#   ',',
#   'which',
#   'was',
#   'obv',
#   'ineffective',
#   '.'],
#  ['jung', 'pic', '.', 'twitter', '.', 'com', '/', 'pdr', '4ji4lpu'],
#  ['we’ve',
#   'been',
#   'so',
#   'mired',
#   'in',
#   'production',
#   '&',
#   'logistics',
#   'for',
#   'past',
#   '18',
#   'months',
#   '.',
#   'really',
#   'looking',
#   'fwd',
#   'to',
#   'getting',
#   'semi',
#   'into',
#   'production',
#   '.'],
#  ['tesla',
#   'semi',
#   'delivering',
#   'tesla',
#   'cars',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'ttepcw',
#   '5d8g'],
#  ['pre-happy', 'birthday', '!'],
#  ['amazing',
#   'work',
#   'by',
#   'tesla',
#   'delivery',
#   'teams',
#   ',',
#   'especially',
#   'in',
#   'europe',
#   '&',
#   'china',
#   '!',
#   'most',
#   'insane',
#   'logistics',
#   'challenge',
#   'i’ve',
#   'ever',
#   'seen',
#   '.',
#   'thanks',
#   'also',
#   'to',
#   'many',
#   'country',
#   '&',
#   'city',
#   'officials',
#   'for',
#   'your',
#   'help',
#   'this',
#   'weekend',
#   '!',
#   'super',
#   'appreciated',
#   '.'],
#  ['coming', 'soon', '!'],
#  ['no'],
#  ['wow'],
#  ['http', ':', '/', '/', 'x', '.', 'com', '/', 'x'],
#  ['this', 'might', 'be', 'my', 'finest', 'work'],
#  ['duck',
#   'emoji',
#   'defeats',
#   'emo',
#   'g',
#   'records',
#   '.',
#   'crushing',
#   'victory',
#   '.'],
#  ['i’m', 'disappointed', 'that', 'my', 'record', 'label', 'failed'],
#  ['emo',
#   'g',
#   'records',
#   'https',
#   ':',
#   '/',
#   '/',
#   'soundcloud',
#   '.',
#   'com',
#   '/',
#   'user',
#   '-',
#   '209448905',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'anvkkefmgr'],
#  ['instagram', 'comments', 'are', 'coding', 'in', 'emojis'],
#  ['also', 'true'],
#  ['true'],
#  ['the', 'quality', 'of', 'emojis', 'varies', 'wildly'],
#  ['lame'],
#  ['c', '+', '+', 'syntax', 'sucks'],
#  ['assert',
#   '(',
#   '“',
#   'money',
#   '”',
#   '=',
#   '=',
#   'series',
#   'of',
#   'heterogeneous',
#   'databases',
#   'insecurely',
#   'connected',
#   'with',
#   'high',
#   'latency',
#   '.',
#   'primary',
#   'purpose',
#   '=',
#   '=',
#   'information',
#   'system',
#   'for',
#   'allocation',
#   'of',
#   'human',
#   'time',
#   '.',
#   'as',
#   'automation',
#   '+',
#   '+',
#   ',',
#   'value',
#   'of',
#   'money',
#   '-',
#   '-',
#   ')',
#   ';'],
#  ['even',
#   'connectivity',
#   'at',
#   'my',
#   'house',
#   'in',
#   'silicon',
#   'valley',
#   'sucks',
#   '!'],
#  ['like',
#   'the',
#   'movie',
#   'us',
#   '.',
#   'scary',
#   '…',
#   'but',
#   'also',
#   'empathetic',
#   '.'],
#  ['no', ',', 'but', 'for', 'sure', 'the', 'other', 'way', 'around', '!'],
#  ['also',
#   'the',
#   'intense',
#   'low',
#   'frequency',
#   'vibrations',
#   'that',
#   'you',
#   'can’t',
#   'hear',
#   ',',
#   'but',
#   'you',
#   'can',
#   'feel',
#   'in',
#   'your',
#   'chest'],
#  ['we’re',
#   'going',
#   'to',
#   'try',
#   '.',
#   'side',
#   'boosters',
#   'come',
#   'back',
#   'to',
#   'cape',
#   ',',
#   'center',
#   'core',
#   'lands',
#   'on',
#   'droneship',
#   '.',
#   'latter',
#   'will',
#   'be',
#   'coming',
#   'in',
#   'v',
#   'hot',
#   '&',
#   'fast',
#   ',',
#   'so',
#   'dicey',
#   '.'],
#  ['annoying',
#   'that',
#   '@ula',
#   'perpetuates',
#   'myth',
#   'that',
#   'delta',
#   'iv',
#   'heavy',
#   'or',
#   'atlas',
#   'v',
#   'can',
#   'do',
#   'some',
#   'orbits',
#   'that',
#   'falcon',
#   'heavy',
#   'can’t',
#   '.',
#   'this',
#   'is',
#   'absolutely',
#   'false',
#   '.',
#   'fh',
#   'would',
#   'have',
#   'to',
#   'go',
#   'full',
#   'expendable',
#   'for',
#   'geo',
#   'direct',
#   ',',
#   'but',
#   'that’s',
#   'very',
#   'rare',
#   '.'],
#  ['yeah',
#   ',',
#   'falcon',
#   'heavy',
#   'block',
#   '5',
#   'has',
#   'way',
#   'more',
#   'performance',
#   'than',
#   'last',
#   'year’s',
#   'vehicle',
#   '.',
#   'lot',
#   'of',
#   'room',
#   'to',
#   'increase',
#   'side',
#   'booster',
#   'load',
#   'transfer',
#   '&',
#   'max',
#   'q',
#   'without',
#   'changing',
#   'any',
#   'parts',
#   '.',
#   'fh',
#   'block',
#   '5',
#   'can',
#   'launch',
#   'more',
#   'payload',
#   'to',
#   'any',
#   'orbit',
#   'than',
#   'any',
#   'vehicle',
#   'currently',
#   'flying',
#   '.'],
#  ['probably',
#   'no',
#   'fairing',
#   'either',
#   '&',
#   'just',
#   '3',
#   'raptor',
#   'vacuum',
#   'engines',
#   '.',
#   'mass',
#   'ratio',
#   'of',
#   '~',
#   '30',
#   '(',
#   '1200',
#   'tons',
#   'full',
#   ',',
#   '40',
#   'tons',
#   'empty',
#   ')',
#   'with',
#   'isp',
#   'of',
#   '380',
#   '.',
#   'then',
#   'drop',
#   'a',
#   'few',
#   'dozen',
#   'modified',
#   'starlink',
#   'satellites',
#   'from',
#   'empty',
#   'engine',
#   'bays',
#   'with',
#   '~',
#   '1600',
#   'isp',
#   ',',
#   'mr',
#   '2',
#   '.',
#   'spread',
#   'out',
#   ',',
#   'see',
#   'what’s',
#   'there',
#   '.',
#   'not',
#   'impossible',
#   '.'],
#  ['retrofits',
#   'will',
#   'start',
#   'when',
#   'our',
#   'software',
#   'is',
#   'able',
#   'to',
#   'take',
#   'meaningful',
#   'advantage',
#   'of',
#   'the',
#   'tesla',
#   'fsd',
#   'computer',
#   ',',
#   'which',
#   'is',
#   'an',
#   'order',
#   'of',
#   'magnitude',
#   'more',
#   'capable',
#   '.',
#   'for',
#   'now',
#   ',',
#   'it’s',
#   'slightly',
#   'disadvantageous',
#   'to',
#   'have',
#   'tesla',
#   'fsd',
#   'computer',
#   ',',
#   'as',
#   'our',
#   'software',
#   'is',
#   'more',
#   'refined',
#   'for',
#   'hw2',
#   '.'],
#  ['anyone', 'who', 'bought', 'fsd', 'will', 'get', 'it'],
#  ['anyone',
#   'who',
#   'purchased',
#   'full',
#   'self-driving',
#   'will',
#   'get',
#   'fsd',
#   'computer',
#   'upgrade',
#   'for',
#   'free',
#   '.',
#   'this',
#   'is',
#   'the',
#   'only',
#   'change',
#   'between',
#   'autopilot',
#   'hw2',
#   '.',
#   '5',
#   '&',
#   'hw3',
#   '.',
#   'going',
#   'forward',
#   '“',
#   'hw3',
#   '”',
#   'will',
#   'just',
#   'be',
#   'called',
#   'fsd',
#   'computer',
#   ',',
#   'which',
#   'is',
#   'accurate',
#   '.',
#   'no',
#   'change',
#   'to',
#   'vehicle',
#   'sensors',
#   'or',
#   'wire',
#   'harness',
#   'needed',
#   '.',
#   'this',
#   'is',
#   'v',
#   'important',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'samscho',
#   '/',
#   'status',
#   '/',
#   '1110649850188558336',
#   '…'],
#  ['yes',
#   '.',
#   'sensitive',
#   'propulsion',
#   '&',
#   'avionics',
#   'remained',
#   'dry',
#   '.',
#   'great',
#   'work',
#   'by',
#   'spacex',
#   'dragon',
#   'engineering',
#   'team',
#   '.',
#   'major',
#   'improvement',
#   'over',
#   'dragon',
#   '1',
#   '.'],
#  ['massive',
#   'delta',
#   'velocity',
#   'slam',
#   'from',
#   'highly',
#   'elliptical',
#   'earth',
#   'orbit',
#   'using',
#   'a',
#   'fully',
#   'retanked',
#   ',',
#   'but',
#   'lightened',
#   'up',
#   'starship',
#   'with',
#   'no',
#   'heat',
#   'shield',
#   'or',
#   'fins',
#   '/',
#   'legs',
#   '.',
#   'best',
#   'choice',
#   'for',
#   'the',
#   'impatient',
#   '.',
#   'ion',
#   'engines',
#   'are',
#   'too',
#   'slow',
#   '.'],
#  ['we',
#   'should',
#   'send',
#   'probes',
#   'to',
#   'outer',
#   'solar',
#   'system',
#   '&',
#   'get',
#   'high',
#   'res',
#   ',',
#   'true',
#   'color',
#   'images',
#   'of',
#   'these',
#   'strange',
#   'things',
#   '.',
#   'maybe',
#   'there’s',
#   'an',
#   'alien',
#   'artifact',
#   'out',
#   'there',
#   '…'],
#  ['super', 'cool', '!'],
#  ['good', 'point'],
#  ['tax',
#   'authorities',
#   'tend',
#   'to',
#   'interpret',
#   'things',
#   'in',
#   'their',
#   'favor',
#   ',',
#   'but',
#   'it',
#   'sure',
#   'sounds',
#   'like',
#   'you',
#   'could',
#   'be',
#   'right',
#   '!',
#   'will',
#   'investigate',
#   '.'],
#  ['rare',
#   'use',
#   'case',
#   ',',
#   'but',
#   'it',
#   'is',
#   'possible',
#   '.',
#   'there',
#   'are',
#   'complications',
#   'with',
#   'this',
#   '.',
#   'eary',
#   'prototype',
#   'roadsters',
#   'had',
#   'this',
#   'ability',
#   '.'],
#  ['exactly'],
#  ['super', 'proud', 'of', 'tesla', 'autopilot', 'team', '!'],
#  ['no', ',', 'it', 'is', 'one', 'week', 'either', 'way', '.'],
#  ['i',
#   'think',
#   'so',
#   '.',
#   'for',
#   'sure',
#   'worth',
#   'giving',
#   'it',
#   'our',
#   'best',
#   'shot',
#   '!',
#   'would',
#   'be',
#   'great',
#   'to',
#   'have',
#   'a',
#   'competitive',
#   ',',
#   'commercial',
#   'program',
#   'to',
#   'build',
#   'a',
#   'moon',
#   'base',
#   'that',
#   'is',
#   'outcome-oriented',
#   '(',
#   'not',
#   'cost-plus',
#   ')',
#   ',',
#   'so',
#   'you',
#   'only',
#   'get',
#   'paid',
#   'for',
#   'safe',
#   'delivery',
#   'of',
#   'cargo',
#   '.'],
#  ['it',
#   'would',
#   'be',
#   'so',
#   'inspiring',
#   'for',
#   'humanity',
#   'to',
#   'see',
#   'humanity',
#   'return',
#   'to',
#   'the',
#   'moon',
#   '!'],
#  ['12',
#   ',',
#   '000',
#   'lbs',
#   '!',
#   '?',
#   'how',
#   'puny',
#   '.',
#   'do',
#   'you',
#   'construct',
#   'children’s',
#   'toys',
#   '?'],
#  ['that’s',
#   'exactly',
#   'it',
#   '.',
#   'you’re',
#   'no',
#   'longer',
#   'mentally',
#   'fatigued',
#   'after',
#   'a',
#   'long',
#   'drive',
#   '.',
#   'makes',
#   'a',
#   'major',
#   'difference',
#   'to',
#   'your',
#   'happiness',
#   'level',
#   'commuting',
#   'home',
#   'from',
#   'work',
#   'after',
#   'a',
#   'long',
#   'day',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'sspencer_smb',
#   '/',
#   's',
#   'tatus',
#   '/',
#   '1110577741102022658',
#   '…'],
#  ['good', 'point'],
#  ['hard',
#   'to',
#   'appreciate',
#   'how',
#   'much',
#   'tesla',
#   'autopilot',
#   'improves',
#   'enjoyment',
#   'of',
#   'driving',
#   'until',
#   'you',
#   'try',
#   'it',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'erdayastronaut',
#   '/',
#   'status',
#   '/',
#   '1110574284076769280',
#   '…'],
#  ['yes',
#   ',',
#   'otherwise',
#   'propellant',
#   'usage',
#   'for',
#   'an',
#   'atmospheric',
#   'entry',
#   'would',
#   'be',
#   'very',
#   'high',
#   'and',
#   '/',
#   'or',
#   'center',
#   'of',
#   'mass',
#   'would',
#   'need',
#   'to',
#   'be',
#   'very',
#   'tightly',
#   'constrained',
#   '.',
#   'yes',
#   ',',
#   'but',
#   'we’re',
#   'going',
#   'to',
#   'skip',
#   'that',
#   'at',
#   'first',
#   'to',
#   'avoid',
#   'fragging',
#   'launch',
#   'pads',
#   '.'],
#  ['glad',
#   'you',
#   'like',
#   'it',
#   '!',
#   'navigate',
#   'on',
#   'autopilot',
#   'hopefully',
#   'approved',
#   'for',
#   'europe',
#   'soon',
#   '.'],
#  ['thank',
#   'you',
#   '!',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'tesla',
#   '/',
#   'status',
#   '/',
#   '1',
#   '109495034959675393',
#   '…'],
#  ['will', 'do'],
#  ['ford',
#   'has',
#   '4',
#   'ceos',
#   'in',
#   '5',
#   'years',
#   '&',
#   'nobody',
#   'blinks',
#   ',',
#   'but',
#   'tesla',
#   'loses',
#   '1',
#   'intern',
#   '&',
#   'it’s',
#   'front',
#   'page',
#   'news',
#   '.',
#   'i',
#   'tell',
#   'ya',
#   '(',
#   'shakes',
#   'fist',
#   'at',
#   'sky',
#   ')',
#   '…'],
#  ['it’s',
#   'possible',
#   'to',
#   'make',
#   'a',
#   'self-sustaining',
#   'city',
#   'on',
#   'mars',
#   'by',
#   '2050',
#   ',',
#   'if',
#   'we',
#   'start',
#   'in',
#   '5',
#   'years',
#   '&',
#   'take',
#   '10',
#   'orbital',
#   'synchronizations'],
#  ['you’re', 'most', 'welcome', '!', 'glad', 'to', 'be', 'helpful', '.'],
#  ['only', 'when', 'y', 'is', 'in', 'production'],
#  ['every',
#   'car',
#   'company',
#   'is',
#   'constantly',
#   'changing',
#   'prices',
#   ',',
#   'but',
#   'nobody',
#   'cares'],
#  ['import', 'tariffs', ',', 'vat', '&', 'transport', 'costs'],
#  ['to',
#   'be',
#   'clear',
#   ',',
#   'this',
#   'doesn’t',
#   'affect',
#   'tesla',
#   'website',
#   'order',
#   'prices',
#   '.',
#   'existing',
#   'inventory',
#   'prices',
#   'are',
#   'currently',
#   'slightly',
#   'lower',
#   'than',
#   'on',
#   'website',
#   '.',
#   'this',
#   'will',
#   'bring',
#   'them',
#   'in',
#   'line',
#   '.'],
#  ['to',
#   'be',
#   'precise',
#   ',',
#   'midnight',
#   'on',
#   'april',
#   '1',
#   ',',
#   'so',
#   'effective',
#   'april',
#   '2'],
#  ['please',
#   'note',
#   'prices',
#   'on',
#   'all',
#   'tesla',
#   'inventory',
#   'cars',
#   'worldwide',
#   'rise',
#   'by',
#   '~',
#   '3',
#   '%',
#   'on',
#   'april',
#   '1'],
#  ['about', 'to', 'be', 'upgraded', 'to', 'chromium'],
#  ['reset'],
#  ['sentry',
#   'mode',
#   'options',
#   'will',
#   'be',
#   ':',
#   'always',
#   'exclude',
#   'home',
#   'exclude',
#   'work',
#   'exclude',
#   'saved',
#   'locations',
#   'ask',
#   'off'],
#  ['if',
#   'someone',
#   'has',
#   'already',
#   'won',
#   'a',
#   'roadster',
#   'from',
#   'a',
#   'prior',
#   'program',
#   ',',
#   'they’re',
#   'only',
#   'eligible',
#   'to',
#   'win',
#   'the',
#   'signed',
#   'performance',
#   'y'],
#  ['sounds', 'like', 'a', 'good', 'idea'],
#  ['how', 'to', 'win', 'the', 'boss', 'fight', 'in', 'sekiro'],
#  ['no',
#   ',',
#   'it’s',
#   'cumulative',
#   ',',
#   'but',
#   'once',
#   'you',
#   'win',
#   'one',
#   'of',
#   'the',
#   'prizes',
#   ',',
#   'referral',
#   'count',
#   'resets',
#   'to',
#   'zero',
#   '&',
#   'you',
#   'can’t',
#   'win',
#   'that',
#   'prize',
#   'again',
#   '.',
#   'intent',
#   'over',
#   'time',
#   'is',
#   'to',
#   'enable',
#   'those',
#   'without',
#   'a',
#   'massive',
#   'social',
#   'media',
#   'presence',
#   'to',
#   'win',
#   '.'],
#  ['ww'],
#  ['agreed', ',', 'you', 'can', 'only', 'win', 'each', 'prize', 'once'],
#  ['you’re', 'welcome', '!'],
#  ['new',
#   'tesla',
#   'referral',
#   'program',
#   'just',
#   'released',
#   'https',
#   ':',
#   '/',
#   '/',
#   'www',
#   '.',
#   'tesla',
#   '.',
#   'com',
#   '/',
#   'blog',
#   '/',
#   'teslas-ne',
#   'w-customer-referral-program',
#   '?',
#   'redirect',
#   '=',
#   'no',
#   '…'],
#  ['why',
#   'uh',
#   'yes',
#   'we',
#   'comprehensive',
#   'statistics',
#   'that',
#   'go',
#   'deep',
#   '&',
#   'wide'],
#  ['me',
#   'too',
#   '!',
#   'he',
#   'was',
#   'so',
#   'great',
#   '.',
#   'loved',
#   'colbert',
#   'report',
#   'too',
#   '.'],
#  ['jim',
#   'cramer',
#   'explains',
#   'short-seller',
#   'market',
#   'manipulation',
#   'https',
#   ':',
#   '/',
#   '/',
#   'en',
#   '.',
#   'm',
#   '.',
#   'wikipedia',
#   '.',
#   'org',
#   '/',
#   'wiki',
#   '/',
#   'jim_crame',
#   'r',
#   '#market_manipulation',
#   '…'],
#  ['jim', 'can’t', 'take', 'the', 'heat'],
#  ['jim', ',', 'no', 'response', '?'],
#  ['exactly'],
#  ['best',
#   'to',
#   'get',
#   'a',
#   'tesla',
#   'powerwall',
#   ',',
#   'so',
#   'you',
#   'can',
#   'power',
#   'your',
#   'house',
#   '&',
#   'also',
#   'drive'],
#  ['probably',
#   'start',
#   'australia',
#   'builds',
#   'in',
#   'late',
#   'may',
#   'or',
#   'june',
#   '&',
#   'start',
#   'arriving',
#   'in',
#   'winter'],
#  ['coming', 'soon'],
#  ['yes', ',', 'full', 'duration'],
#  ['white-hot',
#   'parts',
#   'reached',
#   'orbital',
#   'entry',
#   'temp',
#   'of',
#   'around',
#   '1650',
#   'kelvin'],
#  ['falcon',
#   'rocket',
#   'booster',
#   'is',
#   'aluminum-lithium',
#   '&',
#   'carbon',
#   'fiber',
#   ',',
#   'which',
#   'have',
#   'low',
#   'max',
#   'temperature',
#   'allowables',
#   '.',
#   'super',
#   'heavy',
#   'booster',
#   'is',
#   'stainless',
#   'steel',
#   '.',
#   'since',
#   'it',
#   'only',
#   'goes',
#   'to',
#   'around',
#   'mach',
#   '8',
#   'or',
#   '9',
#   ',',
#   'moreover',
#   'at',
#   'high',
#   'altitude',
#   ',',
#   'it',
#   'needs',
#   'no',
#   'heat',
#   'shield',
#   ',',
#   'not',
#   'even',
#   'paint',
#   '.'],
#  ['transpiration',
#   'cooling',
#   'will',
#   'be',
#   'added',
#   'wherever',
#   'we',
#   'see',
#   'erosion',
#   'of',
#   'the',
#   'shield',
#   '.',
#   'starship',
#   'needs',
#   'to',
#   'be',
#   'ready',
#   'to',
#   'fly',
#   'again',
#   'immediately',
#   'after',
#   'landing',
#   '.',
#   'zero',
#   'refurbishment',
#   '.'],
#  ['no',
#   'straight',
#   'path',
#   'for',
#   'hot',
#   'gas',
#   'to',
#   'accelerate',
#   'through',
#   'the',
#   'gaps'],
#  ['testing',
#   'starship',
#   'heatshield',
#   'hex',
#   'tiles',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'pyce',
#   '9vthxq'],
#  ['hexagonal',
#   'tiles',
#   'on',
#   'most',
#   'of',
#   'windward',
#   'side',
#   ',',
#   'no',
#   'shield',
#   'needed',
#   'on',
#   'leeward',
#   'side',
#   ',',
#   'transpiration',
#   'cooling',
#   'on',
#   'hotspots'],
#  ['only', 'some', 'of', 'the', 'hottest', 'sections'],
#  ['full', 'size'],
#  ['we',
#   'decided',
#   'to',
#   'skip',
#   'building',
#   'a',
#   'new',
#   'nosecone',
#   'for',
#   'hopper',
#   '.',
#   'don’t',
#   'need',
#   'it',
#   '.',
#   'what',
#   'you',
#   'see',
#   'being',
#   'built',
#   'is',
#   'the',
#   'orbital',
#   'starship',
#   'vehicle',
#   '.'],
#  ['you',
#   'can',
#   'deep',
#   'throttle',
#   'on',
#   'single',
#   'shaft',
#   'system',
#   'by',
#   'choking',
#   'flow',
#   'of',
#   'fuel',
#   'or',
#   'oxygen',
#   'between',
#   'pump',
#   '&',
#   'combustion',
#   'chamber',
#   '.',
#   'problem',
#   'is',
#   'more',
#   'with',
#   'the',
#   'tiny',
#   'rocket',
#   'engine',
#   'that',
#   'powers',
#   'the',
#   'pump',
#   ',',
#   'called',
#   'a',
#   'gas',
#   'generator',
#   '.',
#   'that',
#   'has',
#   'to',
#   'throttle',
#   '*',
#   'way',
#   '*',
#   'deeper',
#   'than',
#   'the',
#   'main',
#   'chamber',
#   '.'],
#  ['working',
#   'on',
#   'regulatory',
#   'approval',
#   'for',
#   'both',
#   'boca',
#   'chica',
#   ',',
#   'texas',
#   ',',
#   'and',
#   'cape',
#   'kennedy',
#   ',',
#   'florida',
#   '.',
#   'will',
#   'also',
#   'be',
#   'building',
#   'starship',
#   '&',
#   'super',
#   'heavy',
#   'simultaneously',
#   'in',
#   'both',
#   'locations',
#   '.'],
#  ['agreed'],
#  ['raptor',
#   'is',
#   '*',
#   'very',
#   '*',
#   'complex',
#   ',',
#   'even',
#   'for',
#   'a',
#   'staged',
#   'combustion',
#   'engine',
#   '.',
#   'we’re',
#   'simplifying',
#   'as',
#   'much',
#   'as',
#   'possible',
#   'with',
#   'each',
#   'iteration',
#   '.',
#   'throttling',
#   'down',
#   'to',
#   '~',
#   '50',
#   '%',
#   'is',
#   'hard',
#   ',',
#   'but',
#   'manageable',
#   '.',
#   'going',
#   'to',
#   '25',
#   '%',
#   'would',
#   'be',
#   'extremely',
#   'tough',
#   ',',
#   'but',
#   'hopefully',
#   'not',
#   'needed',
#   '.'],
#  ['started',
#   'rolling',
#   'it',
#   'out',
#   'a',
#   'few',
#   'days',
#   'ago',
#   '.',
#   'always',
#   'starts',
#   'slow',
#   ',',
#   'find',
#   'rare',
#   'corner',
#   'case',
#   'issues',
#   ',',
#   'fix',
#   'them',
#   ',',
#   'continue',
#   'rollout',
#   '…'],
#  ['hopefully',
#   '.',
#   'always',
#   'many',
#   'issues',
#   'integrating',
#   'engine',
#   '&',
#   'stage',
#   '.',
#   'first',
#   'hops',
#   'will',
#   'lift',
#   'off',
#   ',',
#   'but',
#   'only',
#   'barely',
#   '.'],
#  ['first',
#   '(',
#   'really',
#   'short',
#   ')',
#   'hops',
#   'with',
#   'one',
#   'engine',
#   '.',
#   'suborbital',
#   'flights',
#   'with',
#   'three',
#   '.'],
#  ['goes', 'against', 'interests', 'of', 'all', 'texans'],
#  ['wow', ',', 'this', 'is', 'crazy'],
#  ['if',
#   'someone',
#   'really',
#   'wants',
#   'to',
#   'return',
#   'the',
#   'car',
#   'in',
#   'good',
#   'faith',
#   'on',
#   'day',
#   '8',
#   ',',
#   'that’s',
#   'fine'],
#  ['to',
#   'be',
#   'clear',
#   ',',
#   'orders',
#   'are',
#   'fully',
#   'refundable',
#   ',',
#   'even',
#   'after',
#   'you’ve',
#   'had',
#   'your',
#   'tesla',
#   'for',
#   'a',
#   'week'],
#  ['reminder',
#   'to',
#   'buy',
#   'our',
#   's3xy',
#   'cars',
#   'before',
#   'midnight',
#   'on',
#   'monday',
#   '!',
#   'prices',
#   'rise',
#   'slightly',
#   'worldwide',
#   'on',
#   'tuesday',
#   '.',
#   'you',
#   'can',
#   'order',
#   'online',
#   'at',
#   'http',
#   ':',
#   '/',
#   '/',
#   'tesla',
#   '.',
#   'com',
#   '.'],
#  ['yes', '!'],
#  ['definitely',
#   'down',
#   'the',
#   'road',
#   ',',
#   'once',
#   'construction',
#   '&',
#   'upgrades',
#   'aren’t',
#   'so',
#   'crazy'],
#  ['this',
#   'causes',
#   'some',
#   'media',
#   'confusion',
#   ',',
#   'as',
#   'batch',
#   'builds',
#   '&',
#   'ship',
#   'arrival',
#   'times',
#   'can',
#   'make',
#   'our',
#   'sales',
#   'seem',
#   'incredible',
#   'one',
#   'month',
#   '&',
#   'terrible',
#   'following',
#   'month',
#   ',',
#   'but',
#   'consumer',
#   'tastes',
#   'don’t',
#   'actually',
#   'vary',
#   'so',
#   'much',
#   '.',
#   'massive',
#   'month',
#   'over',
#   'month',
#   'changes',
#   'are',
#   'usually',
#   'because',
#   'of',
#   'production',
#   '/',
#   'shipping',
#   'schedules',
#   '.'],
#  ['not',
#   'exactly',
#   'same',
#   'time',
#   ',',
#   'as',
#   'countries',
#   'have',
#   'different',
#   'regulations',
#   '&',
#   'we',
#   'try',
#   'to',
#   'build',
#   'in',
#   'batches',
#   'to',
#   'simplify',
#   'production'],
#  ['might',
#   'arrive',
#   'by',
#   'june',
#   ',',
#   'but',
#   'def',
#   'before',
#   'end',
#   'of',
#   'summer'],
#  ['model',
#   '3',
#   'partial',
#   'permanent',
#   'magnet',
#   'induction',
#   'motor',
#   ',',
#   'especially',
#   'with',
#   'silicon',
#   'carbide',
#   'inverter',
#   ',',
#   'is',
#   'so',
#   'efficient',
#   'that',
#   'it',
#   'outdoes',
#   'two',
#   'induction',
#   'motors',
#   '.',
#   'if',
#   'we',
#   'could',
#   'decouple',
#   'forward',
#   'induction',
#   'motor',
#   'to',
#   'avoid',
#   'spin',
#   'losses',
#   ',',
#   'then',
#   'range',
#   'of',
#   'dual',
#   'might',
#   'be',
#   'higher',
#   ',',
#   'but',
#   'that’s',
#   'a',
#   'lot',
#   'of',
#   'complexity',
#   '.'],
#  ['exactly',
#   '!',
#   'in',
#   'fact',
#   ',',
#   'better',
#   'to',
#   'have',
#   'rwd',
#   'with',
#   'winter',
#   'tires',
#   'than',
#   'awd',
#   'with',
#   'summer',
#   'tires',
#   '.',
#   'we',
#   'appreciate',
#   'the',
#   'extra',
#   'expenditure',
#   'if',
#   'people',
#   'do',
#   'buy',
#   'awd',
#   ',',
#   'but',
#   'it',
#   'isn’t',
#   'critical',
#   'for',
#   'snowy',
#   'regions',
#   '.'],
#  ['still',
#   'get',
#   'this',
#   'question',
#   'a',
#   'lot',
#   ',',
#   'even',
#   'though',
#   'norway',
#   'has',
#   'highest',
#   'tesla',
#   'cars',
#   'per',
#   'person',
#   'on',
#   '(',
#   'super',
#   'appreciated',
#   '!',
#   ')',
#   '.',
#   'also',
#   ',',
#   'awd',
#   'is',
#   'nice',
#   'to',
#   'have',
#   ',',
#   'but',
#   'def',
#   'not',
#   'required',
#   'for',
#   'snow',
#   '/',
#   'ice',
#   '.'],
#  ['about',
#   'a',
#   'minute',
#   'in',
#   ',',
#   'we',
#   'flashed',
#   'a',
#   'teaser',
#   'pic',
#   'of',
#   'tesla',
#   'cyberpunk',
#   'truck',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'hlsgsdyuga'],
#  ['end',
#   'titles',
#   'from',
#   'blade',
#   'runner',
#   'played',
#   'after',
#   'model',
#   'y',
#   'webcast',
#   'cut',
#   'https',
#   ':',
#   '/',
#   '/',
#   'm',
#   '.',
#   'youtube',
#   '.',
#   'com',
#   '/',
#   'watch',
#   '?',
#   'v',
#   '=',
#   'jawo',
#   '7d',
#   'pufum',
#   '…'],
#  ['designed',
#   'to',
#   'feel',
#   'much',
#   'bigger',
#   'on',
#   'inside',
#   'than',
#   'it',
#   'looks',
#   'on',
#   'outside',
#   '.',
#   'an',
#   'incredibly',
#   'important',
#   'principle',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'tesla',
#   '/',
#   'status',
#   '/',
#   '1',
#   '106429722378956801',
#   '…'],
#  ['there', 'was', 'something', ',', 'but', 'no', 'one', 'caught', 'it'],
#  ['it',
#   'also',
#   'feels',
#   'way',
#   'bigger',
#   'on',
#   'the',
#   'inside',
#   'than',
#   'it',
#   'appears',
#   'on',
#   'the',
#   'outside'],
#  ['would',
#   'love',
#   'to',
#   'be',
#   'there',
#   'this',
#   'year',
#   '.',
#   'if',
#   'not',
#   ',',
#   'definitely',
#   'next',
#   '!',
#   'india'],
#  ['yeah', 'pic', '.', 'twitter', '.', 'com', '/', 'bwvurctxc', '0'],
#  ['pic', '.', 'twitter', '.', 'com', '/', 'j3jyxghwdi'],
#  ['exactly', '!'],
#  ['london',
#   'to',
#   'beijing',
#   'supercharger',
#   'route',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'technosucks',
#   '/',
#   'st',
#   'atus',
#   '/',
#   '1106401863535075328',
#   '…'],
#  ['worth',
#   'watching',
#   'revenge',
#   'of',
#   'the',
#   'electric',
#   'car',
#   '.',
#   'covers',
#   'rebirth',
#   'of',
#   'electric',
#   'cars',
#   'in',
#   'general',
#   '.',
#   'has',
#   'footage',
#   'before',
#   '&',
#   'after',
#   'we',
#   'started',
#   'production',
#   'of',
#   'our',
#   'first',
#   'car',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'm',
#   '.',
#   'youtube',
#   '.',
#   'com',
#   '/',
#   'watch',
#   '?',
#   'v',
#   '=',
#   'ru89x1',
#   'jmpq',
#   '4',
#   '…'],
#  ['the', 'hardest', 'joke', 'ever'],
#  ['with', 'pie'],
#  ['long-term',
#   ',',
#   'it’s',
#   'about',
#   'coupling',
#   'the',
#   'collective',
#   'will',
#   'of',
#   'humanity',
#   'to',
#   'ai',
#   '.',
#   'short-term',
#   ',',
#   'it’s',
#   'about',
#   'improving',
#   'the',
#   'lives',
#   'of',
#   'those',
#   'with',
#   'brain',
#   'or',
#   'spine',
#   'problems',
#   '.'],
#  ['next',
#   'software',
#   'update',
#   'will',
#   'increase',
#   'storm',
#   'watch',
#   'sensitivity',
#   '.',
#   'you’re',
#   'right',
#   ',',
#   'it’s',
#   'currently',
#   'too',
#   'low',
#   '.'],
#  ['checking', 'into', 'this'],
#  ['s3xy', 'pic', '.', 'twitter', '.', 'com', '/', '3ectkel2bh'],
#  ['ota'],
#  ['plug', 'in', 'a', 'usb', 'drive', 'to', 'record', 'video'],
#  ['comes',
#   'with',
#   '2019',
#   '.',
#   '8',
#   ',',
#   'which',
#   'finishes',
#   'validation',
#   'this',
#   'week'],
#  ['looking',
#   'forward',
#   'to',
#   'building',
#   'a',
#   'boring',
#   'company',
#   'tunnel',
#   'in',
#   'vegas',
#   '.',
#   'assuming',
#   'to',
#   'be',
#   'operational',
#   'by',
#   'end',
#   'of',
#   'year',
#   '!',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'boringcompany',
#   '/',
#   'status',
#   '/',
#   '1103428015030181888',
#   '…'],
#  ['yes'],
#  ['our',
#   '“',
#   'list',
#   '”',
#   'prices',
#   'are',
#   'our',
#   'actual',
#   'prices',
#   '.',
#   'software',
#   '(',
#   'and',
#   'automotive',
#   ')',
#   'vary',
#   'prices',
#   'frequently',
#   'by',
#   'changing',
#   'the',
#   'discount',
#   'or',
#   'rebate',
#   '.'],
#  ['sure', ',', 'that', 'would', 'be', 'great'],
#  ['sure'],
#  ['correct'],
#  ['that’s', 'the', 'plan'],
#  ['of', 'course'],
#  ['6'],
#  ['in',
#   'retrospect',
#   ',',
#   'lower',
#   'price',
#   'shouldn’t',
#   'have',
#   'been',
#   'offered',
#   '.',
#   'was',
#   'done',
#   'so',
#   'because',
#   'some',
#   'simply',
#   'couldn’t',
#   'afford',
#   'it',
#   '.',
#   'prices',
#   'revert',
#   'to',
#   'normal',
#   'on',
#   'monday',
#   '.'],
#  ['however',
#   ',',
#   'this',
#   'obviously',
#   'cannot',
#   'be',
#   'discussed',
#   'with',
#   'entire',
#   'global',
#   'stores',
#   'team',
#   'beforehand',
#   'or',
#   'news',
#   'would',
#   'leak'],
#  ['we',
#   'are',
#   'still',
#   'closing',
#   'stores',
#   ',',
#   'just',
#   'not',
#   'as',
#   'many',
#   'as',
#   'before',
#   '.',
#   'this',
#   'basically',
#   'splits',
#   'the',
#   'difference',
#   '—',
#   'about',
#   'half',
#   'as',
#   'many',
#   'stores',
#   'closed',
#   ',',
#   'but',
#   'then',
#   'can',
#   'afford',
#   'only',
#   'about',
#   'half',
#   'the',
#   'price',
#   'reduction',
#   '.',
#   'was',
#   'discussed',
#   'with',
#   'exec',
#   'team',
#   '&',
#   'board',
#   '.'],
#  ['when',
#   'prices',
#   'go',
#   'down',
#   ',',
#   'those',
#   'who',
#   'already',
#   'bought',
#   'want',
#   'the',
#   'lower',
#   'price',
#   ',',
#   'but',
#   ',',
#   'if',
#   'prices',
#   'go',
#   'up',
#   ',',
#   'those',
#   'who',
#   'already',
#   'bought',
#   'don’t',
#   'want',
#   'to',
#   'write',
#   'tesla',
#   'a',
#   'check',
#   '.',
#   'so',
#   'it',
#   'goes',
#   '.'],
#  ['yes'],
#  ['those', 'prices', 'will', 'revert', 'to', 'normal', 'on', 'monday', 'too'],
#  ['applies', 'worldwide'],
#  ['yes'],
#  ['tesla',
#   'car',
#   'prices',
#   'go',
#   'up',
#   '~',
#   '3',
#   '%',
#   'next',
#   'week',
#   ',',
#   'except',
#   'for',
#   '$',
#   '35k',
#   'model',
#   '3',
#   '.',
#   'order',
#   'online',
#   'at',
#   'http',
#   ':',
#   '/',
#   '/',
#   'tesla',
#   '.',
#   'com',
#   'before',
#   'then',
#   'for',
#   'current',
#   'prices',
#   '.'],
#  ['couldn’t',
#   'resolve',
#   'all',
#   'the',
#   'rights',
#   'issues',
#   '.',
#   'will',
#   'add',
#   'another',
#   'racing',
#   'game',
#   'soon',
#   '.'],
#  ['ok'],
#  ['yeah', ',', 'it', 'might', 'break'],
#  ['software',
#   'release',
#   'later',
#   'this',
#   'week',
#   'should',
#   'make',
#   'it',
#   'better'],
#  ['2'],
#  ['true', '(', 'sigh', ')'],
#  ['true'],
#  ['probably',
#   'right',
#   '.',
#   'starship',
#   'rate',
#   'of',
#   'progress',
#   'far',
#   'exceeds',
#   'falcon',
#   '&',
#   'dragon',
#   ',',
#   'although',
#   'they’re',
#   'critical',
#   'to',
#   'getting',
#   'there',
#   '.',
#   'dinnovation',
#   '/',
#   'dt',
#   'is',
#   'what',
#   'matters',
#   'long-term',
#   '.'],
#  ['for',
#   'cargo',
#   'missions',
#   ',',
#   'propulsive',
#   'land',
#   'landing',
#   'should',
#   'be',
#   'no',
#   'problem',
#   '.',
#   'doesn’t',
#   'have',
#   'same',
#   'safety',
#   'criticality',
#   'as',
#   'crew',
#   '.'],
#  ['pretty',
#   'much',
#   'any',
#   'moon',
#   'or',
#   'planet',
#   'that',
#   'has',
#   'a',
#   'solid',
#   'or',
#   'liquid',
#   'surface'],
#  ['most',
#   'likely',
#   ',',
#   'but',
#   'this',
#   'is',
#   'contingent',
#   'upon',
#   'nasa',
#   'review',
#   '&',
#   'approval'],
#  ['best',
#   'to',
#   'use',
#   'a',
#   'giant',
#   'brake',
#   'pad',
#   ',',
#   'aka',
#   'heat',
#   'shield'],
#  ['no'],
#  ['dragon',
#   '2',
#   'was',
#   'designed',
#   'to',
#   'land',
#   'using',
#   'thrusters',
#   ',',
#   'with',
#   'parachutes',
#   'as',
#   'backup',
#   '.',
#   'switched',
#   'to',
#   'chutes',
#   'as',
#   'primary',
#   ',',
#   'due',
#   'to',
#   'difficulty',
#   'of',
#   'proving',
#   'safety',
#   ',',
#   'but',
#   'dragon',
#   'can',
#   'still',
#   'do',
#   'it',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'm',
#   '.',
#   'youtube',
#   '.',
#   'com',
#   '/',
#   'watch',
#   '?',
#   'v',
#   '=',
#   '07pm8z',
#   'y0xji',
#   '…'],
#  ['pic', '.', 'twitter', '.', 'com', '/', 'jobxdo', '3zwh'],
#  ['27', ',', '000', 'km', '/', 'h'],
#  ['raptor',
#   'on',
#   'way',
#   'to',
#   'hopper',
#   '.',
#   'will',
#   'be',
#   'mounted',
#   'to',
#   'vehicle',
#   'next',
#   'week',
#   '.'],
#  ['nk', '-', '33', '&', 'rd', '170', '/', '180', 'are', 'exceptional'],
#  ['thank',
#   'you',
#   'on',
#   'behalf',
#   'of',
#   'spacex',
#   '!',
#   'we',
#   'have',
#   'always',
#   'admired',
#   'your',
#   'rocket',
#   '/',
#   'spacecraft',
#   'technology',
#   '.'],
#  ['thank', 'you', 'on', 'behalf', 'of', 'the', 'people', 'of', 'spacex', '!'],
#  ['all',
#   'good',
#   ',',
#   'system',
#   'maintained',
#   'room',
#   'temperature',
#   'within',
#   'spacecraft'],
#  ['phenolic', 'impregnated', 'carbon', 'ablator', ',', 'version', '3'],
#  ['atmospheric',
#   'entry',
#   'at',
#   '17',
#   ',',
#   '000',
#   'mph',
#   'is',
#   'like',
#   'a',
#   'meteor',
#   '&',
#   'will',
#   'vaporize',
#   'steel',
#   '.',
#   'burn',
#   'marks',
#   'below',
#   'are',
#   'on',
#   'cold',
#   'side',
#   '.',
#   'main',
#   'heatshield',
#   'on',
#   'bottom',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'spacex',
#   '/',
#   'status',
#   '/',
#   '1104032250495004673',
#   '…'],
#  ['yes', ',', 'invitations', 'go', 'out', 'tomorrow'],
#  ['getting',
#   'rid',
#   'of',
#   'peak',
#   'power',
#   'splitting',
#   'across',
#   'two',
#   'bays',
#   '&',
#   'updated',
#   'software',
#   'with',
#   'battery',
#   'warmup',
#   'results',
#   'in',
#   '>',
#   '2x',
#   'improvement',
#   'in',
#   'fleet',
#   'charge',
#   'time'],
#  ['we',
#   'will',
#   'spend',
#   '3',
#   'or',
#   '6',
#   'months',
#   'with',
#   'public',
#   'beta',
#   'of',
#   'v3',
#   'in',
#   'north',
#   'america',
#   ',',
#   'make',
#   'sure',
#   'there',
#   'are',
#   'no',
#   'corner',
#   'case',
#   'issues',
#   '&',
#   'then',
#   'begin',
#   'buildout',
#   'worldwide',
#   '.'],
#  ['those',
#   'improvements',
#   'are',
#   'independent',
#   'of',
#   'supercharger',
#   'v3',
#   'power',
#   'increase',
#   'from',
#   '135kw',
#   'to',
#   '250',
#   '+',
#   'kw',
#   '.',
#   'all',
#   'factors',
#   'considered',
#   ',',
#   'charge',
#   'time',
#   'will',
#   'drop',
#   'by',
#   'factor',
#   'of',
#   '4',
#   'best',
#   'case',
#   '&',
#   'more',
#   'than',
#   '2',
#   'for',
#   'whole',
#   'tesla',
#   'fleet',
#   '.',
#   'effectively',
#   ',',
#   'this',
#   'more',
#   'than',
#   'doubles',
#   'total',
#   'ww',
#   'supercharger',
#   'system',
#   'throughput',
#   '.'],
#  ['latest',
#   'software',
#   'improves',
#   'tesla',
#   'supercharger',
#   'times',
#   'by',
#   'up',
#   'to',
#   '25',
#   '%',
#   'for',
#   'all',
#   'tesla',
#   's',
#   '/',
#   'x',
#   '/',
#   '3',
#   'worldwide',
#   ',',
#   'incl',
#   'original',
#   '2012',
#   'model',
#   's',
#   '.',
#   'not',
#   'splitting',
#   'power',
#   'across',
#   '2',
#   'supercharger',
#   'stalls',
#   'helps',
#   'all',
#   'cars',
#   'up',
#   'to',
#   '50',
#   '%',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'alandbru',
#   '/',
#   'statu',
#   's',
#   '/',
#   '1103760956830691328',
#   '…'],
#  ['so', 'true'],
#  ['extremely',
#   'important',
#   'merch',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   '3zuin7kzyk'],
#  ['net',
#   'power',
#   'to',
#   'warm',
#   'pack',
#   'is',
#   'especially',
#   'low',
#   'when',
#   'motors',
#   'are',
#   'running',
#   ',',
#   'as',
#   'coolant',
#   'loop',
#   'routes',
#   'motor',
#   'heat',
#   'to',
#   'the',
#   'pack',
#   'when',
#   'outside',
#   'is',
#   'cold',
#   '(',
#   '&',
#   'rejects',
#   'motor',
#   'heat',
#   'to',
#   'air',
#   'when',
#   'outside',
#   'is',
#   'warm',
#   ')'],
#  ['yes',
#   ',',
#   'but',
#   'an',
#   'engine',
#   'shouldn’t',
#   'count',
#   'until',
#   'it',
#   'flies'],
#  ['ukraine', 'did', 'play', 'a', 'major', 'role'],
#  ['very',
#   'little',
#   'power',
#   '&',
#   'only',
#   'right',
#   'before',
#   'you',
#   'get',
#   'to',
#   'the',
#   'supercharger',
#   '.',
#   'you',
#   'won’t',
#   'notice',
#   'it',
#   'in',
#   'range',
#   '.'],
#  ['if',
#   'you',
#   'navigate',
#   'to',
#   'supercharger',
#   ',',
#   'car',
#   'will',
#   'warm',
#   'up',
#   'battery',
#   'en',
#   'route',
#   ',',
#   'so',
#   'you',
#   'start',
#   'immediately',
#   'at',
#   'max',
#   'power'],
#  ['russia',
#   'has',
#   'excellent',
#   'rocket',
#   'engineering',
#   '&',
#   'best',
#   'engine',
#   'currently',
#   'flying',
#   '.',
#   'reusable',
#   'version',
#   'of',
#   'their',
#   'new',
#   'angara',
#   'rocket',
#   'would',
#   'be',
#   'great',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'arstechnica',
#   '.',
#   'com',
#   '/',
#   'science',
#   '/',
#   '2019',
#   '/',
#   '0',
#   '3',
#   '/',
#   'with-dragon-russian-critic-says-roscosmos-acting-left-behind',
#   '/',
#   '…'],
#  ['thanks', ',', 'that', 'sounds', 'great', '!'],
#  ['you’re',
#   'most',
#   'welcome',
#   '.',
#   'very',
#   'proud',
#   'of',
#   'tesla',
#   'team',
#   '.',
#   'super',
#   'tough',
#   '15',
#   'years',
#   '!'],
#  ['oh', 'stop', ',', 'you’ll', 'make', 'me', 'blush'],
#  ['ok'],
#  ['yeah',
#   ',',
#   'i',
#   'lift',
#   'a',
#   'little',
#   '…',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'uajdv',
#   '8qsw1'],
#  ['pic', '.', 'twitter', '.', 'com', '/', 'aazjdynxzc'],
#  ['tesla', 'comms', 'is', 'fixing', '.', 'that', 'was', 'a', 'mistake', '.'],
#  ['so', 'cute', '!'],
#  ['buddy', 'is', 'like', 'an', 'earth', 'pok', 'émon'],
#  ['gap',
#   'in',
#   'understanding',
#   'is',
#   'that',
#   '$',
#   '35k',
#   'model',
#   '3',
#   'production',
#   '*',
#   'starts',
#   '*',
#   'this',
#   'month',
#   ',',
#   'but',
#   'will',
#   'not',
#   'reach',
#   'volume',
#   'production',
#   'until',
#   'mid',
#   'year',
#   '.',
#   'extremely',
#   'difficult',
#   'to',
#   'predict',
#   'middle',
#   'part',
#   'of',
#   'manufacturing',
#   's-curve',
#   '.'],
#  ['yes'],
#  ['pic', '.', 'twitter', '.', 'com', '/', 'ohmzifvrn', '5'],
#  ['no',
#   ',',
#   'just',
#   'literally',
#   'having',
#   'toast',
#   '&',
#   'jam',
#   'while',
#   'playing',
#   'jamming'],
#  ['having',
#   'toast',
#   '&',
#   'jam',
#   'in',
#   'kitchen',
#   'while',
#   'playing',
#   'jamming',
#   'by',
#   'bob',
#   'marley'],
#  ['yes',
#   '.',
#   'personally',
#   ',',
#   'i’m',
#   'most',
#   'excited',
#   'by',
#   'the',
#   'tesla',
#   'truck',
#   '.',
#   'maybe',
#   'it',
#   'will',
#   'be',
#   'too',
#   'futuristic',
#   'for',
#   'most',
#   'people',
#   ',',
#   'but',
#   'i',
#   'love',
#   'it',
#   '.'],
#  ['yes', ',', 'anyone', 'will', 'be', 'able', 'to', 'take', 'videos'],
#  ['i', 'believe', 'so'],
#  ['no', ',', 'that', 'unveil', 'is', 'later', 'this', 'year'],
#  ['slightly',
#   'higher',
#   'drag',
#   '*',
#   'slightly',
#   'higher',
#   'frontal',
#   'area',
#   'affects',
#   'air',
#   'friction',
#   '&',
#   'mass',
#   'affects',
#   'rolling',
#   'resistance',
#   '&',
#   'hill',
#   'climb',
#   '.',
#   'physics',
#   'is',
#   'the',
#   'law',
#   '.'],
#  ['normal'],
#  ['yes'],
#  ['detailed',
#   'specs',
#   '&',
#   'pricing',
#   'will',
#   'be',
#   'provided',
#   ',',
#   'as',
#   'well',
#   'as',
#   'test',
#   'rides',
#   'in',
#   'y'],
#  ['model',
#   'y',
#   ',',
#   'being',
#   'an',
#   'suv',
#   ',',
#   'is',
#   'about',
#   '10',
#   '%',
#   'bigger',
#   'than',
#   'model',
#   '3',
#   ',',
#   'so',
#   'will',
#   'cost',
#   'about',
#   '10',
#   '%',
#   'more',
#   '&',
#   'have',
#   'slightly',
#   'less',
#   'range',
#   'for',
#   'same',
#   'battery'],
#  ['model',
#   'y',
#   'unveil',
#   'event',
#   'on',
#   'march',
#   '14',
#   'at',
#   'la',
#   'design',
#   'studio'],
#  ['first',
#   'public',
#   'tesla',
#   'v3',
#   '.',
#   '0',
#   'supercharger',
#   'station',
#   'goes',
#   'live',
#   'wed',
#   '8pm'],
#  ['спасибо', 'за', 'добрые', 'слова', '!'],
#  ['spacex',
#   'team',
#   'in',
#   'hawthorne',
#   'control',
#   ',',
#   'dragon',
#   'docked',
#   'to',
#   'station',
#   'above',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'juwkorwjsh'],
#  ['spacex',
#   'crew',
#   'dragon',
#   'has',
#   'docked',
#   'with',
#   'international',
#   '@space_station',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'cccsitllvj'],
#  ['yes', ',', 'she', 'would', 'be', 'able', 'to', 'breathe'],
#  ['proximity',
#   'docking',
#   'sequence',
#   'underway',
#   '.',
#   'dragon',
#   'shadow',
#   'visible',
#   'on',
#   'on',
#   '@space_station',
#   'solar',
#   'arrays',
#   '.',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'elsxglivf',
#   '0'],
#  ['one',
#   'day',
#   'we',
#   'will',
#   'be',
#   'there',
#   'to',
#   'see',
#   'for',
#   'ourselves',
#   'https',
#   ':',
#   '/',
#   '/',
#   'm',
#   '.',
#   'youtube',
#   '.',
#   'com',
#   '/',
#   'watch',
#   '?',
#   'v',
#   '=',
#   'gbxion',
#   'sjmky',
#   '…'],
#  ['69f'],
#  ['something', 'like', 'this', 'could', 'work'],
#  ['everyone', 'knows', 'earth', 'is', 'hollow'],
#  ['i',
#   'am',
#   'not',
#   'a',
#   'dog',
#   '.',
#   'here’s',
#   'a',
#   'pic',
#   'of',
#   'me',
#   ':',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'huy',
#   '6yrydnc'],
#  ['model', 's', 'will', 'be', 'raised', 'to', '162mph', 'too'],
#  ['thank',
#   'you',
#   '.',
#   'may',
#   'you',
#   'have',
#   'good',
#   'luck',
#   'and',
#   'godspeed',
#   'with',
#   'your',
#   'spacecraft',
#   '!'],
#  ['thank',
#   'you',
#   'on',
#   'behalf',
#   'of',
#   'spacex',
#   '.',
#   'also',
#   ',',
#   'thank',
#   'you',
#   'to',
#   '@nasa',
#   ',',
#   'without',
#   'whom',
#   'this',
#   'would',
#   'not',
#   'be',
#   'possible',
#   '.'],
#  ['power',
#   'will',
#   'increase',
#   'on',
#   'all',
#   'cars',
#   '.',
#   'top',
#   'speed',
#   'on',
#   '3p',
#   'increases',
#   'to',
#   '162mph',
#   '.',
#   'range',
#   'on',
#   'rwd',
#   '3',
#   'increases',
#   'to',
#   '325',
#   'miles',
#   '.'],
#  ['yes', ',', 'new', 'cars', 'and', 'existing', 'fleet'],
#  ['firmware',
#   'update',
#   'coming',
#   'later',
#   'this',
#   'month',
#   'will',
#   'increase',
#   'power',
#   'by',
#   '~',
#   '5',
#   '%',
#   '&',
#   'top',
#   'speed',
#   'by',
#   '10',
#   'km',
#   '/',
#   'h',
#   'or',
#   '7mph'],
#  ['spoiler', 'alert', ':', 'not', 'porsche'],
#  ['thank',
#   'you',
#   'on',
#   'behalf',
#   'of',
#   'the',
#   'many',
#   'people',
#   'of',
#   'spacex'],
#  ['lightning', 'bolt', 'right', 'before', 'launch'],
#  ['earth',
#   'floats',
#   'gently',
#   'in',
#   'zero',
#   'gravity',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'xuh',
#   '3kedpve'],
#  ['spacex',
#   'crew',
#   'dragon',
#   'recap',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'i',
#   '/',
#   'events',
#   '/',
#   '11017',
#   '31517045268481',
#   '…'],
#  ['need',
#   'to',
#   'get',
#   'back',
#   'to',
#   'spacex',
#   'launch',
#   'control',
#   '.',
#   'sorry',
#   'this',
#   'solution',
#   'isn’t',
#   'perfect',
#   '.'],
#  ['we’re',
#   'trying',
#   'to',
#   'make',
#   'evs',
#   '&',
#   'autonomy',
#   'more',
#   'affordable',
#   'over',
#   'time',
#   '.',
#   'this',
#   'is',
#   'the',
#   'right',
#   'thing',
#   'to',
#   'do',
#   '.',
#   'however',
#   ',',
#   'we',
#   'cannot',
#   'then',
#   'also',
#   'retroactively',
#   'make',
#   'earlier',
#   'buyers',
#   'whole',
#   'without',
#   'killing',
#   'the',
#   'company',
#   '.'],
#  ['will', 'take', 'a', 'few', 'days', 'for', 'system', 'update'],
#  ['yeah',
#   ',',
#   'we',
#   'need',
#   'a',
#   'few',
#   'days',
#   'to',
#   'update',
#   'the',
#   'system',
#   '.',
#   'if',
#   'anyone',
#   'already',
#   'paid',
#   '$',
#   '3k',
#   ',',
#   'they',
#   'should',
#   'get',
#   '$',
#   '1k',
#   'back',
#   '.'],
#  ['it’s',
#   'not',
#   'exactly',
#   'symmetric',
#   ',',
#   'but',
#   'it',
#   'will',
#   'come',
#   'with',
#   'hw3',
#   'upgrade',
#   'long-term'],
#  ['if',
#   'you',
#   'bought',
#   'enhanced',
#   'autopilot',
#   ',',
#   'fsd',
#   'upgrade',
#   'costs',
#   '$',
#   '2k',
#   'instead',
#   'of',
#   '$',
#   '5k'],
#  ['if',
#   'you',
#   'bought',
#   'a',
#   'tesla',
#   'before',
#   'yesterday’s',
#   'price',
#   'reduction',
#   ',',
#   'you',
#   'can',
#   'have',
#   'autopilot',
#   'or',
#   'full',
#   'self-driving',
#   'at',
#   'half',
#   'normal',
#   'cost',
#   '(',
#   'up',
#   'to',
#   '$',
#   '6k',
#   'less',
#   ')',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'tesla',
#   '/',
#   'status',
#   '/',
#   '1',
#   '101721765707825152',
#   '…'],
#  ['he', 'is', 'the', 'sensor', '!'],
#  ['nope',
#   ',',
#   'he’s',
#   'going',
#   'to',
#   'float',
#   'around',
#   'in',
#   'zero',
#   'gravity'],
#  ['super',
#   'high',
#   'tech',
#   'zero-g',
#   'indicator',
#   'added',
#   'just',
#   'before',
#   'launch',
#   '!',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'cro',
#   '26plaxq'],
#  ['happy', 'birthday', '!'],
#  ['yeah',
#   ',',
#   'just',
#   'use',
#   'a',
#   'dryer',
#   'outlet',
#   '.',
#   'high',
#   'power',
#   ',',
#   'easy',
#   'to',
#   'install',
#   '&',
#   'low',
#   'cost',
#   '.'],
#  ['explanation', 'from', 'tesla', 'later', 'today'],
#  ['yes'],
#  ['haha'],
#  ['ripley', 'pic', '.', 'twitter', '.', 'com', '/', 'z9ztram8ai'],
#  ['base',
#   'model',
#   '3',
#   'available',
#   'in',
#   'europe',
#   'in',
#   '~',
#   '6',
#   'months',
#   ',',
#   'asia',
#   '6',
#   'to',
#   '8',
#   'months',
#   '.',
#   'latter',
#   'contingent',
#   'on',
#   'shanghai',
#   'gigafactory',
#   '.',
#   'country-specific',
#   'taxes',
#   '&',
#   'import',
#   'duties',
#   'mean',
#   'price',
#   'may',
#   'be',
#   '25',
#   '%',
#   'or',
#   'more',
#   'above',
#   'us',
#   'number',
#   '.'],
#  ['exactly'],
#  ['no', 'reductions', 'from', 'here'],
#  ['for',
#   'sure',
#   '.',
#   'it',
#   'fundamentally',
#   'improves',
#   'quality',
#   'of',
#   'life',
#   '.'],
#  ['best',
#   'choice',
#   'for',
#   'most',
#   'people',
#   'is',
#   'standard',
#   'range',
#   'plus',
#   'with',
#   'autopilot'],
#  ['exact',
#   'tesla',
#   'model',
#   '3',
#   'in',
#   'my',
#   'profile',
#   'pic',
#   'costs',
#   '$',
#   '35k',
#   'before',
#   'incentives',
#   '&',
#   'takes',
#   '1',
#   'minute',
#   'to',
#   'buy',
#   'online',
#   'at',
#   'http',
#   ':',
#   '/',
#   '/',
#   'tesla',
#   '.',
#   'com'],
#  ['i',
#   'think',
#   'we',
#   'should',
#   'do',
#   'something',
#   'here',
#   '.',
#   'will',
#   'talk',
#   'with',
#   'team',
#   '&',
#   'send',
#   'out',
#   'a',
#   'note',
#   'in',
#   'next',
#   'few',
#   'days',
#   '.'],
#  ['should',
#   'be',
#   '~',
#   '5',
#   '%',
#   'peak',
#   'power',
#   'increase',
#   'with',
#   'march',
#   '15',
#   'software',
#   'release'],
#  ['scheduled',
#   'for',
#   'march',
#   '15',
#   'release',
#   ',',
#   'along',
#   'with',
#   'many',
#   'other',
#   'improvements'],
#  ['everyone',
#   'who',
#   'bought',
#   'enhanced',
#   'autopilot',
#   'will',
#   'get',
#   'navigate',
#   'on',
#   'autopilot',
#   'on',
#   'highways',
#   ',',
#   'advanced',
#   'summon',
#   '&',
#   'autopark'],
#  ['i', 'was', 'being', 'too', 'obvious'],
#  ['make', 'the', 'mars', 'technocracy', 'real'],
#  ['yay', '!'],
#  ['et', 'phone', 'home', '.', 'no', 'answer'],
#  ['some', 'tesla', 'news'],
#  ['haha'],
#  ['yes'],
#  ['stop',
#   'censoring',
#   'science',
#   '!',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'r4xetymtnh'],
#  ['because',
#   'it',
#   'costs',
#   '$',
#   '2500',
#   'to',
#   'transport',
#   'to',
#   'east',
#   'coast',
#   '&',
#   'everyone',
#   'pays',
#   'same'],
#  ['california'],
#  ['thursday', '2pm'],
#  ['rest',
#   'of',
#   'spacex',
#   'propulsion',
#   'still',
#   'very',
#   'active',
#   ',',
#   'so',
#   'only',
#   '~',
#   '50',
#   'full-time',
#   'equivalent',
#   'people',
#   'right',
#   'now',
#   '.',
#   'that',
#   'will',
#   'grow',
#   'a',
#   'lot',
#   'as',
#   'we',
#   'enter',
#   'production',
#   '.',
#   'it’s',
#   '10x',
#   'harder',
#   '(',
#   'at',
#   'least',
#   ')',
#   'to',
#   'design',
#   'engine',
#   'production',
#   'system',
#   'than',
#   'engine',
#   '.',
#   'in',
#   'automotive',
#   ',',
#   '100x',
#   'harder',
#   '.'],
#  ['maybe',
#   'active',
#   'in',
#   'a',
#   'month',
#   'or',
#   'so',
#   '.',
#   'focus',
#   'right',
#   'now',
#   'is',
#   'getting',
#   'to',
#   'high',
#   'speed',
#   ',',
#   'tight',
#   'follow',
#   'distance',
#   'in',
#   'test',
#   'tunnel',
#   '.'],
#  ['yes', ',', 'exciting', 'potential'],
#  ['exactly'],
#  ['printers',
#   'are',
#   'too',
#   'small',
#   '.',
#   'also',
#   ',',
#   'high',
#   'pressure',
#   ',',
#   'high',
#   'efficiency',
#   'engines',
#   'need',
#   'copper',
#   'cooling',
#   'channels',
#   'with',
#   'an',
#   'inco',
#   '/',
#   'steel',
#   'jacket',
#   '.',
#   'can’t',
#   'print',
#   'yet',
#   '.'],
#  ['exactly',
#   '.',
#   'this',
#   'has',
#   'now',
#   'happened',
#   'several',
#   'times',
#   '.',
#   'something',
#   'is',
#   'broken',
#   'with',
#   'sec',
#   'oversight',
#   '.'],
#  ['tom',
#   'did',
#   'an',
#   'awesome',
#   'job',
#   'leading',
#   'merlin',
#   ',',
#   'kestrel',
#   ',',
#   'draco',
#   '&',
#   'other',
#   'engine',
#   'developments',
#   'from',
#   'start',
#   'through',
#   '2014',
#   'that',
#   'were',
#   'critical',
#   'to',
#   'spacex’s',
#   'success',
#   '.',
#   'great',
#   'respect',
#   '&',
#   'appreciation',
#   '!'],
#  ['thank', 'you', 'evelyn', ',', 'i', 'loved', 'it'],
#  ['indeed',
#   '.',
#   'i',
#   'have',
#   'great',
#   'respect',
#   'for',
#   'judges',
#   '.',
#   'it’s',
#   'not',
#   'perfect',
#   ',',
#   'but',
#   ',',
#   'in',
#   'general',
#   ',',
#   'we',
#   'should',
#   'be',
#   'very',
#   'glad',
#   'of',
#   'the',
#   'us',
#   'justice',
#   'system',
#   '.'],
#  ['sec',
#   'forgot',
#   'to',
#   'read',
#   'tesla',
#   'earnings',
#   'transcript',
#   ',',
#   'which',
#   'clearly',
#   'states',
#   '350k',
#   'to',
#   '500k',
#   '.',
#   'how',
#   'embarrassing',
#   '…'],
#  ['oh', 'hi', 'lol', 'pic', '.', 'twitter', '.', 'com', '/', '9wvbtthoxs'],
#  ['fate', '*', 'loves', '*', 'irony', '.', 'frankly', ',', 'too', 'much', '.'],
#  ['meetings',
#   'are',
#   'a',
#   'valuable',
#   'use',
#   'of',
#   'time',
#   '!',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'sdckdbp',
#   '5e5'],
#  ['there’s', 'a', 'in', 'my'],
#  ['http', ':', '/', '/', 'stankmemes', '.', 'com'],
#  ['respawn',
#   '+',
#   '+',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'mlagk',
#   '38lkk'],
#  ['great',
#   'meme',
#   'review',
#   'hosted',
#   'by',
#   'will',
#   'smith',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'grandayy',
#   '/',
#   'statu',
#   's',
#   '/',
#   '1099037391669653509',
#   '…'],
#  ['haha', 'true'],
#  ['it’s',
#   'designed',
#   'to',
#   'be',
#   'way',
#   'better',
#   '.',
#   'we’ll',
#   'see',
#   'what',
#   'reality',
#   'has',
#   'to',
#   'say',
#   'about',
#   'that',
#   '.'],
#  ['yes', ',', 'lot', 'of', 'risk'],
#  ['guys', ',', 'i', 'have', 'feelings', '…'],
#  ['focusing', 'on', 'starship', 'instead'],
#  ['deorbits', '&', 'burns', 'up', 'over', 'the', 'pacific'],
#  ['upper',
#   'stage',
#   'is',
#   'flight',
#   ',',
#   'except',
#   'mass',
#   'sim',
#   'in',
#   'place',
#   'of',
#   'merlin',
#   '.',
#   'it',
#   'will',
#   'get',
#   'fragged',
#   'for',
#   'sure',
#   'by',
#   'aero',
#   'loads',
#   '&',
#   'dragon',
#   'abort',
#   'thrusters',
#   '.'],
#  ['including',
#   'heavy',
#   ',',
#   'which',
#   'is',
#   '3',
#   'cores',
#   ',',
#   'around',
#   '20',
#   'or',
#   'so'],
#  ['depends',
#   'on',
#   'when',
#   'crew',
#   'dragon',
#   'comes',
#   'back',
#   '.',
#   'that’s',
#   'scheduled',
#   'for',
#   'launch',
#   'next',
#   'saturday',
#   ',',
#   'but',
#   'lot',
#   'of',
#   'new',
#   'hardware',
#   ',',
#   'so',
#   'time',
#   'error',
#   'bars',
#   'are',
#   'big',
#   '.'],
#  ['high',
#   'probability',
#   'of',
#   'this',
#   'particular',
#   'rocket',
#   'getting',
#   'destroyed',
#   'by',
#   'dragon',
#   'supersonic',
#   'abort',
#   'test',
#   '.',
#   'otherwise',
#   ',',
#   'at',
#   'least',
#   '20',
#   'or',
#   '30',
#   'missions',
#   'for',
#   'falcon',
#   '9',
#   '.',
#   'starship',
#   'will',
#   'take',
#   'over',
#   'before',
#   'the',
#   'f9',
#   'fleet',
#   'reaches',
#   'end',
#   'of',
#   'life',
#   '.'],
#  ['crew', 'dragon', 'high', 'altitude', 'abort', 'test'],
#  ['yes'],
#  ['highest',
#   'reentry',
#   'heating',
#   'to',
#   'date',
#   '.',
# ...
#   'https',
#   ':',
#   '/',
#   '/',
#   'm',
#   '.',
#   'soundcloud',
#   '.',
#   'com',
#   '/',
#   'nickiminaj',
#   '/',
#   'sta',
#   'rships',
#   '-',
#   '1',
#   '…'],
#  ['starship', 'tooters'],
#  ['good', 'one'],
#  ['good', 'idea'],
#  ['coming', 'soon'],
#  ['shifting',
#   'resources',
#   'from',
#   'sales',
#   'to',
#   'service',
#   'for',
#   'next',
#   'several',
#   'days'],
#  ['should', 'be', 'next', 'week'],
#  ['no',
#   ',',
#   'it’s',
#   'the',
#   'first',
#   'or',
#   'boost',
#   'stage',
#   ',',
#   'analogous',
#   'to',
#   ',',
#   'but',
#   'much',
#   'larger',
#   'than',
#   'falcon',
#   '9'],
#  ['later', 'versions', 'will'],
#  ['technically',
#   ',',
#   'two',
#   'parts',
#   ':',
#   'starship',
#   'is',
#   'the',
#   'spaceship',
#   '/',
#   'upper',
#   'stage',
#   '&',
#   'super',
#   'heavy',
#   'is',
#   'the',
#   'rocket',
#   'booster',
#   'needed',
#   'to',
#   'escape',
#   'earth’s',
#   'deep',
#   'gravity',
#   'well',
#   '(',
#   'not',
#   'needed',
#   'for',
#   'other',
#   'planets',
#   'or',
#   'moons',
#   ')'],
#  ['renaming', 'bfr', 'to', 'starship'],
#  ['no', ',', 'we’re', 'just', 'going', 'to', 'accelerate', 'bfr'],
#  ['yes'],
#  ['supercharger',
#   'v3',
#   ',',
#   'which',
#   'starts',
#   'rolling',
#   'out',
#   'early',
#   'next',
#   'year',
#   ',',
#   'will',
#   'also',
#   'charge',
#   'much',
#   'faster'],
#  ['tesla',
#   'supercharger',
#   'capacity',
#   'will',
#   'double',
#   'by',
#   'end',
#   'of',
#   'next',
#   'year',
#   '.',
#   'expect',
#   'to',
#   'be',
#   'within',
#   'range',
#   'of',
#   '95',
#   '%',
#   'to',
#   '100',
#   '%',
#   'of',
#   'population',
#   'in',
#   'all',
#   'active',
#   'markets',
#   '.'],
#  ['no',
#   ',',
#   'it’s',
#   'got',
#   'enough',
#   'load',
#   'capacity',
#   '&',
#   'volume',
#   'to',
#   'carry',
#   'the',
#   'battery',
#   'pack',
#   '&',
#   'our',
#   'current',
#   'pack',
#   'energy',
#   'density',
#   'is',
#   'about',
#   'double',
#   'that',
#   'of',
#   'original',
#   'roadster',
#   '.',
#   'still',
#   ',',
#   'it',
#   'would',
#   'probably',
#   'only',
#   'save',
#   'about',
#   '30',
#   '%',
#   'to',
#   '40',
#   '%',
#   'of',
#   'effort',
#   ',',
#   'all',
#   'things',
#   'considered',
#   '.'],
#  ['in',
#   'order',
#   'of',
#   'resource',
#   'priority',
#   ',',
#   'but',
#   'not',
#   'necessarily',
#   'production',
#   'ramp',
#   ',',
#   'as',
#   'that',
#   'depends',
#   'on',
#   'thousands',
#   'of',
#   'parts',
#   '&',
#   'processes',
#   ',',
#   'which',
#   'are',
#   'extremely',
#   'difficult',
#   'to',
#   'forecast'],
#  ['what',
#   'really',
#   'matters',
#   'is',
#   'time',
#   'to',
#   'volume',
#   'production',
#   ',',
#   'not',
#   'initial',
#   'market',
#   'intro',
#   '.',
#   'apart',
#   'from',
#   'brief',
#   'moments',
#   ',',
#   'tesla',
#   'vehicle',
#   'production',
#   'is',
#   'limited',
#   'by',
#   'total',
#   'battery',
#   'output',
#   '.'],
#  ['lot',
#   'on',
#   'our',
#   'plate',
#   ',',
#   'so',
#   'it’s',
#   'either',
#   'get',
#   'van',
#   'gliders',
#   '(',
#   'no',
#   'battery',
#   ',',
#   'powertrain',
#   'or',
#   'compute',
#   'tech',
#   ')',
#   'from',
#   'daimler',
#   '&',
#   'produce',
#   'sooner',
#   'or',
#   'do',
#   'all',
#   '&',
#   'produce',
#   'later',
#   '.',
#   'not',
#   'a',
#   'big',
#   'difference',
#   'to',
#   'total',
#   'vehicles',
#   'produced',
#   'either',
#   'way',
#   '.',
#   'priority',
#   'list',
#   'is',
#   'model',
#   'y',
#   ',',
#   'solar',
#   'roof',
#   'tiles',
#   ',',
#   'pickup',
#   ',',
#   'semi',
#   ',',
#   'roadster',
#   '.'],
#  ['ok'],
#  ['maybe',
#   'interesting',
#   'to',
#   'work',
#   'with',
#   'daimler',
#   '/',
#   'mercedes',
#   'on',
#   'an',
#   'electric',
#   'sprinter',
#   '.',
#   'that’s',
#   'a',
#   'great',
#   'van',
#   '.',
#   'we',
#   'will',
#   'inquire',
#   '.'],
#  ['absolutely', 'agree'],
#  ['investigating'],
#  ['probably', 'mid', '2019'],
#  ['tesla',
#   'can',
#   'provide',
#   'heating',
#   '/',
#   'cooling',
#   '/',
#   'lights',
#   '/',
#   'music',
#   'for',
#   'days',
#   'using',
#   'battery'],
#  ['not',
#   'everywhere',
#   ',',
#   'but',
#   'should',
#   'be',
#   'possible',
#   'around',
#   'major',
#   'metros',
#   '.',
#   'parts',
#   'supply',
#   'chain',
#   'to',
#   'uk',
#   'should',
#   'be',
#   'fixed',
#   '.',
#   'lmk',
#   'if',
#   'not',
#   '.'],
#  ['should',
#   'be',
#   'possible',
#   '.',
#   'please',
#   'ask',
#   'service',
#   '&',
#   'lmk',
#   'response',
#   '.'],
#  ['no', ',', 'but', 'perhaps', 'in', 'a', 'few', 'years'],
#  ['yeah',
#   ',',
#   'good',
#   'idea',
#   '.',
#   'we',
#   'have',
#   'that',
#   'state',
#   'internally',
#   ',',
#   'so',
#   'can',
#   'push',
#   'data',
#   'to',
#   'phone',
#   'app',
#   '.'],
#  ['haha', ',', 'just', 'like', 'super', 'troopers'],
#  ['ideal',
#   'situation',
#   'in',
#   'breakdown',
#   '/',
#   'accident',
#   '(',
#   'assuming',
#   'no',
#   'injuries',
#   ')',
#   'is',
#   'that',
#   'tesla',
#   'arrives',
#   'at',
#   'scene',
#   'fast',
#   'with',
#   'top-of-the-line',
#   'service',
#   'loaner'],
#  ['will',
#   'allow',
#   'having',
#   'your',
#   'car',
#   'picked',
#   'up',
#   '&',
#   'dropped',
#   'off',
#   'or',
#   'using',
#   'mobile',
#   'tesla',
#   'rangers',
#   'service',
#   'vans',
#   'if',
#   'car',
#   'lift',
#   'isn’t',
#   'needed',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'ntxteslaowners',
#   '/',
#   'status',
#   '/',
#   '1064524502321778688',
#   '…'],
#  ['adding',
#   'functionality',
#   'to',
#   'tesla',
#   'phone',
#   'app',
#   'allowing',
#   'owners',
#   'to',
#   'request',
#   'service',
#   'for',
#   'top',
#   'issues',
#   'with',
#   '1',
#   'or',
#   '2',
#   'taps',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'cjk',
#   '7216',
#   '/',
#   'status',
#   '/',
#   '1057765681108725760',
#   '…'],
#  ['yes',
#   ',',
#   'no',
#   'upgrades',
#   'planned',
#   'for',
#   'f9',
#   '.',
#   'minor',
#   'tweaks',
#   'to',
#   'improve',
#   'reliability',
#   'only',
#   ',',
#   'provided',
#   'nasa',
#   '&',
#   'usaf',
#   'are',
#   'supportive',
#   '.'],
#  ['radical', 'change'],
#  ['btw',
#   ',',
#   'spacex',
#   'is',
#   'no',
#   'longer',
#   'planning',
#   'to',
#   'upgrade',
#   'falcon',
#   '9',
#   'second',
#   'stage',
#   'for',
#   'reusability',
#   '.',
#   'accelerating',
#   'bfr',
#   'instead',
#   '.',
#   'new',
#   'design',
#   'is',
#   'very',
#   'exciting',
#   '!',
#   'delightfully',
#   'counter-intuitive',
#   '.'],
#  ['it',
#   'will',
#   'alert',
#   'tesla',
#   'service',
#   'automatically',
#   'as',
#   'fan',
#   'power',
#   'required',
#   'to',
#   'achieve',
#   'target',
#   'pressure',
#   'drop',
#   'exceeds',
#   'spec',
#   'level'],
#  ['set',
#   'air',
#   'flow',
#   'to',
#   'recirculating',
#   'mode',
#   '&',
#   'manually',
#   'raise',
#   'blower',
#   'speed',
#   'to',
#   '5',
#   'in',
#   'model',
#   '3',
#   'for',
#   'best',
#   'air',
#   'quality',
#   '.',
#   'air',
#   'filters',
#   'are',
#   'smaller',
#   'than',
#   's',
#   '/',
#   'x',
#   ',',
#   'so',
#   'clear',
#   'air',
#   'is',
#   'achieved',
#   'by',
#   'circulating',
#   'through',
#   'filter',
#   'several',
#   'times',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'teslarati',
#   '/',
#   'stat',
#   'us',
#   '/',
#   '1063855556534898689',
#   '…'],
#  ['congratulations',
#   '@boringcompany',
#   'on',
#   'completing',
#   'the',
#   'la',
#   '/',
#   'hawthorne',
#   'tunnel',
#   '!',
#   'cutting',
#   'edge',
#   'technology',
#   '!',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   '80wbsqekcq'],
#  ['pic', '.', 'twitter', '.', 'com', '/', 'tqhb', '9hqrxq'],
#  ['boring',
#   'company',
#   'just',
#   'broke',
#   'through',
#   'the',
#   'other',
#   'side',
#   '!',
#   '!',
#   'https',
#   ':',
#   '/',
#   '/',
#   'm',
#   '.',
#   'soundcloud',
#   '.',
#   'com',
#   '/',
#   'fish-tales',
#   '/',
#   'fis',
#   'her-losing-it',
#   '…'],
#  ['missed', 'miku', 'concert', 'sigh'],
#  ['listening',
#   'to',
#   'better',
#   'now',
#   'https',
#   ':',
#   '/',
#   '/',
#   'open',
#   '.',
#   'spotify',
#   '.',
#   'com',
#   '/',
#   'track',
#   '/',
#   '7dt6x5m1',
#   'jzdtet',
#   '8ocbistk',
#   '?',
#   'si',
#   '=',
#   'fjbrhhxxqnsmsceiwuoxig',
#   '&',
#   'nd',
#   '=',
#   '1',
#   '…'],
#  ['china',
#   ',',
#   'especially',
#   ',',
#   'is',
#   'doing',
#   'an',
#   'amazing',
#   'job',
#   'moving',
#   'towards',
#   'sustainable',
#   'energy',
#   'generation',
#   '&',
#   'transport'],
#  ['sure',
#   'hope',
#   'this',
#   'isn’t',
#   'true',
#   '.',
#   'it',
#   'is',
#   'the',
#   'non-linearities',
#   ',',
#   'such',
#   'as',
#   'siberian',
#   'permafrost',
#   'melting',
#   'or',
#   'ocean',
#   'currents',
#   'changing',
#   ',',
#   'that',
#   'are',
#   'most',
#   'difficult',
#   'to',
#   'predict',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'cleantechnica',
#   '/',
#   'status',
#   '/',
#   '1063466830277369857',
#   '…'],
#  ['haha'],
#  ['looking',
#   'back',
#   'at',
#   'the',
#   'sun',
#   'from',
#   'upper',
#   'stage',
#   '&',
#   'falcon',
#   '9',
#   'landed',
#   'on',
#   'drone',
#   'ship',
#   'of',
#   'course',
#   'i',
#   'still',
#   'love',
#   'you',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'sg3fxidqjl'],
#  ['$',
#   '5',
#   'per',
#   'min',
#   'to',
#   'argue',
#   'with',
#   'knight',
#   '.',
#   '$',
#   '12',
#   'for',
#   '3',
#   'min',
#   'bulk',
#   'discount',
#   '.'],
#  ['while', '(', '!', 'castle', ')', '{', 'brick', '+', '+', '}', ';'],
#  ['watchtower',
#   '(',
#   'feat',
#   '.',
#   'knight',
#   ')',
#   'will',
#   'be',
#   'at',
#   'la',
#   '/',
#   'hawthorne',
#   'tunnel',
#   'entrance'],
#  ['fortnite', 'irl'],
#  ['boring',
#   'co',
#   'is',
#   'launching',
#   'a',
#   'whole',
#   'product',
#   'line',
#   'of',
#   'diy',
#   'watchtowers',
#   '.',
#   'you',
#   'get',
#   'bricks',
#   '&',
#   'a',
#   'picture',
#   '.'],
#  ['um',
#   ',',
#   'that',
#   'is',
#   'not',
#   'our',
#   'castle',
#   '.',
#   'i',
#   'just',
#   'found',
#   'a',
#   'picture',
#   'on',
#   'the',
#   'internet',
#   '.'],
#  ['not',
#   'much',
#   'but',
#   'it',
#   'is',
#   'ours',
#   'pic',
#   '.',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'gx2l84m3f7'],
#  ['the',
#   'boring',
#   'company',
#   'is',
#   'building',
#   'a',
#   'watchtower',
#   'in',
#   'la',
#   'out',
#   'of',
#   'dirt',
#   'bricks',
#   '&',
#   'we',
#   'need',
#   'a',
#   'knight',
#   'to',
#   'yell',
#   'insults',
#   'at',
#   'people',
#   'in',
#   'a',
#   'french',
#   'accent',
#   'https',
#   ':',
#   '/',
#   '/',
#   'www',
#   '.',
#   'boringcompany',
#   '.',
#   'com',
#   '/',
#   'jobs',
#   '/'],
#  ['we',
#   'have',
#   'to',
#   'truck',
#   'to',
#   'departure',
#   'rail',
#   'head',
#   '&',
#   'truck',
#   'from',
#   'arrival',
#   'rail',
#   'head',
#   ',',
#   'which',
#   'is',
#   'usually',
#   'from',
#   'customers',
#   '.',
#   'car',
#   'gets',
#   'moved',
#   'around',
#   'rail',
#   'yard',
#   'a',
#   'lot',
#   'too',
#   '&',
#   'trains',
#   'don’t',
#   'leave',
#   'often',
#   '.'],
#  ['probably',
#   'some',
#   'deliveries',
#   'in',
#   'march',
#   ',',
#   'but',
#   'april',
#   'is',
#   'more',
#   'certain'],
#  ['yes'],
#  ['will',
#   'also',
#   'be',
#   'using',
#   'dedicated',
#   'roll-on',
#   ',',
#   'roll-off',
#   'fast',
#   'ships',
#   'for',
#   'transporting',
#   'cars',
#   'to',
#   'europe',
#   '&',
#   'asia',
#   'in',
#   'q1',
#   '.',
#   'major',
#   'focus',
#   'on',
#   'minimizing',
#   'time',
#   'from',
#   'factory',
#   'to',
#   'new',
#   'owner',
#   '.',
#   'did',
#   'not',
#   'fully',
#   'appreciate',
#   'the',
#   'working',
#   'capital',
#   'impact',
#   'until',
#   'recently',
#   '.'],
#  ['we',
#   'bought',
#   'some',
#   'trucking',
#   'companies',
#   '&',
#   'secured',
#   'contracts',
#   'with',
#   'major',
#   'haulers',
#   'to',
#   'avoid',
#   'trucking',
#   'shortage',
#   'mistake',
#   'of',
#   'last',
#   'quarter'],
#  ['probably',
#   'technically',
#   'able',
#   'to',
#   'do',
#   'so',
#   'in',
#   'about',
#   'a',
#   'year',
#   '.',
#   'then',
#   'up',
#   'to',
#   'regulators',
#   '.'],
#  ['skipping',
#   'rail',
#   'saves',
#   'over',
#   'a',
#   'month',
#   'for',
#   'east',
#   'coast',
#   'deliveries',
#   '.',
#   'all',
#   'things',
#   'considered',
#   ',',
#   'it’s',
#   'better',
#   'to',
#   'use',
#   'trucks',
#   '.',
#   'single',
#   'load',
#   '/',
#   'unload',
#   '&',
#   'direct',
#   'to',
#   'owner',
#   'location',
#   '.'],
#  ['tesla',
#   'just',
#   'acquired',
#   'trucking',
#   'capacity',
#   'to',
#   'ensure',
#   'model',
#   '3',
#   'can',
#   'be',
#   'delivered',
#   'in',
#   'us',
#   'by',
#   'dec',
#   '31',
#   'if',
#   'ordered',
#   'by',
#   'nov',
#   '30',
#   'https',
#   ':',
#   '/',
#   '/',
#   '3',
#   '.',
#   'tesla',
#   '.',
#   'com',
#   '/',
#   'model',
#   '3',
#   '/',
#   'design',
#   '#battery',
#   '…'],
#  ['we', 'will', 'fight', 'big', 'tequila', '!'],
#  ['that', 'would', 'be', 'awesome'],
#  ['easily', 'accessible', 'energy'],
#  ['send', 'me', 'a', 'note', '!'],
#  ['would', 'be', 'fun', 'to', 'add', 'to', 'tesla'],
#  ['yes'],
#  ['will', 'try', 'again', 'next', 'month'],
#  ['congratulations',
#   '@spacex',
#   'team',
#   '!',
#   'thanks',
#   '@nasa',
#   ',',
#   'much',
#   'appreciated',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'teslarati',
#   '/',
#   'stat',
#   'us',
#   '/',
#   '1062255003052769281',
#   '…'],
#  ['rest',
#   'in',
#   'peace',
#   ',',
#   'stan',
#   'lee',
#   '.',
#   'the',
#   'many',
#   'worlds',
#   'of',
#   'imagination',
#   '&',
#   'delight',
#   'you',
#   'created',
#   'for',
#   'humanity',
#   'will',
#   'last',
#   'forever',
#   '.'],
#  ['is', 'he', 'ok', '?'],
#  ['it',
#   'naturally',
#   'follows',
#   'that',
#   'a',
#   'hotter',
#   'system',
#   'will',
#   'have',
#   'more',
#   'energetic',
#   'events',
#   '.',
#   'for',
#   'example',
#   ',',
#   'as',
#   'a',
#   'pot',
#   'of',
#   'water',
#   'becomes',
#   'colder',
#   ',',
#   'it',
#   'becomes',
#   'inert',
#   'ice',
#   ',',
#   'but',
#   'heating',
#   'a',
#   'pot',
#   'of',
#   'water',
#   'turns',
#   'it',
#   'into',
#   'a',
#   'steam',
#   'boiler',
#   '.',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'mayemusk',
#   '/',
#   'statu',
#   's',
#   '/',
#   '1061412788113825792',
#   '…'],
#  ['scary',
#   'sign',
#   'of',
#   'times',
#   'to',
#   'come',
#   '.',
#   'it',
#   'will',
#   'get',
#   'worse',
#   '.'],
#  ['agreed',
#   ',',
#   'technically',
#   ',',
#   'mined',
#   'hydrocarbons',
#   'come',
#   'primarily',
#   'from',
#   'ancient',
#   ',',
#   'decayed',
#   'marine',
#   'organisms',
#   '&',
#   'partially',
#   'from',
#   'geological',
#   'processes',
#   '(',
#   'ch4',
#   'particularly',
#   ')'],
#  ['makes',
#   'me',
#   'so',
#   'mad',
#   'when',
#   'smart',
#   ',',
#   'ethical',
#   'scientists',
#   'i',
#   'know',
#   'are',
#   'accused',
#   'of',
#   'publishing',
#   'climate',
#   'papers',
#   'for',
#   '“',
#   'grant',
#   'money',
#   '”',
#   '.',
#   'they',
#   'earn',
#   'vs',
#   'their',
#   'other',
#   'opportunities',
#   ',',
#   'but',
#   'give',
#   'that',
#   'up',
#   'to',
#   'help',
#   'world',
#   '.',
#   'but',
#   'their',
#   'accusers',
#   'make',
#   'billions',
#   'by',
#   'slowing',
#   'down',
#   'clean',
#   'energy',
#   '.',
#   'which',
#   'is',
#   'more',
#   'credible',
#   '?'],
#  ['that',
#   'is',
#   'true',
#   '&',
#   'should',
#   'be',
#   'applauded',
#   '.',
#   'right',
#   'move',
#   'is',
#   'for',
#   'oil',
#   'companies',
#   'truly',
#   'to',
#   'think',
#   'of',
#   'themselves',
#   'as',
#   'energy',
#   'companies',
#   ',',
#   'but',
#   'move',
#   'rapidly',
#   'towards',
#   'clean',
#   ',',
#   'sustainable',
#   'energy',
#   '.',
#   'means',
#   'lower',
#   'profits',
#   'short-term',
#   ',',
#   'but',
#   'will',
#   'make',
#   'them',
#   'stronger',
#   'long-term',
#   '.'],
#  ['we',
#   'know',
#   'we’ll',
#   'run',
#   'out',
#   'of',
#   'dead',
#   'dinosaurs',
#   'to',
#   'mine',
#   'for',
#   'fuel',
#   '&',
#   'have',
#   'to',
#   'use',
#   'sustainable',
#   'energy',
#   'eventually',
#   ',',
#   'so',
#   'why',
#   'not',
#   'go',
#   'renewable',
#   'now',
#   '&',
#   'avoid',
#   'increasing',
#   'risk',
#   'of',
#   'climate',
#   'catastrophe',
#   '?',
#   'betting',
#   'that',
#   'science',
#   'is',
#   'wrong',
#   '&',
#   'oil',
#   'companies',
#   'are',
#   'right',
#   'is',
#   'the',
#   'dumbest',
#   'experiment',
#   'in',
#   'history',
#   'by',
#   'far',
#   '…',
#   'https',
#   ':',
#   '/',
#   '/',
#   'twitter',
#   '.',
#   'com',
#   '/',
#   'newshour',
#   '/',
#   'statu',
#   's',
#   '/',
#   '1026599623396192256',
#   '…'],
#  ['because',
#   'people',
#   'on',
#   'the',
#   'ground',
#   'know',
#   'more',
#   'about',
#   'what’s',
#   'actually',
#   'needed',
#   'than',
#   'politicians',
#   'do'],
#  ['good',
#   ',',
#   'but',
#   'not',
#   'hospital',
#   'grade',
#   '.',
#   's',
#   '&',
#   'x',
#   'were',
#   'designed',
#   'to',
#   'be',
#   'proof',
#   'against',
#   'an',
#   'actual',
#   'bioweapon',
#   'attack',
#   '.',
#   'requires',
#   'a',
#   'giant',
#   'filter',
#   'with',
#   'separate',
#   'acid',
#   '&',
#   'alkaline',
#   'gas',
#   'neutralization',
#   'layers',
#   '.',
#   'not',
#   'enough',
#   'room',
#   'in',
#   'model',
#   '3',
#   '.'],
#  ['if',
#   'tesla',
#   'can',
#   'help',
#   'people',
#   'in',
#   'california',
#   'wildfire',
#   ',',
#   'please',
#   'let',
#   'us',
#   'know',
#   '.',
#   'model',
#   's',
#   '&',
#   'x',
#   'have',
#   'hospital',
#   'grade',
#   'hepa',
#   'filters',
#   '.',
#   'maybe',
#   'helpful',
#   'for',
#   'transporting',
#   'people',
#   '.'],
#  ['fair', 'point', ',', 'will', 'reenable'],
#  ...]

# %%
# from nltk.stem import PorterStemmer
# ps = PorterStemmer()
# token=ps.stem(token)

# %% [markdown]
# ## Extract Features

# %%
tweets_tokens_flat=[]
for tokens in tweets_tokens:
    for token in tokens:
        tweets_tokens_flat.append(token)

# %%
tweets_tokens_flat
# Out:
# ['dogecoin',
#  'value',
#  'may',
#  'vary',
#  'https',
#  ':',
#  '/',
#  '/',
#  'www',
#  '.',
#  'theonion',
#  '.',
#  'com',
#  '/',
#  'bitcoin-plunge',
#  '-',
#  'reveals-possible-vulnerabilities-in-craz',
#  '-',
#  '1821134169',
#  '…',
#  'dogecoin',
#  'rulz',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'flwwugaglu',
#  'uh',
#  'oh',
#  'dogecoin',
#  'might',
#  'be',
#  'my',
#  'fav',
#  'cryptocurrency',
#  '.',
#  'it’s',
#  'pretty',
#  'cool',
#  '.',
#  'yup',
#  'https',
#  ':',
#  '/',
#  '/',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'nasa',
#  '/',
#  'status',
#  '/',
#  '11',
#  '12860196043452417',
#  '…',
#  'some',
#  'challenges',
#  'with',
#  'ice',
#  'formation',
#  'in',
#  'the',
#  'cryogenic',
#  'propellant',
#  'prevalves',
#  '.',
#  'hopefully',
#  'overcome',
#  'soon',
#  '.',
#  'what',
#  'could',
#  'possibly',
#  'go',
#  'wrong',
#  '?',
#  'no',
#  'you’re',
#  'so',
#  'right',
#  '.',
#  'working',
#  'on',
#  'it',
#  '!',
#  'that',
#  'car',
#  'seemed',
#  'so',
#  'advanced',
#  'when',
#  'i',
#  'watched',
#  'that',
#  'show',
#  'as',
#  'a',
#  'kid',
#  '!',
#  'knight',
#  'industries',
#  'two',
#  'thousand',
#  'and',
#  'even',
#  'tinier',
#  'ones',
#  'for',
#  'tardigrades',
#  'yes',
#  'going',
#  'forward',
#  ',',
#  'all',
#  'tesla',
#  'stores',
#  'will',
#  'be',
#  'tiny',
#  '&',
#  'have',
#  'tiny',
#  'cars',
#  'meant',
#  'to',
#  'say',
#  'young',
#  ',',
#  'but',
#  'spelled',
#  'it',
#  'wrong',
#  'ironic',
#  'stan',
#  'if',
#  'can',
#  'do',
#  'this',
#  ',',
#  'what',
#  'can’t',
#  'they',
#  'do',
#  '!',
#  '?',
#  'solid',
#  'work',
#  'by',
#  'keen',
#  ',',
#  'as',
#  'usual',
#  'norway',
#  'https',
#  ':',
#  '/',
#  '/',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'elbilforeninge',
#  'n',
#  '/',
#  'status',
#  '/',
#  '1112702954719588357',
#  '…',
#  'yes',
#  'yes',
#  'seems',
#  'fair',
#  'some',
#  'people',
#  'use',
#  'their',
#  'hair',
#  'to',
#  'express',
#  'themselves',
#  ',',
#  'i',
#  'use',
#  'twitter',
#  '.',
#  '@theonion',
#  'making',
#  'the',
#  'onion',
#  'articles',
#  'real',
#  '…',
#  'https',
#  ':',
#  '/',
#  '/',
#  'www',
#  '.',
#  'rollingstone',
#  '.',
#  'com',
#  '/',
#  'music',
#  '/',
#  'music-ne',
#  'ws',
#  '/',
#  'elon-musk-rap-song-rip-harambe',
#  '-',
#  '815813',
#  '/',
#  '…',
#  '@yungjake',
#  '&',
#  '@bloodpop',
#  'duck',
#  'emoji',
#  'ftw',
#  'final',
#  'edit',
#  'was',
#  'on',
#  'ableton',
#  'surprisingly',
#  'difficult',
#  'to',
#  'address',
#  'false',
#  'positives',
#  'with',
#  'rain',
#  '.',
#  'system',
#  'would',
#  'go',
#  'nuts',
#  'trying',
#  'to',
#  'wipe',
#  'away',
#  'non-existent',
#  'rain',
#  ',',
#  'which',
#  'was',
#  'obv',
#  'ineffective',
#  '.',
#  'jung',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'pdr',
#  '4ji4lpu',
#  'we’ve',
#  'been',
#  'so',
#  'mired',
#  'in',
#  'production',
#  '&',
#  'logistics',
#  'for',
#  'past',
#  '18',
#  'months',
#  '.',
#  'really',
#  'looking',
#  'fwd',
#  'to',
#  'getting',
#  'semi',
#  'into',
#  'production',
#  '.',
#  'tesla',
#  'semi',
#  'delivering',
#  'tesla',
#  'cars',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'ttepcw',
#  '5d8g',
#  'pre-happy',
#  'birthday',
#  '!',
#  'amazing',
#  'work',
#  'by',
#  'tesla',
#  'delivery',
#  'teams',
#  ',',
#  'especially',
#  'in',
#  'europe',
#  '&',
#  'china',
#  '!',
#  'most',
#  'insane',
#  'logistics',
#  'challenge',
#  'i’ve',
#  'ever',
#  'seen',
#  '.',
#  'thanks',
#  'also',
#  'to',
#  'many',
#  'country',
#  '&',
#  'city',
#  'officials',
#  'for',
#  'your',
#  'help',
#  'this',
#  'weekend',
#  '!',
#  'super',
#  'appreciated',
#  '.',
#  'coming',
#  'soon',
#  '!',
#  'no',
#  'wow',
#  'http',
#  ':',
#  '/',
#  '/',
#  'x',
#  '.',
#  'com',
#  '/',
#  'x',
#  'this',
#  'might',
#  'be',
#  'my',
#  'finest',
#  'work',
#  'duck',
#  'emoji',
#  'defeats',
#  'emo',
#  'g',
#  'records',
#  '.',
#  'crushing',
#  'victory',
#  '.',
#  'i’m',
#  'disappointed',
#  'that',
#  'my',
#  'record',
#  'label',
#  'failed',
#  'emo',
#  'g',
#  'records',
#  'https',
#  ':',
#  '/',
#  '/',
#  'soundcloud',
#  '.',
#  'com',
#  '/',
#  'user',
#  '-',
#  '209448905',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'anvkkefmgr',
#  'instagram',
#  'comments',
#  'are',
#  'coding',
#  'in',
#  'emojis',
#  'also',
#  'true',
#  'true',
#  'the',
#  'quality',
#  'of',
#  'emojis',
#  'varies',
#  'wildly',
#  'lame',
#  'c',
#  '+',
#  '+',
#  'syntax',
#  'sucks',
#  'assert',
#  '(',
#  '“',
#  'money',
#  '”',
#  '=',
#  '=',
#  'series',
#  'of',
#  'heterogeneous',
#  'databases',
#  'insecurely',
#  'connected',
#  'with',
#  'high',
#  'latency',
#  '.',
#  'primary',
#  'purpose',
#  '=',
#  '=',
#  'information',
#  'system',
#  'for',
#  'allocation',
#  'of',
#  'human',
#  'time',
#  '.',
#  'as',
#  'automation',
#  '+',
#  '+',
#  ',',
#  'value',
#  'of',
#  'money',
#  '-',
#  '-',
#  ')',
#  ';',
#  'even',
#  'connectivity',
#  'at',
#  'my',
#  'house',
#  'in',
#  'silicon',
#  'valley',
#  'sucks',
#  '!',
#  'like',
#  'the',
#  'movie',
#  'us',
#  '.',
#  'scary',
#  '…',
#  'but',
#  'also',
#  'empathetic',
#  '.',
#  'no',
#  ',',
#  'but',
#  'for',
#  'sure',
#  'the',
#  'other',
#  'way',
#  'around',
#  '!',
#  'also',
#  'the',
#  'intense',
#  'low',
#  'frequency',
#  'vibrations',
#  'that',
#  'you',
#  'can’t',
#  'hear',
#  ',',
#  'but',
#  'you',
#  'can',
#  'feel',
#  'in',
#  'your',
#  'chest',
#  'we’re',
#  'going',
#  'to',
#  'try',
#  '.',
#  'side',
#  'boosters',
#  'come',
#  'back',
#  'to',
#  'cape',
#  ',',
#  'center',
#  'core',
#  'lands',
#  'on',
#  'droneship',
#  '.',
#  'latter',
#  'will',
#  'be',
#  'coming',
#  'in',
#  'v',
#  'hot',
#  '&',
#  'fast',
#  ',',
#  'so',
#  'dicey',
#  '.',
#  'annoying',
#  'that',
#  '@ula',
#  'perpetuates',
#  'myth',
#  'that',
#  'delta',
#  'iv',
#  'heavy',
#  'or',
#  'atlas',
#  'v',
#  'can',
#  'do',
#  'some',
#  'orbits',
#  'that',
#  'falcon',
#  'heavy',
#  'can’t',
#  '.',
#  'this',
#  'is',
#  'absolutely',
#  'false',
#  '.',
#  'fh',
#  'would',
#  'have',
#  'to',
#  'go',
#  'full',
#  'expendable',
#  'for',
#  'geo',
#  'direct',
#  ',',
#  'but',
#  'that’s',
#  'very',
#  'rare',
#  '.',
#  'yeah',
#  ',',
#  'falcon',
#  'heavy',
#  'block',
#  '5',
#  'has',
#  'way',
#  'more',
#  'performance',
#  'than',
#  'last',
#  'year’s',
#  'vehicle',
#  '.',
#  'lot',
#  'of',
#  'room',
#  'to',
#  'increase',
#  'side',
#  'booster',
#  'load',
#  'transfer',
#  '&',
#  'max',
#  'q',
#  'without',
#  'changing',
#  'any',
#  'parts',
#  '.',
#  'fh',
#  'block',
#  '5',
#  'can',
#  'launch',
#  'more',
#  'payload',
#  'to',
#  'any',
#  'orbit',
#  'than',
#  'any',
#  'vehicle',
#  'currently',
#  'flying',
#  '.',
#  'probably',
#  'no',
#  'fairing',
#  'either',
#  '&',
#  'just',
#  '3',
#  'raptor',
#  'vacuum',
#  'engines',
#  '.',
#  'mass',
#  'ratio',
#  'of',
#  '~',
#  '30',
#  '(',
#  '1200',
#  'tons',
#  'full',
#  ',',
#  '40',
#  'tons',
#  'empty',
#  ')',
#  'with',
#  'isp',
#  'of',
#  '380',
#  '.',
#  'then',
#  'drop',
#  'a',
#  'few',
#  'dozen',
#  'modified',
#  'starlink',
#  'satellites',
#  'from',
#  'empty',
#  'engine',
#  'bays',
#  'with',
#  '~',
#  '1600',
#  'isp',
#  ',',
#  'mr',
#  '2',
#  '.',
#  'spread',
#  'out',
#  ',',
#  'see',
#  'what’s',
#  'there',
#  '.',
#  'not',
#  'impossible',
#  '.',
#  'retrofits',
#  'will',
#  'start',
#  'when',
#  'our',
#  'software',
#  'is',
#  'able',
#  'to',
#  'take',
#  'meaningful',
#  'advantage',
#  'of',
#  'the',
#  'tesla',
#  'fsd',
#  'computer',
#  ',',
#  'which',
#  'is',
#  'an',
#  'order',
#  'of',
#  'magnitude',
#  'more',
#  'capable',
#  '.',
#  'for',
#  'now',
#  ',',
#  'it’s',
#  'slightly',
#  'disadvantageous',
#  'to',
#  'have',
#  'tesla',
#  'fsd',
#  'computer',
#  ',',
#  'as',
#  'our',
#  'software',
#  'is',
#  'more',
#  'refined',
#  'for',
#  'hw2',
#  '.',
#  'anyone',
#  'who',
#  'bought',
#  'fsd',
#  'will',
#  'get',
#  'it',
#  'anyone',
#  'who',
#  'purchased',
#  'full',
#  'self-driving',
#  'will',
#  'get',
#  'fsd',
#  'computer',
#  'upgrade',
#  'for',
#  'free',
#  '.',
#  'this',
#  'is',
#  'the',
#  'only',
#  'change',
#  'between',
#  'autopilot',
#  'hw2',
#  '.',
#  '5',
#  '&',
#  'hw3',
#  '.',
#  'going',
#  'forward',
#  '“',
#  'hw3',
#  '”',
#  'will',
#  'just',
#  'be',
#  'called',
#  'fsd',
#  'computer',
#  ',',
#  'which',
#  'is',
#  'accurate',
#  '.',
#  'no',
#  'change',
#  'to',
#  'vehicle',
#  'sensors',
#  'or',
#  'wire',
#  'harness',
#  'needed',
#  '.',
#  'this',
#  'is',
#  'v',
#  'important',
#  '.',
#  'https',
#  ':',
#  '/',
#  '/',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'samscho',
#  '/',
#  'status',
#  '/',
#  '1110649850188558336',
#  '…',
#  'yes',
#  '.',
#  'sensitive',
#  'propulsion',
#  '&',
#  'avionics',
#  'remained',
#  'dry',
#  '.',
#  'great',
#  'work',
#  'by',
#  'spacex',
#  'dragon',
#  'engineering',
#  'team',
#  '.',
#  'major',
#  'improvement',
#  'over',
#  'dragon',
#  '1',
#  '.',
#  'massive',
#  'delta',
#  'velocity',
#  'slam',
#  'from',
#  'highly',
#  'elliptical',
#  'earth',
#  'orbit',
#  'using',
#  'a',
#  'fully',
#  'retanked',
#  ',',
#  'but',
#  'lightened',
#  'up',
#  'starship',
#  'with',
#  'no',
#  'heat',
#  'shield',
#  'or',
#  'fins',
#  '/',
#  'legs',
#  '.',
#  'best',
#  'choice',
#  'for',
#  'the',
#  'impatient',
#  '.',
#  'ion',
#  'engines',
#  'are',
#  'too',
#  'slow',
#  '.',
#  'we',
#  'should',
#  'send',
#  'probes',
#  'to',
#  'outer',
#  'solar',
#  'system',
#  '&',
#  'get',
#  'high',
#  'res',
#  ',',
#  'true',
#  'color',
#  'images',
#  'of',
#  'these',
#  'strange',
#  'things',
#  '.',
#  'maybe',
#  'there’s',
#  'an',
#  'alien',
#  'artifact',
#  'out',
#  'there',
#  '…',
#  'super',
#  'cool',
#  '!',
#  'good',
#  'point',
#  'tax',
#  'authorities',
#  'tend',
#  'to',
#  'interpret',
#  'things',
#  'in',
#  'their',
#  'favor',
#  ',',
#  'but',
#  'it',
#  'sure',
#  'sounds',
#  'like',
#  'you',
#  'could',
#  'be',
#  'right',
#  '!',
#  'will',
#  'investigate',
#  '.',
#  'rare',
#  'use',
#  'case',
#  ',',
#  'but',
#  'it',
#  'is',
#  'possible',
#  '.',
#  'there',
#  'are',
#  'complications',
#  'with',
#  'this',
#  '.',
#  'eary',
#  'prototype',
#  'roadsters',
#  'had',
#  'this',
#  'ability',
#  '.',
#  'exactly',
#  'super',
#  'proud',
#  'of',
#  'tesla',
#  'autopilot',
#  'team',
#  '!',
#  'no',
#  ',',
#  'it',
#  'is',
#  'one',
#  'week',
#  'either',
#  'way',
#  '.',
#  'i',
#  'think',
#  'so',
#  '.',
#  'for',
#  'sure',
#  'worth',
#  'giving',
#  'it',
#  'our',
#  'best',
#  'shot',
#  '!',
#  'would',
#  'be',
#  'great',
#  'to',
#  'have',
#  'a',
#  'competitive',
#  ',',
#  'commercial',
#  'program',
#  'to',
#  'build',
#  'a',
#  'moon',
#  'base',
#  'that',
#  'is',
#  ...]

# %%
# # find most frequent words
# Counter(tweets_tokens_flat).most_common(100)

# %% [markdown]
# Sentiment Analysis

# %%
tweets_tokens_flat
# Out:
# ['dogecoin',
#  'value',
#  'may',
#  'vary',
#  'https',
#  ':',
#  '/',
#  '/',
#  'www',
#  '.',
#  'theonion',
#  '.',
#  'com',
#  '/',
#  'bitcoin-plunge',
#  '-',
#  'reveals-possible-vulnerabilities-in-craz',
#  '-',
#  '1821134169',
#  '…',
#  'dogecoin',
#  'rulz',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'flwwugaglu',
#  'uh',
#  'oh',
#  'dogecoin',
#  'might',
#  'be',
#  'my',
#  'fav',
#  'cryptocurrency',
#  '.',
#  'it’s',
#  'pretty',
#  'cool',
#  '.',
#  'yup',
#  'https',
#  ':',
#  '/',
#  '/',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'nasa',
#  '/',
#  'status',
#  '/',
#  '11',
#  '12860196043452417',
#  '…',
#  'some',
#  'challenges',
#  'with',
#  'ice',
#  'formation',
#  'in',
#  'the',
#  'cryogenic',
#  'propellant',
#  'prevalves',
#  '.',
#  'hopefully',
#  'overcome',
#  'soon',
#  '.',
#  'what',
#  'could',
#  'possibly',
#  'go',
#  'wrong',
#  '?',
#  'no',
#  'you’re',
#  'so',
#  'right',
#  '.',
#  'working',
#  'on',
#  'it',
#  '!',
#  'that',
#  'car',
#  'seemed',
#  'so',
#  'advanced',
#  'when',
#  'i',
#  'watched',
#  'that',
#  'show',
#  'as',
#  'a',
#  'kid',
#  '!',
#  'knight',
#  'industries',
#  'two',
#  'thousand',
#  'and',
#  'even',
#  'tinier',
#  'ones',
#  'for',
#  'tardigrades',
#  'yes',
#  'going',
#  'forward',
#  ',',
#  'all',
#  'tesla',
#  'stores',
#  'will',
#  'be',
#  'tiny',
#  '&',
#  'have',
#  'tiny',
#  'cars',
#  'meant',
#  'to',
#  'say',
#  'young',
#  ',',
#  'but',
#  'spelled',
#  'it',
#  'wrong',
#  'ironic',
#  'stan',
#  'if',
#  'can',
#  'do',
#  'this',
#  ',',
#  'what',
#  'can’t',
#  'they',
#  'do',
#  '!',
#  '?',
#  'solid',
#  'work',
#  'by',
#  'keen',
#  ',',
#  'as',
#  'usual',
#  'norway',
#  'https',
#  ':',
#  '/',
#  '/',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'elbilforeninge',
#  'n',
#  '/',
#  'status',
#  '/',
#  '1112702954719588357',
#  '…',
#  'yes',
#  'yes',
#  'seems',
#  'fair',
#  'some',
#  'people',
#  'use',
#  'their',
#  'hair',
#  'to',
#  'express',
#  'themselves',
#  ',',
#  'i',
#  'use',
#  'twitter',
#  '.',
#  '@theonion',
#  'making',
#  'the',
#  'onion',
#  'articles',
#  'real',
#  '…',
#  'https',
#  ':',
#  '/',
#  '/',
#  'www',
#  '.',
#  'rollingstone',
#  '.',
#  'com',
#  '/',
#  'music',
#  '/',
#  'music-ne',
#  'ws',
#  '/',
#  'elon-musk-rap-song-rip-harambe',
#  '-',
#  '815813',
#  '/',
#  '…',
#  '@yungjake',
#  '&',
#  '@bloodpop',
#  'duck',
#  'emoji',
#  'ftw',
#  'final',
#  'edit',
#  'was',
#  'on',
#  'ableton',
#  'surprisingly',
#  'difficult',
#  'to',
#  'address',
#  'false',
#  'positives',
#  'with',
#  'rain',
#  '.',
#  'system',
#  'would',
#  'go',
#  'nuts',
#  'trying',
#  'to',
#  'wipe',
#  'away',
#  'non-existent',
#  'rain',
#  ',',
#  'which',
#  'was',
#  'obv',
#  'ineffective',
#  '.',
#  'jung',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'pdr',
#  '4ji4lpu',
#  'we’ve',
#  'been',
#  'so',
#  'mired',
#  'in',
#  'production',
#  '&',
#  'logistics',
#  'for',
#  'past',
#  '18',
#  'months',
#  '.',
#  'really',
#  'looking',
#  'fwd',
#  'to',
#  'getting',
#  'semi',
#  'into',
#  'production',
#  '.',
#  'tesla',
#  'semi',
#  'delivering',
#  'tesla',
#  'cars',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'ttepcw',
#  '5d8g',
#  'pre-happy',
#  'birthday',
#  '!',
#  'amazing',
#  'work',
#  'by',
#  'tesla',
#  'delivery',
#  'teams',
#  ',',
#  'especially',
#  'in',
#  'europe',
#  '&',
#  'china',
#  '!',
#  'most',
#  'insane',
#  'logistics',
#  'challenge',
#  'i’ve',
#  'ever',
#  'seen',
#  '.',
#  'thanks',
#  'also',
#  'to',
#  'many',
#  'country',
#  '&',
#  'city',
#  'officials',
#  'for',
#  'your',
#  'help',
#  'this',
#  'weekend',
#  '!',
#  'super',
#  'appreciated',
#  '.',
#  'coming',
#  'soon',
#  '!',
#  'no',
#  'wow',
#  'http',
#  ':',
#  '/',
#  '/',
#  'x',
#  '.',
#  'com',
#  '/',
#  'x',
#  'this',
#  'might',
#  'be',
#  'my',
#  'finest',
#  'work',
#  'duck',
#  'emoji',
#  'defeats',
#  'emo',
#  'g',
#  'records',
#  '.',
#  'crushing',
#  'victory',
#  '.',
#  'i’m',
#  'disappointed',
#  'that',
#  'my',
#  'record',
#  'label',
#  'failed',
#  'emo',
#  'g',
#  'records',
#  'https',
#  ':',
#  '/',
#  '/',
#  'soundcloud',
#  '.',
#  'com',
#  '/',
#  'user',
#  '-',
#  '209448905',
#  'pic',
#  '.',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'anvkkefmgr',
#  'instagram',
#  'comments',
#  'are',
#  'coding',
#  'in',
#  'emojis',
#  'also',
#  'true',
#  'true',
#  'the',
#  'quality',
#  'of',
#  'emojis',
#  'varies',
#  'wildly',
#  'lame',
#  'c',
#  '+',
#  '+',
#  'syntax',
#  'sucks',
#  'assert',
#  '(',
#  '“',
#  'money',
#  '”',
#  '=',
#  '=',
#  'series',
#  'of',
#  'heterogeneous',
#  'databases',
#  'insecurely',
#  'connected',
#  'with',
#  'high',
#  'latency',
#  '.',
#  'primary',
#  'purpose',
#  '=',
#  '=',
#  'information',
#  'system',
#  'for',
#  'allocation',
#  'of',
#  'human',
#  'time',
#  '.',
#  'as',
#  'automation',
#  '+',
#  '+',
#  ',',
#  'value',
#  'of',
#  'money',
#  '-',
#  '-',
#  ')',
#  ';',
#  'even',
#  'connectivity',
#  'at',
#  'my',
#  'house',
#  'in',
#  'silicon',
#  'valley',
#  'sucks',
#  '!',
#  'like',
#  'the',
#  'movie',
#  'us',
#  '.',
#  'scary',
#  '…',
#  'but',
#  'also',
#  'empathetic',
#  '.',
#  'no',
#  ',',
#  'but',
#  'for',
#  'sure',
#  'the',
#  'other',
#  'way',
#  'around',
#  '!',
#  'also',
#  'the',
#  'intense',
#  'low',
#  'frequency',
#  'vibrations',
#  'that',
#  'you',
#  'can’t',
#  'hear',
#  ',',
#  'but',
#  'you',
#  'can',
#  'feel',
#  'in',
#  'your',
#  'chest',
#  'we’re',
#  'going',
#  'to',
#  'try',
#  '.',
#  'side',
#  'boosters',
#  'come',
#  'back',
#  'to',
#  'cape',
#  ',',
#  'center',
#  'core',
#  'lands',
#  'on',
#  'droneship',
#  '.',
#  'latter',
#  'will',
#  'be',
#  'coming',
#  'in',
#  'v',
#  'hot',
#  '&',
#  'fast',
#  ',',
#  'so',
#  'dicey',
#  '.',
#  'annoying',
#  'that',
#  '@ula',
#  'perpetuates',
#  'myth',
#  'that',
#  'delta',
#  'iv',
#  'heavy',
#  'or',
#  'atlas',
#  'v',
#  'can',
#  'do',
#  'some',
#  'orbits',
#  'that',
#  'falcon',
#  'heavy',
#  'can’t',
#  '.',
#  'this',
#  'is',
#  'absolutely',
#  'false',
#  '.',
#  'fh',
#  'would',
#  'have',
#  'to',
#  'go',
#  'full',
#  'expendable',
#  'for',
#  'geo',
#  'direct',
#  ',',
#  'but',
#  'that’s',
#  'very',
#  'rare',
#  '.',
#  'yeah',
#  ',',
#  'falcon',
#  'heavy',
#  'block',
#  '5',
#  'has',
#  'way',
#  'more',
#  'performance',
#  'than',
#  'last',
#  'year’s',
#  'vehicle',
#  '.',
#  'lot',
#  'of',
#  'room',
#  'to',
#  'increase',
#  'side',
#  'booster',
#  'load',
#  'transfer',
#  '&',
#  'max',
#  'q',
#  'without',
#  'changing',
#  'any',
#  'parts',
#  '.',
#  'fh',
#  'block',
#  '5',
#  'can',
#  'launch',
#  'more',
#  'payload',
#  'to',
#  'any',
#  'orbit',
#  'than',
#  'any',
#  'vehicle',
#  'currently',
#  'flying',
#  '.',
#  'probably',
#  'no',
#  'fairing',
#  'either',
#  '&',
#  'just',
#  '3',
#  'raptor',
#  'vacuum',
#  'engines',
#  '.',
#  'mass',
#  'ratio',
#  'of',
#  '~',
#  '30',
#  '(',
#  '1200',
#  'tons',
#  'full',
#  ',',
#  '40',
#  'tons',
#  'empty',
#  ')',
#  'with',
#  'isp',
#  'of',
#  '380',
#  '.',
#  'then',
#  'drop',
#  'a',
#  'few',
#  'dozen',
#  'modified',
#  'starlink',
#  'satellites',
#  'from',
#  'empty',
#  'engine',
#  'bays',
#  'with',
#  '~',
#  '1600',
#  'isp',
#  ',',
#  'mr',
#  '2',
#  '.',
#  'spread',
#  'out',
#  ',',
#  'see',
#  'what’s',
#  'there',
#  '.',
#  'not',
#  'impossible',
#  '.',
#  'retrofits',
#  'will',
#  'start',
#  'when',
#  'our',
#  'software',
#  'is',
#  'able',
#  'to',
#  'take',
#  'meaningful',
#  'advantage',
#  'of',
#  'the',
#  'tesla',
#  'fsd',
#  'computer',
#  ',',
#  'which',
#  'is',
#  'an',
#  'order',
#  'of',
#  'magnitude',
#  'more',
#  'capable',
#  '.',
#  'for',
#  'now',
#  ',',
#  'it’s',
#  'slightly',
#  'disadvantageous',
#  'to',
#  'have',
#  'tesla',
#  'fsd',
#  'computer',
#  ',',
#  'as',
#  'our',
#  'software',
#  'is',
#  'more',
#  'refined',
#  'for',
#  'hw2',
#  '.',
#  'anyone',
#  'who',
#  'bought',
#  'fsd',
#  'will',
#  'get',
#  'it',
#  'anyone',
#  'who',
#  'purchased',
#  'full',
#  'self-driving',
#  'will',
#  'get',
#  'fsd',
#  'computer',
#  'upgrade',
#  'for',
#  'free',
#  '.',
#  'this',
#  'is',
#  'the',
#  'only',
#  'change',
#  'between',
#  'autopilot',
#  'hw2',
#  '.',
#  '5',
#  '&',
#  'hw3',
#  '.',
#  'going',
#  'forward',
#  '“',
#  'hw3',
#  '”',
#  'will',
#  'just',
#  'be',
#  'called',
#  'fsd',
#  'computer',
#  ',',
#  'which',
#  'is',
#  'accurate',
#  '.',
#  'no',
#  'change',
#  'to',
#  'vehicle',
#  'sensors',
#  'or',
#  'wire',
#  'harness',
#  'needed',
#  '.',
#  'this',
#  'is',
#  'v',
#  'important',
#  '.',
#  'https',
#  ':',
#  '/',
#  '/',
#  'twitter',
#  '.',
#  'com',
#  '/',
#  'samscho',
#  '/',
#  'status',
#  '/',
#  '1110649850188558336',
#  '…',
#  'yes',
#  '.',
#  'sensitive',
#  'propulsion',
#  '&',
#  'avionics',
#  'remained',
#  'dry',
#  '.',
#  'great',
#  'work',
#  'by',
#  'spacex',
#  'dragon',
#  'engineering',
#  'team',
#  '.',
#  'major',
#  'improvement',
#  'over',
#  'dragon',
#  '1',
#  '.',
#  'massive',
#  'delta',
#  'velocity',
#  'slam',
#  'from',
#  'highly',
#  'elliptical',
#  'earth',
#  'orbit',
#  'using',
#  'a',
#  'fully',
#  'retanked',
#  ',',
#  'but',
#  'lightened',
#  'up',
#  'starship',
#  'with',
#  'no',
#  'heat',
#  'shield',
#  'or',
#  'fins',
#  '/',
#  'legs',
#  '.',
#  'best',
#  'choice',
#  'for',
#  'the',
#  'impatient',
#  '.',
#  'ion',
#  'engines',
#  'are',
#  'too',
#  'slow',
#  '.',
#  'we',
#  'should',
#  'send',
#  'probes',
#  'to',
#  'outer',
#  'solar',
#  'system',
#  '&',
#  'get',
#  'high',
#  'res',
#  ',',
#  'true',
#  'color',
#  'images',
#  'of',
#  'these',
#  'strange',
#  'things',
#  '.',
#  'maybe',
#  'there’s',
#  'an',
#  'alien',
#  'artifact',
#  'out',
#  'there',
#  '…',
#  'super',
#  'cool',
#  '!',
#  'good',
#  'point',
#  'tax',
#  'authorities',
#  'tend',
#  'to',
#  'interpret',
#  'things',
#  'in',
#  'their',
#  'favor',
#  ',',
#  'but',
#  'it',
#  'sure',
#  'sounds',
#  'like',
#  'you',
#  'could',
#  'be',
#  'right',
#  '!',
#  'will',
#  'investigate',
#  '.',
#  'rare',
#  'use',
#  'case',
#  ',',
#  'but',
#  'it',
#  'is',
#  'possible',
#  '.',
#  'there',
#  'are',
#  'complications',
#  'with',
#  'this',
#  '.',
#  'eary',
#  'prototype',
#  'roadsters',
#  'had',
#  'this',
#  'ability',
#  '.',
#  'exactly',
#  'super',
#  'proud',
#  'of',
#  'tesla',
#  'autopilot',
#  'team',
#  '!',
#  'no',
#  ',',
#  'it',
#  'is',
#  'one',
#  'week',
#  'either',
#  'way',
#  '.',
#  'i',
#  'think',
#  'so',
#  '.',
#  'for',
#  'sure',
#  'worth',
#  'giving',
#  'it',
#  'our',
#  'best',
#  'shot',
#  '!',
#  'would',
#  'be',
#  'great',
#  'to',
#  'have',
#  'a',
#  'competitive',
#  ',',
#  'commercial',
#  'program',
#  'to',
#  'build',
#  'a',
#  'moon',
#  'base',
#  'that',
#  'is',
#  ...]

# %%
# remove punctuation
tweets_tokens_flat=[re.sub('[^a-zA-Z\-]' ,'',w) for w in tweets_tokens_flat] 
# remove non-word hyphen
tweets_tokens_flat=[re.sub('^\-' ,'',w) for w in tweets_tokens_flat] 
# remove empty tokens
tweets_tokens_flat=[w for w in tweets_tokens_flat if w]#

# %%
tweets_tokens_flat
# Out:
# ['dogecoin',
#  'value',
#  'may',
#  'vary',
#  'https',
#  'www',
#  'theonion',
#  'com',
#  'bitcoin-plunge',
#  'reveals-possible-vulnerabilities-in-craz',
#  'dogecoin',
#  'rulz',
#  'pic',
#  'twitter',
#  'com',
#  'flwwugaglu',
#  'uh',
#  'oh',
#  'dogecoin',
#  'might',
#  'be',
#  'my',
#  'fav',
#  'cryptocurrency',
#  'its',
#  'pretty',
#  'cool',
#  'yup',
#  'https',
#  'twitter',
#  'com',
#  'nasa',
#  'status',
#  'some',
#  'challenges',
#  'with',
#  'ice',
#  'formation',
#  'in',
#  'the',
#  'cryogenic',
#  'propellant',
#  'prevalves',
#  'hopefully',
#  'overcome',
#  'soon',
#  'what',
#  'could',
#  'possibly',
#  'go',
#  'wrong',
#  'no',
#  'youre',
#  'so',
#  'right',
#  'working',
#  'on',
#  'it',
#  'that',
#  'car',
#  'seemed',
#  'so',
#  'advanced',
#  'when',
#  'i',
#  'watched',
#  'that',
#  'show',
#  'as',
#  'a',
#  'kid',
#  'knight',
#  'industries',
#  'two',
#  'thousand',
#  'and',
#  'even',
#  'tinier',
#  'ones',
#  'for',
#  'tardigrades',
#  'yes',
#  'going',
#  'forward',
#  'all',
#  'tesla',
#  'stores',
#  'will',
#  'be',
#  'tiny',
#  'have',
#  'tiny',
#  'cars',
#  'meant',
#  'to',
#  'say',
#  'young',
#  'but',
#  'spelled',
#  'it',
#  'wrong',
#  'ironic',
#  'stan',
#  'if',
#  'can',
#  'do',
#  'this',
#  'what',
#  'cant',
#  'they',
#  'do',
#  'solid',
#  'work',
#  'by',
#  'keen',
#  'as',
#  'usual',
#  'norway',
#  'https',
#  'twitter',
#  'com',
#  'elbilforeninge',
#  'n',
#  'status',
#  'yes',
#  'yes',
#  'seems',
#  'fair',
#  'some',
#  'people',
#  'use',
#  'their',
#  'hair',
#  'to',
#  'express',
#  'themselves',
#  'i',
#  'use',
#  'twitter',
#  'theonion',
#  'making',
#  'the',
#  'onion',
#  'articles',
#  'real',
#  'https',
#  'www',
#  'rollingstone',
#  'com',
#  'music',
#  'music-ne',
#  'ws',
#  'elon-musk-rap-song-rip-harambe',
#  'yungjake',
#  'bloodpop',
#  'duck',
#  'emoji',
#  'ftw',
#  'final',
#  'edit',
#  'was',
#  'on',
#  'ableton',
#  'surprisingly',
#  'difficult',
#  'to',
#  'address',
#  'false',
#  'positives',
#  'with',
#  'rain',
#  'system',
#  'would',
#  'go',
#  'nuts',
#  'trying',
#  'to',
#  'wipe',
#  'away',
#  'non-existent',
#  'rain',
#  'which',
#  'was',
#  'obv',
#  'ineffective',
#  'jung',
#  'pic',
#  'twitter',
#  'com',
#  'pdr',
#  'jilpu',
#  'weve',
#  'been',
#  'so',
#  'mired',
#  'in',
#  'production',
#  'logistics',
#  'for',
#  'past',
#  'months',
#  'really',
#  'looking',
#  'fwd',
#  'to',
#  'getting',
#  'semi',
#  'into',
#  'production',
#  'tesla',
#  'semi',
#  'delivering',
#  'tesla',
#  'cars',
#  'pic',
#  'twitter',
#  'com',
#  'ttepcw',
#  'dg',
#  'pre-happy',
#  'birthday',
#  'amazing',
#  'work',
#  'by',
#  'tesla',
#  'delivery',
#  'teams',
#  'especially',
#  'in',
#  'europe',
#  'china',
#  'most',
#  'insane',
#  'logistics',
#  'challenge',
#  'ive',
#  'ever',
#  'seen',
#  'thanks',
#  'also',
#  'to',
#  'many',
#  'country',
#  'city',
#  'officials',
#  'for',
#  'your',
#  'help',
#  'this',
#  'weekend',
#  'super',
#  'appreciated',
#  'coming',
#  'soon',
#  'no',
#  'wow',
#  'http',
#  'x',
#  'com',
#  'x',
#  'this',
#  'might',
#  'be',
#  'my',
#  'finest',
#  'work',
#  'duck',
#  'emoji',
#  'defeats',
#  'emo',
#  'g',
#  'records',
#  'crushing',
#  'victory',
#  'im',
#  'disappointed',
#  'that',
#  'my',
#  'record',
#  'label',
#  'failed',
#  'emo',
#  'g',
#  'records',
#  'https',
#  'soundcloud',
#  'com',
#  'user',
#  'pic',
#  'twitter',
#  'com',
#  'anvkkefmgr',
#  'instagram',
#  'comments',
#  'are',
#  'coding',
#  'in',
#  'emojis',
#  'also',
#  'true',
#  'true',
#  'the',
#  'quality',
#  'of',
#  'emojis',
#  'varies',
#  'wildly',
#  'lame',
#  'c',
#  'syntax',
#  'sucks',
#  'assert',
#  'money',
#  'series',
#  'of',
#  'heterogeneous',
#  'databases',
#  'insecurely',
#  'connected',
#  'with',
#  'high',
#  'latency',
#  'primary',
#  'purpose',
#  'information',
#  'system',
#  'for',
#  'allocation',
#  'of',
#  'human',
#  'time',
#  'as',
#  'automation',
#  'value',
#  'of',
#  'money',
#  'even',
#  'connectivity',
#  'at',
#  'my',
#  'house',
#  'in',
#  'silicon',
#  'valley',
#  'sucks',
#  'like',
#  'the',
#  'movie',
#  'us',
#  'scary',
#  'but',
#  'also',
#  'empathetic',
#  'no',
#  'but',
#  'for',
#  'sure',
#  'the',
#  'other',
#  'way',
#  'around',
#  'also',
#  'the',
#  'intense',
#  'low',
#  'frequency',
#  'vibrations',
#  'that',
#  'you',
#  'cant',
#  'hear',
#  'but',
#  'you',
#  'can',
#  'feel',
#  'in',
#  'your',
#  'chest',
#  'were',
#  'going',
#  'to',
#  'try',
#  'side',
#  'boosters',
#  'come',
#  'back',
#  'to',
#  'cape',
#  'center',
#  'core',
#  'lands',
#  'on',
#  'droneship',
#  'latter',
#  'will',
#  'be',
#  'coming',
#  'in',
#  'v',
#  'hot',
#  'fast',
#  'so',
#  'dicey',
#  'annoying',
#  'that',
#  'ula',
#  'perpetuates',
#  'myth',
#  'that',
#  'delta',
#  'iv',
#  'heavy',
#  'or',
#  'atlas',
#  'v',
#  'can',
#  'do',
#  'some',
#  'orbits',
#  'that',
#  'falcon',
#  'heavy',
#  'cant',
#  'this',
#  'is',
#  'absolutely',
#  'false',
#  'fh',
#  'would',
#  'have',
#  'to',
#  'go',
#  'full',
#  'expendable',
#  'for',
#  'geo',
#  'direct',
#  'but',
#  'thats',
#  'very',
#  'rare',
#  'yeah',
#  'falcon',
#  'heavy',
#  'block',
#  'has',
#  'way',
#  'more',
#  'performance',
#  'than',
#  'last',
#  'years',
#  'vehicle',
#  'lot',
#  'of',
#  'room',
#  'to',
#  'increase',
#  'side',
#  'booster',
#  'load',
#  'transfer',
#  'max',
#  'q',
#  'without',
#  'changing',
#  'any',
#  'parts',
#  'fh',
#  'block',
#  'can',
#  'launch',
#  'more',
#  'payload',
#  'to',
#  'any',
#  'orbit',
#  'than',
#  'any',
#  'vehicle',
#  'currently',
#  'flying',
#  'probably',
#  'no',
#  'fairing',
#  'either',
#  'just',
#  'raptor',
#  'vacuum',
#  'engines',
#  'mass',
#  'ratio',
#  'of',
#  'tons',
#  'full',
#  'tons',
#  'empty',
#  'with',
#  'isp',
#  'of',
#  'then',
#  'drop',
#  'a',
#  'few',
#  'dozen',
#  'modified',
#  'starlink',
#  'satellites',
#  'from',
#  'empty',
#  'engine',
#  'bays',
#  'with',
#  'isp',
#  'mr',
#  'spread',
#  'out',
#  'see',
#  'whats',
#  'there',
#  'not',
#  'impossible',
#  'retrofits',
#  'will',
#  'start',
#  'when',
#  'our',
#  'software',
#  'is',
#  'able',
#  'to',
#  'take',
#  'meaningful',
#  'advantage',
#  'of',
#  'the',
#  'tesla',
#  'fsd',
#  'computer',
#  'which',
#  'is',
#  'an',
#  'order',
#  'of',
#  'magnitude',
#  'more',
#  'capable',
#  'for',
#  'now',
#  'its',
#  'slightly',
#  'disadvantageous',
#  'to',
#  'have',
#  'tesla',
#  'fsd',
#  'computer',
#  'as',
#  'our',
#  'software',
#  'is',
#  'more',
#  'refined',
#  'for',
#  'hw',
#  'anyone',
#  'who',
#  'bought',
#  'fsd',
#  'will',
#  'get',
#  'it',
#  'anyone',
#  'who',
#  'purchased',
#  'full',
#  'self-driving',
#  'will',
#  'get',
#  'fsd',
#  'computer',
#  'upgrade',
#  'for',
#  'free',
#  'this',
#  'is',
#  'the',
#  'only',
#  'change',
#  'between',
#  'autopilot',
#  'hw',
#  'hw',
#  'going',
#  'forward',
#  'hw',
#  'will',
#  'just',
#  'be',
#  'called',
#  'fsd',
#  'computer',
#  'which',
#  'is',
#  'accurate',
#  'no',
#  'change',
#  'to',
#  'vehicle',
#  'sensors',
#  'or',
#  'wire',
#  'harness',
#  'needed',
#  'this',
#  'is',
#  'v',
#  'important',
#  'https',
#  'twitter',
#  'com',
#  'samscho',
#  'status',
#  'yes',
#  'sensitive',
#  'propulsion',
#  'avionics',
#  'remained',
#  'dry',
#  'great',
#  'work',
#  'by',
#  'spacex',
#  'dragon',
#  'engineering',
#  'team',
#  'major',
#  'improvement',
#  'over',
#  'dragon',
#  'massive',
#  'delta',
#  'velocity',
#  'slam',
#  'from',
#  'highly',
#  'elliptical',
#  'earth',
#  'orbit',
#  'using',
#  'a',
#  'fully',
#  'retanked',
#  'but',
#  'lightened',
#  'up',
#  'starship',
#  'with',
#  'no',
#  'heat',
#  'shield',
#  'or',
#  'fins',
#  'legs',
#  'best',
#  'choice',
#  'for',
#  'the',
#  'impatient',
#  'ion',
#  'engines',
#  'are',
#  'too',
#  'slow',
#  'we',
#  'should',
#  'send',
#  'probes',
#  'to',
#  'outer',
#  'solar',
#  'system',
#  'get',
#  'high',
#  'res',
#  'true',
#  'color',
#  'images',
#  'of',
#  'these',
#  'strange',
#  'things',
#  'maybe',
#  'theres',
#  'an',
#  'alien',
#  'artifact',
#  'out',
#  'there',
#  'super',
#  'cool',
#  'good',
#  'point',
#  'tax',
#  'authorities',
#  'tend',
#  'to',
#  'interpret',
#  'things',
#  'in',
#  'their',
#  'favor',
#  'but',
#  'it',
#  'sure',
#  'sounds',
#  'like',
#  'you',
#  'could',
#  'be',
#  'right',
#  'will',
#  'investigate',
#  'rare',
#  'use',
#  'case',
#  'but',
#  'it',
#  'is',
#  'possible',
#  'there',
#  'are',
#  'complications',
#  'with',
#  'this',
#  'eary',
#  'prototype',
#  'roadsters',
#  'had',
#  'this',
#  'ability',
#  'exactly',
#  'super',
#  'proud',
#  'of',
#  'tesla',
#  'autopilot',
#  'team',
#  'no',
#  'it',
#  'is',
#  'one',
#  'week',
#  'either',
#  'way',
#  'i',
#  'think',
#  'so',
#  'for',
#  'sure',
#  'worth',
#  'giving',
#  'it',
#  'our',
#  'best',
#  'shot',
#  'would',
#  'be',
#  'great',
#  'to',
#  'have',
#  'a',
#  'competitive',
#  'commercial',
#  'program',
#  'to',
#  'build',
#  'a',
#  'moon',
#  'base',
#  'that',
#  'is',
#  'outcome-oriented',
#  'not',
#  'cost-plus',
#  'so',
#  'you',
#  'only',
#  'get',
#  'paid',
#  'for',
#  'safe',
#  'delivery',
#  'of',
#  'cargo',
#  'it',
#  'would',
#  'be',
#  'so',
#  'inspiring',
#  'for',
#  'humanity',
#  'to',
#  'see',
#  'humanity',
#  'return',
#  'to',
#  'the',
#  'moon',
#  'lbs',
#  'how',
#  'puny',
#  'do',
#  'you',
#  'construct',
#  'childrens',
#  'toys',
#  'thats',
#  'exactly',
#  'it',
#  'youre',
#  'no',
#  'longer',
#  'mentally',
#  'fatigued',
#  'after',
#  'a',
#  'long',
#  'drive',
#  'makes',
#  'a',
#  'major',
#  'difference',
#  'to',
#  'your',
#  'happiness',
#  'level',
#  'commuting',
#  'home',
#  'from',
#  'work',
#  'after',
#  'a',
#  'long',
#  'day',
#  'https',
#  'twitter',
#  'com',
#  'sspencersmb',
#  's',
#  'tatus',
#  'good',
#  'point',
#  'hard',
#  'to',
#  'appreciate',
#  'how',
#  'much',
#  'tesla',
#  'autopilot',
#  'improves',
#  'enjoyment',
#  'of',
#  'driving',
#  'until',
#  'you',
#  'try',
#  'it',
#  'https',
#  'twitter',
#  'com',
#  'erdayastronaut',
#  'status',
#  'yes',
#  'otherwise',
#  'propellant',
#  'usage',
#  'for',
#  'an',
#  'atmospheric',
#  'entry',
#  'would',
#  'be',
#  'very',
#  'high',
#  'and',
#  'or',
#  'center',
#  'of',
#  'mass',
#  'would',
#  'need',
#  'to',
#  'be',
#  'very',
#  'tightly',
#  'constrained',
#  'yes',
#  'but',
#  'were',
#  'going',
#  'to',
#  'skip',
#  'that',
#  'at',
#  'first',
#  'to',
#  'avoid',
#  'fragging',
#  'launch',
#  'pads',
#  'glad',
#  'you',
#  'like',
#  'it',
#  'navigate',
#  'on',
#  'autopilot',
#  'hopefully',
#  'approved',
#  'for',
#  'europe',
#  'soon',
#  'thank',
#  'you',
#  'https',
#  'twitter',
#  'com',
#  'tesla',
#  'status',
#  'will',
#  'do',
#  'ford',
#  'has',
#  'ceos',
#  'in',
#  'years',
#  'nobody',
#  'blinks',
#  'but',
#  'tesla',
#  'loses',
#  'intern',
#  'its',
#  'front',
#  'page',
#  'news',
#  'i',
#  'tell',
#  'ya',
#  'shakes',
#  'fist',
#  'at',
#  'sky',
#  'its',
#  'possible',
#  'to',
#  'make',
#  'a',
#  'self-sustaining',
#  'city',
#  'on',
#  'mars',
#  'by',
#  'if',
#  'we',
#  'start',
#  'in',
#  'years',
#  'take',
#  'orbital',
#  'synchronizations',
#  'youre',
#  'most',
#  'welcome',
#  'glad',
#  'to',
#  'be',
#  'helpful',
#  'only',
#  'when',
#  'y',
#  'is',
#  'in',
#  'production',
#  'every',
#  'car',
#  'company',
#  'is',
#  'constantly',
#  'changing',
#  'prices',
#  'but',
#  'nobody',
#  'cares',
#  'import',
#  'tariffs',
#  'vat',
#  'transport',
#  'costs',
#  ...]

# %%
# remove stopwords
tweets_tokens_flat = [w for w in tweets_tokens_flat if w not in stopwords.words("english")]

# %%
tweets_tokens_flat
# Out:
# ['dogecoin',
#  'value',
#  'may',
#  'vary',
#  'https',
#  'www',
#  'theonion',
#  'com',
#  'bitcoin-plunge',
#  'reveals-possible-vulnerabilities-in-craz',
#  'dogecoin',
#  'rulz',
#  'pic',
#  'twitter',
#  'com',
#  'flwwugaglu',
#  'uh',
#  'oh',
#  'dogecoin',
#  'might',
#  'fav',
#  'cryptocurrency',
#  'pretty',
#  'cool',
#  'yup',
#  'https',
#  'twitter',
#  'com',
#  'nasa',
#  'status',
#  'challenges',
#  'ice',
#  'formation',
#  'cryogenic',
#  'propellant',
#  'prevalves',
#  'hopefully',
#  'overcome',
#  'soon',
#  'could',
#  'possibly',
#  'go',
#  'wrong',
#  'youre',
#  'right',
#  'working',
#  'car',
#  'seemed',
#  'advanced',
#  'watched',
#  'show',
#  'kid',
#  'knight',
#  'industries',
#  'two',
#  'thousand',
#  'even',
#  'tinier',
#  'ones',
#  'tardigrades',
#  'yes',
#  'going',
#  'forward',
#  'tesla',
#  'stores',
#  'tiny',
#  'tiny',
#  'cars',
#  'meant',
#  'say',
#  'young',
#  'spelled',
#  'wrong',
#  'ironic',
#  'stan',
#  'cant',
#  'solid',
#  'work',
#  'keen',
#  'usual',
#  'norway',
#  'https',
#  'twitter',
#  'com',
#  'elbilforeninge',
#  'n',
#  'status',
#  'yes',
#  'yes',
#  'seems',
#  'fair',
#  'people',
#  'use',
#  'hair',
#  'express',
#  'use',
#  'twitter',
#  'theonion',
#  'making',
#  'onion',
#  'articles',
#  'real',
#  'https',
#  'www',
#  'rollingstone',
#  'com',
#  'music',
#  'music-ne',
#  'ws',
#  'elon-musk-rap-song-rip-harambe',
#  'yungjake',
#  'bloodpop',
#  'duck',
#  'emoji',
#  'ftw',
#  'final',
#  'edit',
#  'ableton',
#  'surprisingly',
#  'difficult',
#  'address',
#  'false',
#  'positives',
#  'rain',
#  'system',
#  'would',
#  'go',
#  'nuts',
#  'trying',
#  'wipe',
#  'away',
#  'non-existent',
#  'rain',
#  'obv',
#  'ineffective',
#  'jung',
#  'pic',
#  'twitter',
#  'com',
#  'pdr',
#  'jilpu',
#  'weve',
#  'mired',
#  'production',
#  'logistics',
#  'past',
#  'months',
#  'really',
#  'looking',
#  'fwd',
#  'getting',
#  'semi',
#  'production',
#  'tesla',
#  'semi',
#  'delivering',
#  'tesla',
#  'cars',
#  'pic',
#  'twitter',
#  'com',
#  'ttepcw',
#  'dg',
#  'pre-happy',
#  'birthday',
#  'amazing',
#  'work',
#  'tesla',
#  'delivery',
#  'teams',
#  'especially',
#  'europe',
#  'china',
#  'insane',
#  'logistics',
#  'challenge',
#  'ive',
#  'ever',
#  'seen',
#  'thanks',
#  'also',
#  'many',
#  'country',
#  'city',
#  'officials',
#  'help',
#  'weekend',
#  'super',
#  'appreciated',
#  'coming',
#  'soon',
#  'wow',
#  'http',
#  'x',
#  'com',
#  'x',
#  'might',
#  'finest',
#  'work',
#  'duck',
#  'emoji',
#  'defeats',
#  'emo',
#  'g',
#  'records',
#  'crushing',
#  'victory',
#  'im',
#  'disappointed',
#  'record',
#  'label',
#  'failed',
#  'emo',
#  'g',
#  'records',
#  'https',
#  'soundcloud',
#  'com',
#  'user',
#  'pic',
#  'twitter',
#  'com',
#  'anvkkefmgr',
#  'instagram',
#  'comments',
#  'coding',
#  'emojis',
#  'also',
#  'true',
#  'true',
#  'quality',
#  'emojis',
#  'varies',
#  'wildly',
#  'lame',
#  'c',
#  'syntax',
#  'sucks',
#  'assert',
#  'money',
#  'series',
#  'heterogeneous',
#  'databases',
#  'insecurely',
#  'connected',
#  'high',
#  'latency',
#  'primary',
#  'purpose',
#  'information',
#  'system',
#  'allocation',
#  'human',
#  'time',
#  'automation',
#  'value',
#  'money',
#  'even',
#  'connectivity',
#  'house',
#  'silicon',
#  'valley',
#  'sucks',
#  'like',
#  'movie',
#  'us',
#  'scary',
#  'also',
#  'empathetic',
#  'sure',
#  'way',
#  'around',
#  'also',
#  'intense',
#  'low',
#  'frequency',
#  'vibrations',
#  'cant',
#  'hear',
#  'feel',
#  'chest',
#  'going',
#  'try',
#  'side',
#  'boosters',
#  'come',
#  'back',
#  'cape',
#  'center',
#  'core',
#  'lands',
#  'droneship',
#  'latter',
#  'coming',
#  'v',
#  'hot',
#  'fast',
#  'dicey',
#  'annoying',
#  'ula',
#  'perpetuates',
#  'myth',
#  'delta',
#  'iv',
#  'heavy',
#  'atlas',
#  'v',
#  'orbits',
#  'falcon',
#  'heavy',
#  'cant',
#  'absolutely',
#  'false',
#  'fh',
#  'would',
#  'go',
#  'full',
#  'expendable',
#  'geo',
#  'direct',
#  'thats',
#  'rare',
#  'yeah',
#  'falcon',
#  'heavy',
#  'block',
#  'way',
#  'performance',
#  'last',
#  'years',
#  'vehicle',
#  'lot',
#  'room',
#  'increase',
#  'side',
#  'booster',
#  'load',
#  'transfer',
#  'max',
#  'q',
#  'without',
#  'changing',
#  'parts',
#  'fh',
#  'block',
#  'launch',
#  'payload',
#  'orbit',
#  'vehicle',
#  'currently',
#  'flying',
#  'probably',
#  'fairing',
#  'either',
#  'raptor',
#  'vacuum',
#  'engines',
#  'mass',
#  'ratio',
#  'tons',
#  'full',
#  'tons',
#  'empty',
#  'isp',
#  'drop',
#  'dozen',
#  'modified',
#  'starlink',
#  'satellites',
#  'empty',
#  'engine',
#  'bays',
#  'isp',
#  'mr',
#  'spread',
#  'see',
#  'whats',
#  'impossible',
#  'retrofits',
#  'start',
#  'software',
#  'able',
#  'take',
#  'meaningful',
#  'advantage',
#  'tesla',
#  'fsd',
#  'computer',
#  'order',
#  'magnitude',
#  'capable',
#  'slightly',
#  'disadvantageous',
#  'tesla',
#  'fsd',
#  'computer',
#  'software',
#  'refined',
#  'hw',
#  'anyone',
#  'bought',
#  'fsd',
#  'get',
#  'anyone',
#  'purchased',
#  'full',
#  'self-driving',
#  'get',
#  'fsd',
#  'computer',
#  'upgrade',
#  'free',
#  'change',
#  'autopilot',
#  'hw',
#  'hw',
#  'going',
#  'forward',
#  'hw',
#  'called',
#  'fsd',
#  'computer',
#  'accurate',
#  'change',
#  'vehicle',
#  'sensors',
#  'wire',
#  'harness',
#  'needed',
#  'v',
#  'important',
#  'https',
#  'twitter',
#  'com',
#  'samscho',
#  'status',
#  'yes',
#  'sensitive',
#  'propulsion',
#  'avionics',
#  'remained',
#  'dry',
#  'great',
#  'work',
#  'spacex',
#  'dragon',
#  'engineering',
#  'team',
#  'major',
#  'improvement',
#  'dragon',
#  'massive',
#  'delta',
#  'velocity',
#  'slam',
#  'highly',
#  'elliptical',
#  'earth',
#  'orbit',
#  'using',
#  'fully',
#  'retanked',
#  'lightened',
#  'starship',
#  'heat',
#  'shield',
#  'fins',
#  'legs',
#  'best',
#  'choice',
#  'impatient',
#  'ion',
#  'engines',
#  'slow',
#  'send',
#  'probes',
#  'outer',
#  'solar',
#  'system',
#  'get',
#  'high',
#  'res',
#  'true',
#  'color',
#  'images',
#  'strange',
#  'things',
#  'maybe',
#  'theres',
#  'alien',
#  'artifact',
#  'super',
#  'cool',
#  'good',
#  'point',
#  'tax',
#  'authorities',
#  'tend',
#  'interpret',
#  'things',
#  'favor',
#  'sure',
#  'sounds',
#  'like',
#  'could',
#  'right',
#  'investigate',
#  'rare',
#  'use',
#  'case',
#  'possible',
#  'complications',
#  'eary',
#  'prototype',
#  'roadsters',
#  'ability',
#  'exactly',
#  'super',
#  'proud',
#  'tesla',
#  'autopilot',
#  'team',
#  'one',
#  'week',
#  'either',
#  'way',
#  'think',
#  'sure',
#  'worth',
#  'giving',
#  'best',
#  'shot',
#  'would',
#  'great',
#  'competitive',
#  'commercial',
#  'program',
#  'build',
#  'moon',
#  'base',
#  'outcome-oriented',
#  'cost-plus',
#  'get',
#  'paid',
#  'safe',
#  'delivery',
#  'cargo',
#  'would',
#  'inspiring',
#  'humanity',
#  'see',
#  'humanity',
#  'return',
#  'moon',
#  'lbs',
#  'puny',
#  'construct',
#  'childrens',
#  'toys',
#  'thats',
#  'exactly',
#  'youre',
#  'longer',
#  'mentally',
#  'fatigued',
#  'long',
#  'drive',
#  'makes',
#  'major',
#  'difference',
#  'happiness',
#  'level',
#  'commuting',
#  'home',
#  'work',
#  'long',
#  'day',
#  'https',
#  'twitter',
#  'com',
#  'sspencersmb',
#  'tatus',
#  'good',
#  'point',
#  'hard',
#  'appreciate',
#  'much',
#  'tesla',
#  'autopilot',
#  'improves',
#  'enjoyment',
#  'driving',
#  'try',
#  'https',
#  'twitter',
#  'com',
#  'erdayastronaut',
#  'status',
#  'yes',
#  'otherwise',
#  'propellant',
#  'usage',
#  'atmospheric',
#  'entry',
#  'would',
#  'high',
#  'center',
#  'mass',
#  'would',
#  'need',
#  'tightly',
#  'constrained',
#  'yes',
#  'going',
#  'skip',
#  'first',
#  'avoid',
#  'fragging',
#  'launch',
#  'pads',
#  'glad',
#  'like',
#  'navigate',
#  'autopilot',
#  'hopefully',
#  'approved',
#  'europe',
#  'soon',
#  'thank',
#  'https',
#  'twitter',
#  'com',
#  'tesla',
#  'status',
#  'ford',
#  'ceos',
#  'years',
#  'nobody',
#  'blinks',
#  'tesla',
#  'loses',
#  'intern',
#  'front',
#  'page',
#  'news',
#  'tell',
#  'ya',
#  'shakes',
#  'fist',
#  'sky',
#  'possible',
#  'make',
#  'self-sustaining',
#  'city',
#  'mars',
#  'start',
#  'years',
#  'take',
#  'orbital',
#  'synchronizations',
#  'youre',
#  'welcome',
#  'glad',
#  'helpful',
#  'production',
#  'every',
#  'car',
#  'company',
#  'constantly',
#  'changing',
#  'prices',
#  'nobody',
#  'cares',
#  'import',
#  'tariffs',
#  'vat',
#  'transport',
#  'costs',
#  'clear',
#  'doesnt',
#  'affect',
#  'tesla',
#  'website',
#  'order',
#  'prices',
#  'existing',
#  'inventory',
#  'prices',
#  'currently',
#  'slightly',
#  'lower',
#  'website',
#  'bring',
#  'line',
#  'precise',
#  'midnight',
#  'april',
#  'effective',
#  'april',
#  'please',
#  'note',
#  'prices',
#  'tesla',
#  'inventory',
#  'cars',
#  'worldwide',
#  'rise',
#  'april',
#  'upgraded',
#  'chromium',
#  'reset',
#  'sentry',
#  'mode',
#  'options',
#  'always',
#  'exclude',
#  'home',
#  'exclude',
#  'work',
#  'exclude',
#  'saved',
#  'locations',
#  'ask',
#  'someone',
#  'already',
#  'roadster',
#  'prior',
#  'program',
#  'theyre',
#  'eligible',
#  'win',
#  'signed',
#  'performance',
#  'sounds',
#  'like',
#  'good',
#  'idea',
#  'win',
#  'boss',
#  'fight',
#  'sekiro',
#  'cumulative',
#  'win',
#  'one',
#  'prizes',
#  'referral',
#  'count',
#  'resets',
#  'zero',
#  'cant',
#  'win',
#  'prize',
#  'intent',
#  'time',
#  'enable',
#  'without',
#  'massive',
#  'social',
#  'media',
#  'presence',
#  'win',
#  'ww',
#  'agreed',
#  'win',
#  'prize',
#  'youre',
#  'welcome',
#  'new',
#  'tesla',
#  'referral',
#  'program',
#  'released',
#  'https',
#  'www',
#  'tesla',
#  'com',
#  'blog',
#  'teslas-ne',
#  'w-customer-referral-program',
#  'redirect',
#  'uh',
#  'yes',
#  'comprehensive',
#  'statistics',
#  'go',
#  'deep',
#  'wide',
#  'great',
#  'loved',
#  'colbert',
#  'report',
#  'jim',
#  'cramer',
#  'explains',
#  'short-seller',
#  'market',
#  'manipulation',
#  'https',
#  'en',
#  'wikipedia',
#  'org',
#  'wiki',
#  'jimcrame',
#  'r',
#  'marketmanipulation',
#  'jim',
#  'cant',
#  'take',
#  'heat',
#  'jim',
#  'response',
#  'exactly',
#  'best',
#  'get',
#  'tesla',
#  'powerwall',
#  'power',
#  'house',
#  'also',
#  'drive',
#  'probably',
#  'start',
#  'australia',
#  'builds',
#  'late',
#  'may',
#  'june',
#  'start',
#  'arriving',
#  'winter',
#  'coming',
#  'soon',
#  'yes',
#  'full',
#  'duration',
#  'white-hot',
#  'parts',
#  'reached',
#  'orbital',
#  'entry',
#  'temp',
#  'around',
#  'kelvin',
#  'falcon',
#  'rocket',
#  'booster',
#  'aluminum-lithium',
#  'carbon',
#  'fiber',
#  'low',
#  'max',
#  'temperature',
#  'allowables',
#  'super',
#  'heavy',
#  'booster',
#  'stainless',
#  'steel',
#  'since',
#  'goes',
#  'around',
#  'mach',
#  'moreover',
#  'high',
#  'altitude',
#  'needs',
#  'heat',
#  'shield',
#  'even',
#  'paint',
#  'transpiration',
#  'cooling',
#  'added',
#  'wherever',
#  'see',
#  'erosion',
#  'shield',
#  'starship',
#  'needs',
#  'ready',
#  'fly',
#  'immediately',
#  'landing',
#  'zero',
#  'refurbishment',
#  'straight',
#  'path',
#  'hot',
#  'gas',
#  'accelerate',
#  'gaps',
#  'testing',
#  'starship',
#  'heatshield',
#  'hex',
#  'tiles',
#  'pic',
#  'twitter',
#  'com',
#  'pyce',
#  'vthxq',
#  'hexagonal',
#  'tiles',
#  'windward',
#  'side',
#  'shield',
#  'needed',
#  'leeward',
#  'side',
#  'transpiration',
#  'cooling',
#  'hotspots',
#  'hottest',
#  'sections',
#  'full',
#  'size',
#  'decided',
#  'skip',
#  'building',
#  'new',
#  'nosecone',
#  'hopper',
#  'dont',
#  'need',
#  'see',
#  'built',
#  'orbital',
#  'starship',
#  'vehicle',
#  'deep',
#  'throttle',
#  'single',
#  'shaft',
#  'system',
#  'choking',
#  'flow',
#  'fuel',
#  'oxygen',
#  'pump',
#  'combustion',
#  'chamber',
#  'problem',
#  'tiny',
#  'rocket',
#  'engine',
#  'powers',
#  'pump',
#  'called',
#  'gas',
#  'generator',
#  'throttle',
#  'way',
#  'deeper',
#  'main',
#  'chamber',
#  'working',
#  'regulatory',
#  'approval',
#  'boca',
#  'chica',
#  'texas',
#  'cape',
#  'kennedy',
#  'florida',
#  'also',
#  'building',
#  'starship',
#  'super',
#  'heavy',
#  'simultaneously',
#  'locations',
#  'agreed',
#  'raptor',
#  'complex',
#  'even',
#  'staged',
#  'combustion',
#  'engine',
#  'simplifying',
#  'much',
#  'possible',
#  'iteration',
#  'throttling',
#  'hard',
#  'manageable',
#  'going',
#  'would',
#  'extremely',
#  'tough',
#  'hopefully',
#  'needed',
#  'started',
#  'rolling',
#  'days',
#  'ago',
#  'always',
#  'starts',
#  'slow',
#  'find',
#  'rare',
#  ...]

# %%
# find most frequent words
Counter(tweets_tokens_flat).most_common(100)
# Out:
# [('com', 1210),
#  ('tesla', 717),
#  ('twitter', 643),
#  ('https', 587),
#  ('http', 430),
#  ('pic', 376),
#  ('www', 345),
#  ('model', 333),
#  ('yes', 290),
#  ('good', 289),
#  ('like', 250),
#  ('spacex', 232),
#  ('car', 229),
#  ('v', 193),
#  ('would', 192),
#  ('rocket', 191),
#  ('next', 181),
#  ('great', 165),
#  ('time', 162),
#  ('people', 160),
#  ('one', 159),
#  ('cars', 156),
#  ('falcon', 151),
#  ('dont', 148),
#  ('us', 144),
#  ('launch', 144),
#  ('first', 144),
#  ('right', 135),
#  ('status', 134),
#  ('also', 134),
#  ('thanks', 133),
#  ('need', 130),
#  ('new', 129),
#  ('soon', 127),
#  ('much', 127),
#  ('make', 125),
#  ('watch', 125),
#  ('get', 123),
#  ('year', 123),
#  ('better', 122),
#  ('x', 121),
#  ('even', 120),
#  ('high', 119),
#  ('yeah', 119),
#  ('youtube', 117),
#  ('love', 117),
#  ('really', 115),
#  ('way', 114),
#  ('thats', 113),
#  ('true', 112),
#  ('p', 112),
#  ('production', 111),
#  ('work', 107),
#  ('maybe', 106),
#  ('actually', 106),
#  ('coming', 104),
#  ('team', 101),
#  ('exactly', 100),
#  ('im', 97),
#  ('instagram', 97),
#  ('dragon', 97),
#  ('think', 94),
#  ('many', 91),
#  ('week', 91),
#  ('space', 91),
#  ('going', 90),
#  ('go', 89),
#  ('test', 88),
#  ('sure', 87),
#  ('back', 87),
#  ('best', 87),
#  ('still', 87),
#  ('youre', 86),
#  ('probably', 86),
#  ('w', 86),
#  ('landing', 85),
#  ('autopilot', 83),
#  ('news', 83),
#  ('know', 83),
#  ('years', 82),
#  ('mars', 82),
#  ('teslamotors', 82),
#  ('lot', 80),
#  ('k', 80),
#  ('super', 79),
#  ('almost', 78),
#  ('long', 76),
#  ('boring', 76),
#  ('want', 76),
#  ('could', 75),
#  ('heavy', 75),
#  ('article', 75),
#  ('company', 74),
#  ('use', 73),
#  ('software', 73),
#  ('html', 72),
#  ('flight', 70),
#  ('cool', 69),
#  ('future', 69),
#  ('cant', 68)]

# %%
self_stopwords=['com','twitter','https','http','www','v','x','p','would']

# %%
tweets_tokens_flat=[w for w in tweets_tokens_flat if w not in self_stopwords]

# %%
Counter(tweets_tokens_flat).most_common(100)
# Out:
# [('tesla', 717),
#  ('pic', 376),
#  ('model', 333),
#  ('yes', 290),
#  ('good', 289),
#  ('like', 250),
#  ('spacex', 232),
#  ('car', 229),
#  ('rocket', 191),
#  ('next', 181),
#  ('great', 165),
#  ('time', 162),
#  ('people', 160),
#  ('one', 159),
#  ('cars', 156),
#  ('falcon', 151),
#  ('dont', 148),
#  ('us', 144),
#  ('launch', 144),
#  ('first', 144),
#  ('right', 135),
#  ('status', 134),
#  ('also', 134),
#  ('thanks', 133),
#  ('need', 130),
#  ('new', 129),
#  ('soon', 127),
#  ('much', 127),
#  ('make', 125),
#  ('watch', 125),
#  ('get', 123),
#  ('year', 123),
#  ('better', 122),
#  ('even', 120),
#  ('high', 119),
#  ('yeah', 119),
#  ('youtube', 117),
#  ('love', 117),
#  ('really', 115),
#  ('way', 114),
#  ('thats', 113),
#  ('true', 112),
#  ('production', 111),
#  ('work', 107),
#  ('maybe', 106),
#  ('actually', 106),
#  ('coming', 104),
#  ('team', 101),
#  ('exactly', 100),
#  ('im', 97),
#  ('instagram', 97),
#  ('dragon', 97),
#  ('think', 94),
#  ('many', 91),
#  ('week', 91),
#  ('space', 91),
#  ('going', 90),
#  ('go', 89),
#  ('test', 88),
#  ('sure', 87),
#  ('back', 87),
#  ('best', 87),
#  ('still', 87),
#  ('youre', 86),
#  ('probably', 86),
#  ('w', 86),
#  ('landing', 85),
#  ('autopilot', 83),
#  ('news', 83),
#  ('know', 83),
#  ('years', 82),
#  ('mars', 82),
#  ('teslamotors', 82),
#  ('lot', 80),
#  ('k', 80),
#  ('super', 79),
#  ('almost', 78),
#  ('long', 76),
#  ('boring', 76),
#  ('want', 76),
#  ('could', 75),
#  ('heavy', 75),
#  ('article', 75),
#  ('company', 74),
#  ('use', 73),
#  ('software', 73),
#  ('html', 72),
#  ('flight', 70),
#  ('cool', 69),
#  ('future', 69),
#  ('cant', 68),
#  ('point', 68),
#  ('ok', 68),
#  ('air', 68),
#  ('see', 67),
#  ('power', 66),
#  ('end', 66),
#  ('drive', 65),
#  ('st', 65),
#  ('design', 65)]

# %%
# sentiment analysis
# bi-gram
# dictionary based on eda

# %%
tweets_tokens_text=' '.join(tweets_tokens_flat)

# %%
tweets_tokens_text
# Out:
# 'dogecoin value may vary theonion bitcoin-plunge reveals-possible-vulnerabilities-in-craz dogecoin rulz pic flwwugaglu uh oh dogecoin might fav cryptocurrency pretty cool yup nasa status challenges ice formation cryogenic propellant prevalves hopefully overcome soon could possibly go wrong youre right working car seemed advanced watched show kid knight industries two thousand even tinier ones tardigrades yes going forward tesla stores tiny tiny cars meant say young spelled wrong ironic stan cant solid work keen usual norway elbilforeninge n status yes yes seems fair people use hair express use theonion making onion articles real rollingstone music music-ne ws elon-musk-rap-song-rip-harambe yungjake bloodpop duck emoji ftw final edit ableton surprisingly difficult address false positives rain system go nuts trying wipe away non-existent rain obv ineffective jung pic pdr jilpu weve mired production logistics past months really looking fwd getting semi production tesla semi delivering tesla cars pic ttepcw dg pre-happy birthday amazing work tesla delivery teams especially europe china insane logistics challenge ive ever seen thanks also many country city officials help weekend super appreciated coming soon wow might finest work duck emoji defeats emo g records crushing victory im disappointed record label failed emo g records soundcloud user pic anvkkefmgr instagram comments coding emojis also true true quality emojis varies wildly lame c syntax sucks assert money series heterogeneous databases insecurely connected high latency primary purpose information system allocation human time automation value money even connectivity house silicon valley sucks like movie us scary also empathetic sure way around also intense low frequency vibrations cant hear feel chest going try side boosters come back cape center core lands droneship latter coming hot fast dicey annoying ula perpetuates myth delta iv heavy atlas orbits falcon heavy cant absolutely false fh go full expendable geo direct thats rare yeah falcon heavy block way performance last years vehicle lot room increase side booster load transfer max q without changing parts fh block launch payload orbit vehicle currently flying probably fairing either raptor vacuum engines mass ratio tons full tons empty isp drop dozen modified starlink satellites empty engine bays isp mr spread see whats impossible retrofits start software able take meaningful advantage tesla fsd computer order magnitude capable slightly disadvantageous tesla fsd computer software refined hw anyone bought fsd get anyone purchased full self-driving get fsd computer upgrade free change autopilot hw hw going forward hw called fsd computer accurate change vehicle sensors wire harness needed important samscho status yes sensitive propulsion avionics remained dry great work spacex dragon engineering team major improvement dragon massive delta velocity slam highly elliptical earth orbit using fully retanked lightened starship heat shield fins legs best choice impatient ion engines slow send probes outer solar system get high res true color images strange things maybe theres alien artifact super cool good point tax authorities tend interpret things favor sure sounds like could right investigate rare use case possible complications eary prototype roadsters ability exactly super proud tesla autopilot team one week either way think sure worth giving best shot great competitive commercial program build moon base outcome-oriented cost-plus get paid safe delivery cargo inspiring humanity see humanity return moon lbs puny construct childrens toys thats exactly youre longer mentally fatigued long drive makes major difference happiness level commuting home work long day sspencersmb tatus good point hard appreciate much tesla autopilot improves enjoyment driving try erdayastronaut status yes otherwise propellant usage atmospheric entry high center mass need tightly constrained yes going skip first avoid fragging launch pads glad like n ...
